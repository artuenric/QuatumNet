# %% [markdown]
# # <b>Avalia o comportamento das Requests</b>

# %%
# Importando as dependências
from quantumnet.components import Controller, Network
from quantumnet.objects import time
from simulations.simulation import Sim

# %% [markdown]
# Informações a serem coletadas

# %%
received_requests = {}
successful_requests = {}
fulfilled_requests = {}

# %% [markdown]
# ### <b>Preenchimento Proativo</b>

# %%
# Parâmetros das simulações
network_info = {
    'n_initial_qubits': 10,
    'n_initial_eprs': 10,
    'topology_name': 'Grade',
    'topology_params': (3, 4),
    'time_to_refill': 10,
}
controller_info = {
    'default_ttl': 50,
}
request_info = {
    'num_hosts': 12,
    'n_requests': 100,
    'traffic_type': 'random',
    'burst_probability': 0.3,
    'burst_size': 25,
    'requests_per_burst': 5,
    'fmin_range': (0.5, 1.0),
    'eprs_range': (1, 10),
}
# Exclusivo para preenchimento proativo e hibrido
proactive_params = {
    1 : { 'frange': (0.6, 0.7), 'neprs': 10 },
    5:  { 'frange': (0.8, 0.9), 'neprs': 10 },
}

# %%
# Inicializando a simulação
sim = Sim(network_info, controller_info, request_info)
print(f"Requests: {sim.requests}")

# Preenche as tabelas de forma proativa
for alice in sim.network.hosts:
    print(f"Adicionando regras para {alice}")
    for bob in sim.network.hosts:
        for key in proactive_params.keys():
            sim.controller.add_match_route_rule_in_host_proactive(alice, bob, proactive_params[key]['frange'], proactive_params[key]['neprs'])
    # Mostra as tabelas
    sim.network.get_host(alice).draw_flow_table()
# Out:
# Requests: [R8F4CB0:3-9:0.74:10, RB2CA70:3-1:0.6:1, R2F7EF0:8-11:0.94:10, RE95880:0-11:0.66:2, RE7AAE0:2-7:0.89:1, RE7AB10:2-10:0.78:4, RE7AB40:5-0:0.99:4, RE7AB70:4-9:0.59:10, RE7ABA0:9-7:0.69:10, RE7ABD0:6-1:0.98:5, RE7AC00:10-3:0.73:1, RE7AC30:10-4:0.69:5, RE7AC60:3-9:0.69:10, RE7AC90:1-0:0.93:3, RE7ACC0:4-3:0.77:6, RE7ACF0:3-2:0.61:8, RE7AD20:5-7:0.63:2, RE7AD50:5-8:0.92:4, RE7AD80:9-4:0.91:9, RE7ADB0:2-0:0.93:4, RE7ADE0:11-9:0.99:3, RE7AE10:6-4:0.55:2, RE7AE40:7-9:0.6:3, RE7AE70:5-4:0.61:5, RE7AEA0:10-8:0.67:7, RE7AED0:9-2:0.86:8, RE7AF00:7-8:0.55:3, RE7AF30:4-6:0.75:4, RE7AF60:6-9:0.59:5, RE7AF90:7-4:0.51:8, RE7AFC0:1-2:0.79:9, RE7AFF0:3-4:0.5:6, RE7B020:8-3:0.67:1, RE7B050:11-4:0.97:3, RE7B080:1-10:0.92:9, RE7B0B0:7-9:0.88:2, RE7B0E0:6-7:0.88:7, RE7B110:10-0:0.67:4, RE7B140:4-8:0.85:8, RE7B170:7-4:0.97:8, RE7B1A0:2-8:0.65:1, RE7B1D0:3-0:0.83:3, RE7B200:7-11:0.76:5, RE7B230:5-10:0.97:5, RE7B260:7-3:0.79:1, RE7B290:4-11:0.68:6, RE7B2C0:0-6:0.64:8, RE7B2F0:8-2:0.88:8, RE7B320:6-3:0.6:7, RE7B350:1-4:0.75:3, RE7B380:2-11:0.83:9, RE7B3B0:11-2:0.74:5, RE7B3E0:2-6:0.83:5, RE7B410:10-11:0.62:6, RE7B440:10-5:0.76:4, RE7B470:3-10:0.53:4, RE7B4A0:5-10:0.75:10, RE7B4D0:9-4:0.89:8, RE7B500:11-7:0.59:7, RE7B530:11-1:0.81:1, RE7B560:10-2:0.61:9, RE7B590:11-3:0.54:2, RE7B5C0:6-4:0.85:5, RE7B5F0:5-2:0.59:5, RE7B620:9-5:0.53:2, RE7B650:4-6:0.99:10, RE7B680:5-2:0.93:6, RE7B6B0:11-7:0.9:5, RE7B6E0:7-10:0.8:7, RE7B710:7-0:0.7:3, RE7B740:5-2:0.99:4, RE7B770:10-2:0.64:8, RE7B7A0:0-5:0.68:10, RE7B7D0:10-2:0.61:5, RE7B800:9-2:0.67:5, RE7B830:3-9:0.96:4, RE7B860:9-10:0.85:4, RE7B890:11-8:0.76:5, RE7B8C0:0-4:0.7:4, RE7B8F0:6-5:0.62:9, RE7B920:3-2:0.71:2, RE7B950:5-3:0.99:7, RE7B980:1-2:0.51:5, RE7B9B0:7-9:1.0:10, RE7B9E0:2-8:0.64:6, RE7BA10:7-1:0.86:5, RE7BA40:11-9:0.81:6, RE7BA70:1-6:0.73:4, RE7BAA0:0-10:0.93:10, RE7BAD0:8-7:0.55:8, RE7BB00:0-8:0.67:7, RE7BB30:11-4:0.88:8, RE7BB60:5-9:0.67:3, RE7BB90:0-2:0.65:1, RE7BBC0:6-5:0.72:9, RE7BBF0:9-6:0.94:5, RE7BC20:7-8:0.89:10, RE7BC50:2-1:0.73:7, RE7BC80:0-11:0.79:1, RE7BCB0:10-11:0.83:8]
# Adicionando regras para 0
# +----------------------+----------------------+--------------------+
# | Match                | Route                | Rule               |
# +======================+======================+====================+
# | (0, (0.6, 0.7), 10)  | [0]                  | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [0]                  | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [0, 1]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [0, 1]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [0, 1, 2]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [0, 1, 2]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [0, 4]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [0, 4]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [0, 1, 5]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [0, 1, 5]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [0, 4, 8]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [0, 4, 8]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# Adicionando regras para 1
# +----------------------+-------------------+--------------------+
# | Match                | Route             | Rule               |
# +======================+===================+====================+
# | (0, (0.6, 0.7), 10)  | [1, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [1, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [1]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [1]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [1, 2]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [1, 2]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [1, 2, 3]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [1, 2, 3]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [1, 0, 4]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [1, 0, 4]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [1, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [1, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [1, 2, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [1, 2, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [1, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [1, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [1, 5, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [1, 5, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# Adicionando regras para 2
# +----------------------+-----------------+--------------------+
# | Match                | Route           | Rule               |
# +======================+=================+====================+
# | (0, (0.6, 0.7), 10)  | [2, 1, 0]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [2, 1, 0]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [2, 1]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [2, 1]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [2]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [2]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [2, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [2, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [2, 1, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [2, 1, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [2, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [2, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [2, 3, 7]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [2, 3, 7]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.6, 0.7), 10) | [2, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 10) | [2, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.6, 0.7), 10) | [2, 3, 7, 11]   | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 10) | [2, 3, 7, 11]   | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# Adicionando regras para 3
# +----------------------+--------------------+--------------------+
# | Match                | Route              | Rule               |
# +======================+====================+====================+
# | (0, (0.6, 0.7), 10)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [3, 2, 1]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [3, 2, 1]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [3, 2]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [3, 2]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [3]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [3]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [3, 2, 6]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [3, 2, 6]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [3, 7]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [3, 7]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [3, 2, 6, 10]      | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [3, 2, 6, 10]      | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [3, 7, 11]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [3, 7, 11]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# Adicionando regras para 4
# +----------------------+-------------------+--------------------+
# | Match                | Route             | Rule               |
# +======================+===================+====================+
# | (0, (0.6, 0.7), 10)  | [4, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [4, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [4, 0, 1]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [4, 0, 1]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [4]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [4]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [4, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [4, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [4, 5, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [4, 5, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [4, 8]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [4, 8]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [4, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [4, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# Adicionando regras para 5
# +----------------------+---------------+--------------------+
# | Match                | Route         | Rule               |
# +======================+===============+====================+
# | (0, (0.6, 0.7), 10)  | [5, 4, 0]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [5, 4, 0]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [5, 1]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [5, 1]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [5, 1, 2]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [5, 1, 2]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [5, 4]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [5, 4]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [5]           | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [5]           | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [5, 6]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [5, 6]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [5, 6, 7]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [5, 6, 7]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [5, 4, 8]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [5, 4, 8]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [5, 9]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [5, 9]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (10, (0.6, 0.7), 10) | [5, 6, 10]    | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (10, (0.8, 0.9), 10) | [5, 6, 10]    | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (11, (0.6, 0.7), 10) | [5, 6, 7, 11] | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (11, (0.8, 0.9), 10) | [5, 6, 7, 11] | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# Adicionando regras para 6
# +----------------------+--------------+--------------------+
# | Match                | Route        | Rule               |
# +======================+==============+====================+
# | (0, (0.6, 0.7), 10)  | [6, 5, 4, 0] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [6, 5, 4, 0] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [6, 5, 1]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [6, 5, 1]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [6, 2]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [6, 2]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [6, 2, 3]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [6, 2, 3]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [6, 5, 4]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [6, 5, 4]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [6, 5]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [6, 5]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [6]          | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [6]          | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [6, 7]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [6, 7]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [6, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [6, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (10, (0.6, 0.7), 10) | [6, 10]      | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (10, (0.8, 0.9), 10) | [6, 10]      | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (11, (0.6, 0.7), 10) | [6, 7, 11]   | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (11, (0.8, 0.9), 10) | [6, 7, 11]   | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# Adicionando regras para 7
# +----------------------+-----------------+--------------------+
# | Match                | Route           | Rule               |
# +======================+=================+====================+
# | (0, (0.6, 0.7), 10)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [7, 6, 2]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [7, 6, 2]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [7, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [7, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [7, 6, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [7, 6, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [7, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [7, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [7]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [7]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.6, 0.7), 10) | [7, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 10) | [7, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.6, 0.7), 10) | [7, 11]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 10) | [7, 11]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# Adicionando regras para 8
# +----------------------+--------------------+--------------------+
# | Match                | Route              | Rule               |
# +======================+====================+====================+
# | (0, (0.6, 0.7), 10)  | [8, 4, 0]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [8, 4, 0]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [8, 4]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [8, 4]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [8, 4, 5]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [8, 4, 5]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [8]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [8]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [8, 9]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [8, 9]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [8, 9, 10]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [8, 9, 10]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [8, 9, 10, 11]     | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [8, 9, 10, 11]     | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# Adicionando regras para 9
# +----------------------+-----------------+--------------------+
# | Match                | Route           | Rule               |
# +======================+=================+====================+
# | (0, (0.6, 0.7), 10)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [9, 5, 1]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [9, 5, 1]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [9, 8, 4]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [9, 8, 4]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [9, 5]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [9, 5]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [9, 5, 6]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [9, 5, 6]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [9, 8]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [9, 8]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [9]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [9]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.6, 0.7), 10) | [9, 10]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 10) | [9, 10]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.6, 0.7), 10) | [9, 10, 11]     | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 10) | [9, 10, 11]     | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# Adicionando regras para 10
# +----------------------+------------------+--------------------+
# | Match                | Route            | Rule               |
# +======================+==================+====================+
# | (0, (0.6, 0.7), 10)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [10, 6, 2]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [10, 6, 2]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [10, 9, 5]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [10, 9, 5]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [10, 6]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [10, 6]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [10, 6, 7]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [10, 6, 7]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [10, 9, 8]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [10, 9, 8]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [10, 9]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [10, 9]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [10]             | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [10]             | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [10, 11]         | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [10, 11]         | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# Adicionando regras para 11
# +----------------------+---------------------+--------------------+
# | Match                | Route               | Rule               |
# +======================+=====================+====================+
# | (0, (0.6, 0.7), 10)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [11, 7, 3]          | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [11, 7, 3]          | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [11, 10, 6]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [11, 10, 6]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [11, 7]             | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [11, 7]             | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [11, 10, 9]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [11, 10, 9]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [11, 10]            | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [11, 10]            | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [11]                | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [11]                | BasicRuleProactive |
# +----------------------+---------------------+--------------------+

# %%
# Processa as requisições
for request in sim.requests:
    print(f"[Time {time.get_current_time()}] Processando requisição {request}.")
    alice = sim.network.get_host(request.alice)
    rule = alice.find_rule_by_request(request)

    if rule == False:  # Caso não exista um match na tabela
        print(f"[Time {time.get_current_time()}] Descartando requisição {request} no Host {alice}.")
        request.starttime = time.get_current_time()
        request.endtime = time.get_current_time()
        # Registra a requisição descartada
        sim.controller.fulfill_request(request)
        
    else:  # Caso já exista a regra
        print(f"[Time {time.get_current_time()}] Atendendo requisição {request} no Host {alice}.")
        request.starttime = time.get_current_time()
        sim.controller.run_rule(rule[1])
        request.endtime = time.get_current_time() + 1        
        # Registra a requisição atendida
        sim.controller.successful_request(request)
        # Exibir informações da requisição
        print(f"Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")
        
    # Atualiza o tempo
    sim.update_time(1)

# Salva as requisições
received_requests['proativo'] = sim.requests.copy()
successful_requests['proativo'] = sim.controller.successful_requests
fulfilled_requests['proativo'] = sim.controller.fulfilled_requests

# Fim da simulação
time.reset()
# Out:
# [Time 0] Processando requisição R8F4CB0:3-9:0.74:10.
# [Time 0] Descartando requisição R8F4CB0:3-9:0.74:10 no Host 3.
# [Time 1] Processando requisição RB2CA70:3-1:0.6:1.
# [Time 1] Atendendo requisição RB2CA70:3-1:0.6:1 no Host 3.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request RB2CA70:3-1:0.6:1: Start Time = 1, End Time = 2
# [Time 2] Processando requisição R2F7EF0:8-11:0.94:10.
# [Time 2] Descartando requisição R2F7EF0:8-11:0.94:10 no Host 8.
# [Time 3] Processando requisição RE95880:0-11:0.66:2.
# [Time 3] Atendendo requisição RE95880:0-11:0.66:2 no Host 0.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Ação: CreateEPR(8-9)
# [BasicRuleProactive] Ação: CreateEPR(9-10)
# [BasicRuleProactive] Ação: CreateEPR(10-11)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(0-4-8)
# Running Swap(0-4-8)
# [BasicRuleProactive] Ação: Swap(8-9-10)
# Running Swap(8-9-10)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(0-8-10)
# Running Swap(0-8-10)
# Request RE95880:0-11:0.66:2: Start Time = 3, End Time = 4
# [Time 4] Processando requisição RE7AAE0:2-7:0.89:1.
# [Time 4] Atendendo requisição RE7AAE0:2-7:0.89:1 no Host 2.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Ação: CreateEPR(3-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request RE7AAE0:2-7:0.89:1: Start Time = 4, End Time = 5
# [Time 5] Processando requisição RE7AB10:2-10:0.78:4.
# [Time 5] Descartando requisição RE7AB10:2-10:0.78:4 no Host 2.
# [Time 6] Processando requisição RE7AB40:5-0:0.99:4.
# [Time 6] Descartando requisição RE7AB40:5-0:0.99:4 no Host 5.
# [Time 7] Processando requisição RE7AB70:4-9:0.59:10.
# [Time 7] Descartando requisição RE7AB70:4-9:0.59:10 no Host 4.
# [Time 8] Processando requisição RE7ABA0:9-7:0.69:10.
# [Time 8] Atendendo requisição RE7ABA0:9-7:0.69:10 no Host 9.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request RE7ABA0:9-7:0.69:10: Start Time = 8, End Time = 9
# [Time 9] Processando requisição RE7ABD0:6-1:0.98:5.
# [Time 9] Descartando requisição RE7ABD0:6-1:0.98:5 no Host 6.
# [Time 10] Recursos atualizados
# [Time 10] Processando requisição RE7AC00:10-3:0.73:1.
# [Time 10] Descartando requisição RE7AC00:10-3:0.73:1 no Host 10.
# [Time 11] Processando requisição RE7AC30:10-4:0.69:5.
# [Time 11] Atendendo requisição RE7AC30:10-4:0.69:5 no Host 10.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request RE7AC30:10-4:0.69:5: Start Time = 11, End Time = 12
# [Time 12] Processando requisição RE7AC60:3-9:0.69:10.
# [Time 12] Atendendo requisição RE7AC60:3-9:0.69:10 no Host 3.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-5)
# [BasicRuleProactive] Ação: CreateEPR(5-9)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(3-2-1)
# Running Swap(3-2-1)
# [BasicRuleProactive] Ação: Swap(1-5-9)
# Running Swap(1-5-9)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(3-1-9)
# Running Swap(3-1-9)
# Request RE7AC60:3-9:0.69:10: Start Time = 12, End Time = 13
# [Time 13] Processando requisição RE7AC90:1-0:0.93:3.
# [Time 13] Descartando requisição RE7AC90:1-0:0.93:3 no Host 1.
# [Time 14] Processando requisição RE7ACC0:4-3:0.77:6.
# [Time 14] Descartando requisição RE7ACC0:4-3:0.77:6 no Host 4.
# [Time 15] Processando requisição RE7ACF0:3-2:0.61:8.
# [Time 15] Atendendo requisição RE7ACF0:3-2:0.61:8 no Host 3.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# Request RE7ACF0:3-2:0.61:8: Start Time = 15, End Time = 16
# [Time 16] Processando requisição RE7AD20:5-7:0.63:2.
# [Time 16] Atendendo requisição RE7AD20:5-7:0.63:2 no Host 5.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Request RE7AD20:5-7:0.63:2: Start Time = 16, End Time = 17
# [Time 17] Processando requisição RE7AD50:5-8:0.92:4.
# [Time 17] Descartando requisição RE7AD50:5-8:0.92:4 no Host 5.
# [Time 18] Processando requisição RE7AD80:9-4:0.91:9.
# [Time 18] Descartando requisição RE7AD80:9-4:0.91:9 no Host 9.
# [Time 19] Processando requisição RE7ADB0:2-0:0.93:4.
# [Time 19] Descartando requisição RE7ADB0:2-0:0.93:4 no Host 2.
# [Time 20] Recursos atualizados
# [Time 20] Processando requisição RE7ADE0:11-9:0.99:3.
# [Time 20] Descartando requisição RE7ADE0:11-9:0.99:3 no Host 11.
# [Time 21] Processando requisição RE7AE10:6-4:0.55:2.
# [Time 21] Descartando requisição RE7AE10:6-4:0.55:2 no Host 6.
# [Time 22] Processando requisição RE7AE40:7-9:0.6:3.
# [Time 22] Atendendo requisição RE7AE40:7-9:0.6:3 no Host 7.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-9)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request RE7AE40:7-9:0.6:3: Start Time = 22, End Time = 23
# [Time 23] Processando requisição RE7AE70:5-4:0.61:5.
# [Time 23] Atendendo requisição RE7AE70:5-4:0.61:5 no Host 5.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# Request RE7AE70:5-4:0.61:5: Start Time = 23, End Time = 24
# [Time 24] Processando requisição RE7AEA0:10-8:0.67:7.
# [Time 24] Atendendo requisição RE7AEA0:10-8:0.67:7 no Host 10.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-9)
# [BasicRuleProactive] Ação: CreateEPR(9-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request RE7AEA0:10-8:0.67:7: Start Time = 24, End Time = 25
# [Time 25] Processando requisição RE7AED0:9-2:0.86:8.
# [Time 25] Atendendo requisição RE7AED0:9-2:0.86:8 no Host 9.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-5)
# [BasicRuleProactive] Ação: CreateEPR(5-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request RE7AED0:9-2:0.86:8: Start Time = 25, End Time = 26
# [Time 26] Processando requisição RE7AF00:7-8:0.55:3.
# [Time 26] Descartando requisição RE7AF00:7-8:0.55:3 no Host 7.
# [Time 27] Processando requisição RE7AF30:4-6:0.75:4.
# [Time 27] Descartando requisição RE7AF30:4-6:0.75:4 no Host 4.
# [Time 28] Processando requisição RE7AF60:6-9:0.59:5.
# [Time 28] Descartando requisição RE7AF60:6-9:0.59:5 no Host 6.
# [Time 29] Processando requisição RE7AF90:7-4:0.51:8.
# [Time 29] Descartando requisição RE7AF90:7-4:0.51:8 no Host 7.
# [Time 30] Recursos atualizados
# [Time 30] Processando requisição RE7AFC0:1-2:0.79:9.
# [Time 30] Descartando requisição RE7AFC0:1-2:0.79:9 no Host 1.
# [Time 31] Processando requisição RE7AFF0:3-4:0.5:6.
# [Time 31] Descartando requisição RE7AFF0:3-4:0.5:6 no Host 3.
# [Time 32] Processando requisição RE7B020:8-3:0.67:1.
# [Time 32] Atendendo requisição RE7B020:8-3:0.67:1 no Host 8.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# [BasicRuleProactive] Ação: Swap(0-1-2)
# Running Swap(0-1-2)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request RE7B020:8-3:0.67:1: Start Time = 32, End Time = 33
# [Time 33] Processando requisição RE7B050:11-4:0.97:3.
# [Time 33] Descartando requisição RE7B050:11-4:0.97:3 no Host 11.
# [Time 34] Processando requisição RE7B080:1-10:0.92:9.
# [Time 34] Descartando requisição RE7B080:1-10:0.92:9 no Host 1.
# [Time 35] Processando requisição RE7B0B0:7-9:0.88:2.
# [Time 35] Atendendo requisição RE7B0B0:7-9:0.88:2 no Host 7.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-9)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request RE7B0B0:7-9:0.88:2: Start Time = 35, End Time = 36
# [Time 36] Processando requisição RE7B0E0:6-7:0.88:7.
# [Time 36] Atendendo requisição RE7B0E0:6-7:0.88:7 no Host 6.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# Request RE7B0E0:6-7:0.88:7: Start Time = 36, End Time = 37
# [Time 37] Processando requisição RE7B110:10-0:0.67:4.
# [Time 37] Atendendo requisição RE7B110:10-0:0.67:4 no Host 10.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-2)
# Running Swap(10-6-2)
# [BasicRuleProactive] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(10-2-0)
# Running Swap(10-2-0)
# Request RE7B110:10-0:0.67:4: Start Time = 37, End Time = 38
# [Time 38] Processando requisição RE7B140:4-8:0.85:8.
# [Time 38] Atendendo requisição RE7B140:4-8:0.85:8 no Host 4.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# Request RE7B140:4-8:0.85:8: Start Time = 38, End Time = 39
# [Time 39] Processando requisição RE7B170:7-4:0.97:8.
# [Time 39] Descartando requisição RE7B170:7-4:0.97:8 no Host 7.
# [Time 40] Recursos atualizados
# [Time 40] Processando requisição RE7B1A0:2-8:0.65:1.
# [Time 40] Atendendo requisição RE7B1A0:2-8:0.65:1 no Host 2.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# [BasicRuleProactive] Ação: Swap(0-4-8)
# Running Swap(0-4-8)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(2-0-8)
# Running Swap(2-0-8)
# Request RE7B1A0:2-8:0.65:1: Start Time = 40, End Time = 41
# [Time 41] Processando requisição RE7B1D0:3-0:0.83:3.
# [Time 41] Atendendo requisição RE7B1D0:3-0:0.83:3 no Host 3.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request RE7B1D0:3-0:0.83:3: Start Time = 41, End Time = 42
# [Time 42] Processando requisição RE7B200:7-11:0.76:5.
# [Time 42] Descartando requisição RE7B200:7-11:0.76:5 no Host 7.
# [Time 43] Processando requisição RE7B230:5-10:0.97:5.
# [Time 43] Descartando requisição RE7B230:5-10:0.97:5 no Host 5.
# [Time 44] Processando requisição RE7B260:7-3:0.79:1.
# [Time 44] Descartando requisição RE7B260:7-3:0.79:1 no Host 7.
# [Time 45] Processando requisição RE7B290:4-11:0.68:6.
# [Time 45] Atendendo requisição RE7B290:4-11:0.68:6 no Host 4.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Ação: CreateEPR(8-9)
# [BasicRuleProactive] Ação: CreateEPR(9-10)
# [BasicRuleProactive] Ação: CreateEPR(10-11)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(4-8-9)
# Running Swap(4-8-9)
# [BasicRuleProactive] Ação: Swap(9-10-11)
# Running Swap(9-10-11)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(4-9-11)
# Running Swap(4-9-11)
# Request RE7B290:4-11:0.68:6: Start Time = 45, End Time = 46
# [Time 46] Processando requisição RE7B2C0:0-6:0.64:8.
# [Time 46] Atendendo requisição RE7B2C0:0-6:0.64:8 no Host 0.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request RE7B2C0:0-6:0.64:8: Start Time = 46, End Time = 47
# [Time 47] Processando requisição RE7B2F0:8-2:0.88:8.
# [Time 47] Atendendo requisição RE7B2F0:8-2:0.88:8 no Host 8.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# [BasicRuleProactive] Ação: Swap(0-1-2)
# Running Swap(0-1-2)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request RE7B2F0:8-2:0.88:8: Start Time = 47, End Time = 48
# [Time 48] Processando requisição RE7B320:6-3:0.6:7.
# [Time 48] Atendendo requisição RE7B320:6-3:0.6:7 no Host 6.
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(6-2-3)
# Running Swap(6-2-3)
# Request RE7B320:6-3:0.6:7: Start Time = 48, End Time = 49
# [Time 49] Processando requisição RE7B350:1-4:0.75:3.
# [Time 49] Descartando requisição RE7B350:1-4:0.75:3 no Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [Time 50] Recursos atualizados
# [Time 50] Processando requisição RE7B380:2-11:0.83:9.
# [Time 50] Descartando requisição RE7B380:2-11:0.83:9 no Host 2.
# [Time 51] Processando requisição RE7B3B0:11-2:0.74:5.
# [Time 51] Descartando requisição RE7B3B0:11-2:0.74:5 no Host 11.
# [Time 52] Processando requisição RE7B3E0:2-6:0.83:5.
# [Time 52] Descartando requisição RE7B3E0:2-6:0.83:5 no Host 2.
# [Time 53] Processando requisição RE7B410:10-11:0.62:6.
# [Time 53] Descartando requisição RE7B410:10-11:0.62:6 no Host 10.
# [Time 54] Processando requisição RE7B440:10-5:0.76:4.
# [Time 54] Descartando requisição RE7B440:10-5:0.76:4 no Host 10.
# [Time 55] Processando requisição RE7B470:3-10:0.53:4.
# [Time 55] Descartando requisição RE7B470:3-10:0.53:4 no Host 3.
# [Time 56] Processando requisição RE7B4A0:5-10:0.75:10.
# [Time 56] Descartando requisição RE7B4A0:5-10:0.75:10 no Host 5.
# [Time 57] Processando requisição RE7B4D0:9-4:0.89:8.
# [Time 57] Descartando requisição RE7B4D0:9-4:0.89:8 no Host 9.
# [Time 58] Processando requisição RE7B500:11-7:0.59:7.
# [Time 58] Descartando requisição RE7B500:11-7:0.59:7 no Host 11.
# [Time 59] Processando requisição RE7B530:11-1:0.81:1.
# [Time 59] Descartando requisição RE7B530:11-1:0.81:1 no Host 11.
# [Time 60] Recursos atualizados
# [Time 60] Processando requisição RE7B560:10-2:0.61:9.
# [Time 60] Descartando requisição RE7B560:10-2:0.61:9 no Host 10.
# [Time 61] Processando requisição RE7B590:11-3:0.54:2.
# [Time 61] Descartando requisição RE7B590:11-3:0.54:2 no Host 11.
# [Time 62] Processando requisição RE7B5C0:6-4:0.85:5.
# [Time 62] Descartando requisição RE7B5C0:6-4:0.85:5 no Host 6.
# [Time 63] Processando requisição RE7B5F0:5-2:0.59:5.
# [Time 63] Descartando requisição RE7B5F0:5-2:0.59:5 no Host 5.
# [Time 64] Processando requisição RE7B620:9-5:0.53:2.
# [Time 64] Descartando requisição RE7B620:9-5:0.53:2 no Host 9.
# [Time 65] Processando requisição RE7B650:4-6:0.99:10.
# [Time 65] Descartando requisição RE7B650:4-6:0.99:10 no Host 4.
# [Time 66] Processando requisição RE7B680:5-2:0.93:6.
# [Time 66] Descartando requisição RE7B680:5-2:0.93:6 no Host 5.
# [Time 67] Processando requisição RE7B6B0:11-7:0.9:5.
# [Time 67] Descartando requisição RE7B6B0:11-7:0.9:5 no Host 11.
# [Time 68] Processando requisição RE7B6E0:7-10:0.8:7.
# [Time 68] Descartando requisição RE7B6E0:7-10:0.8:7 no Host 7.
# [Time 69] Processando requisição RE7B710:7-0:0.7:3.
# [Time 69] Descartando requisição RE7B710:7-0:0.7:3 no Host 7.
# [Time 70] Recursos atualizados
# [Time 70] Processando requisição RE7B740:5-2:0.99:4.
# [Time 70] Descartando requisição RE7B740:5-2:0.99:4 no Host 5.
# [Time 71] Processando requisição RE7B770:10-2:0.64:8.
# [Time 71] Descartando requisição RE7B770:10-2:0.64:8 no Host 10.
# [Time 72] Processando requisição RE7B7A0:0-5:0.68:10.
# [Time 72] Descartando requisição RE7B7A0:0-5:0.68:10 no Host 0.
# [Time 73] Processando requisição RE7B7D0:10-2:0.61:5.
# [Time 73] Descartando requisição RE7B7D0:10-2:0.61:5 no Host 10.
# [Time 74] Processando requisição RE7B800:9-2:0.67:5.
# [Time 74] Descartando requisição RE7B800:9-2:0.67:5 no Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [Time 75] Processando requisição RE7B830:3-9:0.96:4.
# [Time 75] Descartando requisição RE7B830:3-9:0.96:4 no Host 3.
# [Time 76] Processando requisição RE7B860:9-10:0.85:4.
# [Time 76] Descartando requisição RE7B860:9-10:0.85:4 no Host 9.
# [Time 77] Processando requisição RE7B890:11-8:0.76:5.
# [Time 77] Descartando requisição RE7B890:11-8:0.76:5 no Host 11.
# [Time 78] Processando requisição RE7B8C0:0-4:0.7:4.
# [Time 78] Descartando requisição RE7B8C0:0-4:0.7:4 no Host 0.
# [Time 79] Processando requisição RE7B8F0:6-5:0.62:9.
# [Time 79] Descartando requisição RE7B8F0:6-5:0.62:9 no Host 6.
# [Time 80] Recursos atualizados
# [Time 80] Processando requisição RE7B920:3-2:0.71:2.
# [Time 80] Descartando requisição RE7B920:3-2:0.71:2 no Host 3.
# [Time 81] Processando requisição RE7B950:5-3:0.99:7.
# [Time 81] Descartando requisição RE7B950:5-3:0.99:7 no Host 5.
# [Time 82] Processando requisição RE7B980:1-2:0.51:5.
# [Time 82] Descartando requisição RE7B980:1-2:0.51:5 no Host 1.
# [Time 83] Processando requisição RE7B9B0:7-9:1.0:10.
# [Time 83] Descartando requisição RE7B9B0:7-9:1.0:10 no Host 7.
# [Time 84] Processando requisição RE7B9E0:2-8:0.64:6.
# [Time 84] Descartando requisição RE7B9E0:2-8:0.64:6 no Host 2.
# [Time 85] Processando requisição RE7BA10:7-1:0.86:5.
# [Time 85] Descartando requisição RE7BA10:7-1:0.86:5 no Host 7.
# [Time 86] Processando requisição RE7BA40:11-9:0.81:6.
# [Time 86] Descartando requisição RE7BA40:11-9:0.81:6 no Host 11.
# [Time 87] Processando requisição RE7BA70:1-6:0.73:4.
# [Time 87] Descartando requisição RE7BA70:1-6:0.73:4 no Host 1.
# [Time 88] Processando requisição RE7BAA0:0-10:0.93:10.
# [Time 88] Descartando requisição RE7BAA0:0-10:0.93:10 no Host 0.
# [Time 89] Processando requisição RE7BAD0:8-7:0.55:8.
# [Time 89] Descartando requisição RE7BAD0:8-7:0.55:8 no Host 8.
# [Time 90] Recursos atualizados
# [Time 90] Processando requisição RE7BB00:0-8:0.67:7.
# [Time 90] Descartando requisição RE7BB00:0-8:0.67:7 no Host 0.
# [Time 91] Processando requisição RE7BB30:11-4:0.88:8.
# [Time 91] Descartando requisição RE7BB30:11-4:0.88:8 no Host 11.
# [Time 92] Processando requisição RE7BB60:5-9:0.67:3.
# [Time 92] Descartando requisição RE7BB60:5-9:0.67:3 no Host 5.
# [Time 93] Processando requisição RE7BB90:0-2:0.65:1.
# [Time 93] Descartando requisição RE7BB90:0-2:0.65:1 no Host 0.
# [Time 94] Processando requisição RE7BBC0:6-5:0.72:9.
# [Time 94] Descartando requisição RE7BBC0:6-5:0.72:9 no Host 6.
# [Time 95] Processando requisição RE7BBF0:9-6:0.94:5.
# [Time 95] Descartando requisição RE7BBF0:9-6:0.94:5 no Host 9.
# [Time 96] Processando requisição RE7BC20:7-8:0.89:10.
# [Time 96] Descartando requisição RE7BC20:7-8:0.89:10 no Host 7.
# [Time 97] Processando requisição RE7BC50:2-1:0.73:7.
# [Time 97] Descartando requisição RE7BC50:2-1:0.73:7 no Host 2.
# [Time 98] Processando requisição RE7BC80:0-11:0.79:1.
# [Time 98] Descartando requisição RE7BC80:0-11:0.79:1 no Host 0.
# [Time 99] Processando requisição RE7BCB0:10-11:0.83:8.
# [Time 99] Descartando requisição RE7BCB0:10-11:0.83:8 no Host 10.
# [Time 100] Recursos atualizados

# %% [markdown]
# ### <b>Preenchimento Reativo</b>

# %%
# Parâmetros das simulações
network_info = {
    'n_initial_qubits': 10,
    'n_initial_eprs': 10,
    'topology_name': 'Grade',
    'topology_params': (3, 4),
    'time_to_refill': 10,
}
controller_info = {
    'default_ttl': 50,
}
request_info = {
    'num_hosts': 12,
    'n_requests': 100,
    'traffic_type': 'random',
    'burst_probability': 0.3,
    'burst_size': 25,
    'requests_per_burst': 5,
    'fmin_range': (0.5, 1.0),
    'eprs_range': (1, 10),
}

# %%
# Inicializando a simulação
sim = Sim(network_info, controller_info, request_info)
print("Requests:", sim.requests)

for request in sim.requests:
        print(f"[Time {time.get_current_time()}] Processando requisição {request}...")
        alice = sim.network.get_host(request.alice)
        rule = alice.find_rule_by_request(request)

        if rule == False:  # Caso não exista um match na tabela
            request.starttime = time.get_current_time()
            sim.update_time(3)
            alice.draw_flow_table()
            print(f"[Time {time.get_current_time()}] Adicionando regra no Host {alice}")
            sim.controller.add_match_route_rule_in_host_reactive(request)
            alice.draw_flow_table()
            rule = alice.find_rule_by_request(request)
            
        else:  # Caso já exista a regra
            print(f"[Time {time.get_current_time()}] Regra existente para {request} no Host {alice}.")
            request.starttime = time.get_current_time()
            sim.update_time(1)
                
        # Executa a regra
        print(f"[Time {time.get_current_time()}] Atendendo requisição {request} no Host {alice}.")
        sim.controller.run_rule(rule[1])
        request.endtime = time.get_current_time()
        # Registra a requisição atendida
        sim.controller.successful_request(request)
        
        # Exibir informações da requisição
        print(f"[Time {time.get_current_time()}] Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")

# Salva as requisições
received_requests['reativo'] = sim.requests.copy()
successful_requests['reativo'] = sim.controller.successful_requests
fulfilled_requests['reativo'] = sim.controller.fulfilled_requests

# Fim da simulação
time.reset()
# Out:
# Requests: [R754860:4-7:0.66:8, REA8B00:2-0:0.57:3, REA8B30:2-1:0.73:2, REA8B60:5-2:0.85:5, REA8B90:9-2:0.64:5, REA8BC0:9-6:0.87:6, REA8BF0:2-4:0.88:10, REA8C20:10-5:0.58:8, REA8C50:1-5:0.53:3, REA8C80:1-0:0.91:4, REA8CB0:10-6:0.57:9, REA8CE0:6-11:0.86:9, REA8D10:0-9:0.65:10, REA8D40:9-5:0.63:2, REA8D70:10-3:0.52:3, REA8DA0:6-9:0.66:2, REA8DD0:8-6:0.64:1, REA8E00:7-8:0.66:9, REA8E30:7-3:0.52:3, REA8E60:3-7:0.89:2, REA8E90:11-7:0.57:9, REA8EC0:7-11:0.95:6, REA8EF0:9-4:0.96:3, REA8F20:11-3:0.79:3, REA8F50:5-11:0.55:9, REA8F80:9-2:0.99:10, REA8FB0:11-7:0.86:9, REA8FE0:7-11:0.6:8, REA9010:0-10:1.0:8, REA9040:7-4:0.76:10, REA9070:3-6:0.82:2, REA90A0:1-10:0.64:10, REA90D0:9-0:0.99:10, REA9100:1-11:0.93:6, REA9130:3-9:0.9:10, REA9160:4-7:0.85:7, REA9190:10-7:0.85:2, REA91C0:3-2:0.73:8, REA91F0:9-2:0.7:6, REA9220:5-6:0.74:7, REA9250:11-5:0.76:9, REA9280:1-10:0.77:8, REA92B0:4-3:0.6:1, REA92E0:3-5:0.73:9, REA9310:4-6:0.92:6, REA9340:5-6:0.6:5, REA9370:7-3:0.9:1, REA93A0:4-3:0.71:6, REA93D0:7-5:0.84:8, REA9400:1-6:0.55:4, REA9430:9-10:0.9:3, REA9460:3-2:0.57:1, REA9490:9-0:0.94:5, REA94C0:5-8:0.62:1, REA94F0:6-11:0.73:1, REA9520:1-11:0.69:1, REA9550:1-11:0.81:8, REA9580:0-5:0.97:2, REA95B0:11-1:0.83:1, REA95E0:8-9:0.64:4, REA9610:2-9:0.81:5, REA9640:6-11:0.88:4, REA9670:0-10:0.79:3, REA96A0:6-8:0.63:5, REA96D0:5-9:0.54:5, REA9700:10-5:0.84:4, REA9730:9-1:0.58:10, REA9760:5-1:0.72:3, REA9790:3-8:0.78:7, REA97C0:4-2:0.59:5, REA97F0:2-8:0.76:5, REA9820:8-3:0.51:8, REA9850:0-7:0.68:1, REA9880:8-11:0.79:7, REA98B0:2-3:0.72:6, REA98E0:4-7:0.98:7, REA9910:0-2:0.73:10, REA9940:6-2:0.78:8, REA9970:11-7:0.87:10, REA99A0:0-2:0.69:8, REA99D0:9-8:0.67:8, REA9A00:4-9:0.89:6, REA9A30:4-10:0.85:4, REA9A60:10-7:0.79:9, REA9A90:9-6:0.71:3, REA9AC0:9-5:0.93:4, REA9AF0:9-3:0.59:8, REA9B20:10-11:0.78:7, REA9B50:4-9:0.86:6, REA9B80:9-8:0.63:5, REA9BB0:2-6:0.77:4, REA9BE0:7-1:0.7:8, REA9C10:11-10:0.93:9, REA9C40:6-11:0.78:10, REA9C70:10-0:0.82:7, REA9CA0:4-0:0.91:4, REA9CD0:10-0:0.5:3, REA9D00:8-11:0.94:1, REA9D30:0-1:0.58:9, REA9D60:7-0:0.7:9]
# [Time 0] Processando requisição R754860:4-7:0.66:8...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 3] Adicionando regra no Host 4
# Decisão aplicada: (Normal E2E,)
# +----------------------+--------------+-----------+
# | Match                | Route        | Rule      |
# +======================+==============+===========+
# | (7, (0.56, 0.76), 8) | [4, 5, 6, 7] | BasicRule |
# +----------------------+--------------+-----------+
# [Time 3] Atendendo requisição R754860:4-7:0.66:8 no Host 4.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(4-5-6)
# Running Swap(4-5-6)
# [Time 3] Request R754860:4-7:0.66:8: Start Time = 0, End Time = 3
# [Time 3] Processando requisição REA8B00:2-0:0.57:3...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 6] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.47, 0.6699999999999999), 3) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 6] Atendendo requisição REA8B00:2-0:0.57:3 no Host 2.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# [Time 6] Request REA8B00:2-0:0.57:3: Start Time = 3, End Time = 6
# [Time 6] Processando requisição REA8B30:2-1:0.73:2...
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.47, 0.6699999999999999), 3) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 9] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.47, 0.6699999999999999), 3) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# | (1, (0.63, 0.83), 2)               | [2, 1]    | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 9] Atendendo requisição REA8B30:2-1:0.73:2 no Host 2.
# [BasicRule] Passo: 1
# [Time 9] Request REA8B30:2-1:0.73:2: Start Time = 6, End Time = 9
# [Time 9] Processando requisição REA8B60:5-2:0.85:5...
# [Time 10] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 12] Adicionando regra no Host 5
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.75, 0.95), 5) | [5, 1, 2] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 12] Atendendo requisição REA8B60:5-2:0.85:5 no Host 5.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(5-1-2)
# Running Swap(5-1-2)
# [Time 12] Request REA8B60:5-2:0.85:5: Start Time = 9, End Time = 12
# [Time 12] Processando requisição REA8B90:9-2:0.64:5...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 15] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 15] Atendendo requisição REA8B90:9-2:0.64:5 no Host 9.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(9-5-2)
# Running Swap(9-5-2)
# [Time 15] Request REA8B90:9-2:0.64:5: Start Time = 12, End Time = 15
# [Time 15] Processando requisição REA8BC0:9-6:0.87:6...
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 18] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule |
# +----------------------+-----------+-----------+
# | (6, (0.77, 0.97), 6) | [9, 5, 6] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 18] Atendendo requisição REA8BC0:9-6:0.87:6 no Host 9.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(9-5-6)
# Running Swap(9-5-6)
# [Time 18] Request REA8BC0:9-6:0.87:6: Start Time = 15, End Time = 18
# [Time 18] Processando requisição REA8BF0:2-4:0.88:10...
# [Time 20] Recursos atualizados
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.47, 0.6699999999999999), 3) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# | (1, (0.63, 0.83), 2)               | [2, 1]    | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 21] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.47, 0.6699999999999999), 3) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# | (1, (0.63, 0.83), 2)               | [2, 1]    | BasicRule |
# +------------------------------------+-----------+-----------+
# | (4, (0.78, 0.98), 10)              | [2, 0, 4] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 21] Atendendo requisição REA8BF0:2-4:0.88:10 no Host 2.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(2-0-4)
# Running Swap(2-0-4)
# [Time 21] Request REA8BF0:2-4:0.88:10: Start Time = 18, End Time = 21
# [Time 21] Processando requisição REA8C20:10-5:0.58:8...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 24] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (5, (0.48, 0.6799999999999999), 8) | [10, 9, 5] | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 24] Atendendo requisição REA8C20:10-5:0.58:8 no Host 10.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(10-9-5)
# Running Swap(10-9-5)
# [Time 24] Request REA8C20:10-5:0.58:8: Start Time = 21, End Time = 24
# [Time 24] Processando requisição REA8C50:1-5:0.53:3...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 27] Adicionando regra no Host 1
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+---------+-----------+
# | Match                               | Route   | Rule      |
# +=====================================+=========+===========+
# | (5, (0.43000000000000005, 0.63), 3) | [1, 5]  | BasicRule |
# +-------------------------------------+---------+-----------+
# [Time 27] Atendendo requisição REA8C50:1-5:0.53:3 no Host 1.
# [BasicRule] Passo: 1
# [Time 27] Request REA8C50:1-5:0.53:3: Start Time = 24, End Time = 27
# [Time 27] Processando requisição REA8C80:1-0:0.91:4...
# [Time 30] Recursos atualizados
# +-------------------------------------+---------+-----------+
# | Match                               | Route   | Rule      |
# +=====================================+=========+===========+
# | (5, (0.43000000000000005, 0.63), 3) | [1, 5]  | BasicRule |
# +-------------------------------------+---------+-----------+
# [Time 30] Adicionando regra no Host 1
# Decisão aplicada: (High Fidelity,)
# +-------------------------------------+---------+-------------------+
# | Match                               | Route   | Rule              |
# +=====================================+=========+===================+
# | (5, (0.43000000000000005, 0.63), 3) | [1, 5]  | BasicRule         |
# +-------------------------------------+---------+-------------------+
# | (0, (0.81, 1.01), 4)                | [1, 0]  | HighFidelityRoule |
# +-------------------------------------+---------+-------------------+
# [Time 30] Atendendo requisição REA8C80:1-0:0.91:4 no Host 1.
# [Time 30] Request REA8C80:1-0:0.91:4: Start Time = 27, End Time = 30
# [Time 30] Processando requisição REA8CB0:10-6:0.57:9...
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (5, (0.48, 0.6799999999999999), 8) | [10, 9, 5] | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 33] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (5, (0.48, 0.6799999999999999), 8) | [10, 9, 5] | BasicRule |
# +------------------------------------+------------+-----------+
# | (6, (0.47, 0.6699999999999999), 9) | [10, 6]    | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 33] Atendendo requisição REA8CB0:10-6:0.57:9 no Host 10.
# [BasicRule] Passo: 1
# [Time 33] Request REA8CB0:10-6:0.57:9: Start Time = 30, End Time = 33
# [Time 33] Processando requisição REA8CE0:6-11:0.86:9...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 36] Adicionando regra no Host 6
# Decisão aplicada: (Normal E2E,)
# +-----------------------+------------+-----------+
# | Match                 | Route      | Rule      |
# +=======================+============+===========+
# | (11, (0.76, 0.96), 9) | [6, 7, 11] | BasicRule |
# +-----------------------+------------+-----------+
# [Time 36] Atendendo requisição REA8CE0:6-11:0.86:9 no Host 6.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(6-7-11)
# Running Swap(6-7-11)
# [Time 36] Request REA8CE0:6-11:0.86:9: Start Time = 33, End Time = 36
# [Time 36] Processando requisição REA8D10:0-9:0.65:10...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 39] Adicionando regra no Host 0
# Decisão aplicada: (Normal E2E,)
# +-----------------------+--------------+-----------+
# | Match                 | Route        | Rule      |
# +=======================+==============+===========+
# | (9, (0.55, 0.75), 10) | [0, 4, 8, 9] | BasicRule |
# +-----------------------+--------------+-----------+
# [Time 39] Atendendo requisição REA8D10:0-9:0.65:10 no Host 0.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(0-4-8)
# Running Swap(0-4-8)
# [Time 39] Request REA8D10:0-9:0.65:10: Start Time = 36, End Time = 39
# [Time 39] Processando requisição REA8D40:9-5:0.63:2...
# [Time 40] Recursos atualizados
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule |
# +----------------------+-----------+-----------+
# | (6, (0.77, 0.97), 6) | [9, 5, 6] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 42] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule |
# +----------------------+-----------+-----------+
# | (6, (0.77, 0.97), 6) | [9, 5, 6] | BasicRule |
# +----------------------+-----------+-----------+
# | (5, (0.53, 0.73), 2) | [9, 5]    | BasicRule |
# +----------------------+-----------+-----------+
# [Time 42] Atendendo requisição REA8D40:9-5:0.63:2 no Host 9.
# [BasicRule] Passo: 1
# [Time 42] Request REA8D40:9-5:0.63:2: Start Time = 39, End Time = 42
# [Time 42] Processando requisição REA8D70:10-3:0.52:3...
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (5, (0.48, 0.6799999999999999), 8) | [10, 9, 5] | BasicRule |
# +------------------------------------+------------+-----------+
# | (6, (0.47, 0.6699999999999999), 9) | [10, 6]    | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 45] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+---------------+-----------+
# | Match                               | Route         | Rule      |
# +=====================================+===============+===========+
# | (5, (0.48, 0.6799999999999999), 8)  | [10, 9, 5]    | BasicRule |
# +-------------------------------------+---------------+-----------+
# | (6, (0.47, 0.6699999999999999), 9)  | [10, 6]       | BasicRule |
# +-------------------------------------+---------------+-----------+
# | (3, (0.42000000000000004, 0.62), 3) | [10, 6, 2, 3] | BasicRule |
# +-------------------------------------+---------------+-----------+
# [Time 45] Atendendo requisição REA8D70:10-3:0.52:3 no Host 10.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(10-6-2)
# Running Swap(10-6-2)
# [Time 45] Request REA8D70:10-3:0.52:3: Start Time = 42, End Time = 45
# [Time 45] Processando requisição REA8DA0:6-9:0.66:2...
# +-----------------------+------------+-----------+
# | Match                 | Route      | Rule      |
# +=======================+============+===========+
# | (11, (0.76, 0.96), 9) | [6, 7, 11] | BasicRule |
# +-----------------------+------------+-----------+
# [Time 48] Adicionando regra no Host 6
# Decisão aplicada: (Normal E2E,)
# +-----------------------+------------+-----------+
# | Match                 | Route      | Rule      |
# +=======================+============+===========+
# | (11, (0.76, 0.96), 9) | [6, 7, 11] | BasicRule |
# +-----------------------+------------+-----------+
# | (9, (0.56, 0.76), 2)  | [6, 9]     | BasicRule |
# +-----------------------+------------+-----------+
# [Time 48] Atendendo requisição REA8DA0:6-9:0.66:2 no Host 6.
# [BasicRule] Passo: 1
# [Time 48] Request REA8DA0:6-9:0.66:2: Start Time = 45, End Time = 48
# [Time 48] Processando requisição REA8DD0:8-6:0.64:1...
# [Time 50] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 51] Adicionando regra no Host 8
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (6, (0.54, 0.74), 1) | [8, 4, 6] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 51] Atendendo requisição REA8DD0:8-6:0.64:1 no Host 8.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(8-4-6)
# Running Swap(8-4-6)
# [Time 51] Request REA8DD0:8-6:0.64:1: Start Time = 48, End Time = 51
# [Time 51] Processando requisição REA8E00:7-8:0.66:9...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 54] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (8, (0.56, 0.76), 9) | [7, 6, 8] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 54] Atendendo requisição REA8E00:7-8:0.66:9 no Host 7.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(7-6-8)
# Running Swap(7-6-8)
# [Time 54] Request REA8E00:7-8:0.66:9: Start Time = 51, End Time = 54
# [Time 54] Processando requisição REA8E30:7-3:0.52:3...
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (8, (0.56, 0.76), 9) | [7, 6, 8] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 57] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+-----------+-----------+
# | Match                               | Route     | Rule      |
# +=====================================+===========+===========+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule |
# +-------------------------------------+-----------+-----------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule |
# +-------------------------------------+-----------+-----------+
# [Time 57] Atendendo requisição REA8E30:7-3:0.52:3 no Host 7.
# [BasicRule] Passo: 1
# [Time 57] Request REA8E30:7-3:0.52:3: Start Time = 54, End Time = 57
# [Time 57] Processando requisição REA8E60:3-7:0.89:2...
# [Time 60] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 60] Adicionando regra no Host 3
# Decisão aplicada: (Normal E2E,)
# +----------------------+---------+-----------+
# | Match                | Route   | Rule      |
# +======================+=========+===========+
# | (7, (0.79, 0.99), 2) | [3, 7]  | BasicRule |
# +----------------------+---------+-----------+
# [Time 60] Atendendo requisição REA8E60:3-7:0.89:2 no Host 3.
# [BasicRule] Passo: 1
# [Time 60] Request REA8E60:3-7:0.89:2: Start Time = 57, End Time = 60
# [Time 60] Processando requisição REA8E90:11-7:0.57:9...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 63] Adicionando regra no Host 11
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+---------+-----------+
# | Match                              | Route   | Rule      |
# +====================================+=========+===========+
# | (7, (0.47, 0.6699999999999999), 9) | [11, 7] | BasicRule |
# +------------------------------------+---------+-----------+
# [Time 63] Atendendo requisição REA8E90:11-7:0.57:9 no Host 11.
# [BasicRule] Passo: 1
# [Time 63] Request REA8E90:11-7:0.57:9: Start Time = 60, End Time = 63
# [Time 63] Processando requisição REA8EC0:7-11:0.95:6...
# +-------------------------------------+-----------+-----------+
# | Match                               | Route     | Rule      |
# +=====================================+===========+===========+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule |
# +-------------------------------------+-----------+-----------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule |
# +-------------------------------------+-----------+-----------+
# [Time 66] Adicionando regra no Host 7
# Decisão aplicada: (High Fidelity,)
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.85, 1.05), 6)               | [7, 11]   | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# [Time 66] Atendendo requisição REA8EC0:7-11:0.95:6 no Host 7.
# [Time 66] Request REA8EC0:7-11:0.95:6: Start Time = 63, End Time = 66
# [Time 66] Processando requisição REA8EF0:9-4:0.96:3...
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule |
# +----------------------+-----------+-----------+
# | (6, (0.77, 0.97), 6) | [9, 5, 6] | BasicRule |
# +----------------------+-----------+-----------+
# | (5, (0.53, 0.73), 2) | [9, 5]    | BasicRule |
# +----------------------+-----------+-----------+
# [Time 69] Adicionando regra no Host 9
# Decisão aplicada: (High Fidelity,)
# +----------------------+-----------+-------------------+
# | Match                | Route     | Rule              |
# +======================+===========+===================+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule         |
# +----------------------+-----------+-------------------+
# | (6, (0.77, 0.97), 6) | [9, 5, 6] | BasicRule         |
# +----------------------+-----------+-------------------+
# | (5, (0.53, 0.73), 2) | [9, 5]    | BasicRule         |
# +----------------------+-----------+-------------------+
# | (4, (0.86, 1.06), 3) | [9, 8, 4] | HighFidelityRoule |
# +----------------------+-----------+-------------------+
# [Time 69] Atendendo requisição REA8EF0:9-4:0.96:3 no Host 9.
# [Time 69] Request REA8EF0:9-4:0.96:3: Start Time = 66, End Time = 69
# [Time 69] Processando requisição REA8F20:11-3:0.79:3...
# [Time 70] Recursos atualizados
# +------------------------------------+---------+-----------+
# | Match                              | Route   | Rule      |
# +====================================+=========+===========+
# | (7, (0.47, 0.6699999999999999), 9) | [11, 7] | BasicRule |
# +------------------------------------+---------+-----------+
# [Time 72] Adicionando regra no Host 11
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (7, (0.47, 0.6699999999999999), 9) | [11, 7]    | BasicRule |
# +------------------------------------+------------+-----------+
# | (3, (0.6900000000000001, 0.89), 3) | [11, 7, 3] | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 72] Atendendo requisição REA8F20:11-3:0.79:3 no Host 11.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(11-7-3)
# Running Swap(11-7-3)
# [Time 72] Request REA8F20:11-3:0.79:3: Start Time = 69, End Time = 72
# [Time 72] Processando requisição REA8F50:5-11:0.55:9...
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.75, 0.95), 5) | [5, 1, 2] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 75] Adicionando regra no Host 5
# Decisão aplicada: (Normal E2E,)
# +--------------------------------------+-------------+-----------+
# | Match                                | Route       | Rule      |
# +======================================+=============+===========+
# | (2, (0.75, 0.95), 5)                 | [5, 1, 2]   | BasicRule |
# +--------------------------------------+-------------+-----------+
# | (11, (0.45000000000000007, 0.65), 9) | [5, 10, 11] | BasicRule |
# +--------------------------------------+-------------+-----------+
# [Time 75] Atendendo requisição REA8F50:5-11:0.55:9 no Host 5.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(5-10-11)
# Running Swap(5-10-11)
# [Time 75] Request REA8F50:5-11:0.55:9: Start Time = 72, End Time = 75
# [Time 75] Processando requisição REA8F80:9-2:0.99:10...
# [BasicRule] Regra fechada e removida do Host 4.
# +----------------------+-----------+-------------------+
# | Match                | Route     | Rule              |
# +======================+===========+===================+
# | (2, (0.54, 0.74), 5) | [9, 5, 2] | BasicRule         |
# +----------------------+-----------+-------------------+
# | (6, (0.77, 0.97), 6) | [9, 5, 6] | BasicRule         |
# +----------------------+-----------+-------------------+
# | (5, (0.53, 0.73), 2) | [9, 5]    | BasicRule         |
# +----------------------+-----------+-------------------+
# | (4, (0.86, 1.06), 3) | [9, 8, 4] | HighFidelityRoule |
# +----------------------+-----------+-------------------+
# [Time 78] Adicionando regra no Host 9
# Decisão aplicada: (High Fidelity,)
# +-----------------------+-----------+-------------------+
# | Match                 | Route     | Rule              |
# +=======================+===========+===================+
# | (2, (0.54, 0.74), 5)  | [9, 5, 2] | BasicRule         |
# +-----------------------+-----------+-------------------+
# | (6, (0.77, 0.97), 6)  | [9, 5, 6] | BasicRule         |
# +-----------------------+-----------+-------------------+
# | (5, (0.53, 0.73), 2)  | [9, 5]    | BasicRule         |
# +-----------------------+-----------+-------------------+
# | (4, (0.86, 1.06), 3)  | [9, 8, 4] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# | (2, (0.89, 1.09), 10) | [9, 6, 2] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# [Time 78] Atendendo requisição REA8F80:9-2:0.99:10 no Host 9.
# [Time 78] Request REA8F80:9-2:0.99:10: Start Time = 75, End Time = 78
# [Time 78] Processando requisição REA8FB0:11-7:0.86:9...
# [Time 80] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 2.
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (7, (0.47, 0.6699999999999999), 9) | [11, 7]    | BasicRule |
# +------------------------------------+------------+-----------+
# | (3, (0.6900000000000001, 0.89), 3) | [11, 7, 3] | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 81] Adicionando regra no Host 11
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (7, (0.47, 0.6699999999999999), 9) | [11, 7]    | BasicRule |
# +------------------------------------+------------+-----------+
# | (3, (0.6900000000000001, 0.89), 3) | [11, 7, 3] | BasicRule |
# +------------------------------------+------------+-----------+
# | (7, (0.76, 0.96), 9)               | [11, 7]    | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 81] Atendendo requisição REA8FB0:11-7:0.86:9 no Host 11.
# [BasicRule] Passo: 1
# [Time 81] Request REA8FB0:11-7:0.86:9: Start Time = 78, End Time = 81
# [Time 81] Processando requisição REA8FE0:7-11:0.6:8...
# [BasicRule] Regra fechada e removida do Host 2.
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.85, 1.05), 6)               | [7, 11]   | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# [Time 84] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.85, 1.05), 6)               | [7, 11]   | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.5, 0.7), 8)                 | [7, 11]   | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# [Time 84] Atendendo requisição REA8FE0:7-11:0.6:8 no Host 7.
# [BasicRule] Passo: 1
# [Time 84] Request REA8FE0:7-11:0.6:8: Start Time = 81, End Time = 84
# [Time 84] Processando requisição REA9010:0-10:1.0:8...
# [BasicRule] Regra fechada e removida do Host 5.
# +-----------------------+--------------+-----------+
# | Match                 | Route        | Rule      |
# +=======================+==============+===========+
# | (9, (0.55, 0.75), 10) | [0, 4, 8, 9] | BasicRule |
# +-----------------------+--------------+-----------+
# [Time 87] Adicionando regra no Host 0
# Decisão aplicada: (High Fidelity,)
# +-----------------------+--------------+-------------------+
# | Match                 | Route        | Rule              |
# +=======================+==============+===================+
# | (9, (0.55, 0.75), 10) | [0, 4, 8, 9] | BasicRule         |
# +-----------------------+--------------+-------------------+
# | (10, (0.9, 1.1), 8)   | [0, 2, 10]   | HighFidelityRoule |
# +-----------------------+--------------+-------------------+
# [Time 87] Atendendo requisição REA9010:0-10:1.0:8 no Host 0.
# [Time 87] Request REA9010:0-10:1.0:8: Start Time = 84, End Time = 87
# [Time 87] Processando requisição REA9040:7-4:0.76:10...
# [BasicRule] Regra fechada e removida do Host 9.
# [Time 90] Recursos atualizados
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.85, 1.05), 6)               | [7, 11]   | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.5, 0.7), 8)                 | [7, 11]   | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# [Time 90] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (8, (0.56, 0.76), 9)                | [7, 6, 8] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (3, (0.42000000000000004, 0.62), 3) | [7, 3]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.85, 1.05), 6)               | [7, 11]   | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# | (11, (0.5, 0.7), 8)                 | [7, 11]   | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (4, (0.66, 0.86), 10)               | [7, 6, 4] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# [Time 90] Atendendo requisição REA9040:7-4:0.76:10 no Host 7.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(7-6-4)
# Running Swap(7-6-4)
# [Time 90] Request REA9040:7-4:0.76:10: Start Time = 87, End Time = 90
# [Time 90] Processando requisição REA9070:3-6:0.82:2...
# [BasicRule] Regra fechada e removida do Host 9.
# +----------------------+---------+-----------+
# | Match                | Route   | Rule      |
# +======================+=========+===========+
# | (7, (0.79, 0.99), 2) | [3, 7]  | BasicRule |
# +----------------------+---------+-----------+
# [Time 93] Adicionando regra no Host 3
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (7, (0.79, 0.99), 2)               | [3, 7]    | BasicRule |
# +------------------------------------+-----------+-----------+
# | (6, (0.72, 0.9199999999999999), 2) | [3, 2, 6] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 93] Atendendo requisição REA9070:3-6:0.82:2 no Host 3.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(3-2-6)
# Running Swap(3-2-6)
# [Time 93] Request REA9070:3-6:0.82:2: Start Time = 90, End Time = 93
# [Time 93] Processando requisição REA90A0:1-10:0.64:10...
# [BasicRule] Regra fechada e removida do Host 2.
# +-------------------------------------+---------+-------------------+
# | Match                               | Route   | Rule              |
# +=====================================+=========+===================+
# | (5, (0.43000000000000005, 0.63), 3) | [1, 5]  | BasicRule         |
# +-------------------------------------+---------+-------------------+
# | (0, (0.81, 1.01), 4)                | [1, 0]  | HighFidelityRoule |
# +-------------------------------------+---------+-------------------+
# [Time 96] Adicionando regra no Host 1
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+------------+-------------------+
# | Match                               | Route      | Rule              |
# +=====================================+============+===================+
# | (5, (0.43000000000000005, 0.63), 3) | [1, 5]     | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (0, (0.81, 1.01), 4)                | [1, 0]     | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# | (10, (0.54, 0.74), 10)              | [1, 5, 10] | BasicRule         |
# +-------------------------------------+------------+-------------------+
# [Time 96] Atendendo requisição REA90A0:1-10:0.64:10 no Host 1.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(1-5-10)
# Running Swap(1-5-10)
# [Time 96] Request REA90A0:1-10:0.64:10: Start Time = 93, End Time = 96
# [Time 96] Processando requisição REA90D0:9-0:0.99:10...
# [BasicRule] Regra fechada e removida do Host 10.
# +-----------------------+-----------+-------------------+
# | Match                 | Route     | Rule              |
# +=======================+===========+===================+
# | (5, (0.53, 0.73), 2)  | [9, 5]    | BasicRule         |
# +-----------------------+-----------+-------------------+
# | (4, (0.86, 1.06), 3)  | [9, 8, 4] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# | (2, (0.89, 1.09), 10) | [9, 6, 2] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# [Time 99] Adicionando regra no Host 9
# Decisão aplicada: (High Fidelity,)
# +-----------------------+-----------+-------------------+
# | Match                 | Route     | Rule              |
# +=======================+===========+===================+
# | (5, (0.53, 0.73), 2)  | [9, 5]    | BasicRule         |
# +-----------------------+-----------+-------------------+
# | (4, (0.86, 1.06), 3)  | [9, 8, 4] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# | (2, (0.89, 1.09), 10) | [9, 6, 2] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# | (0, (0.89, 1.09), 10) | [9, 8, 0] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# [Time 99] Atendendo requisição REA90D0:9-0:0.99:10 no Host 9.
# [Time 99] Request REA90D0:9-0:0.99:10: Start Time = 96, End Time = 99
# [Time 99] Processando requisição REA9100:1-11:0.93:6...
# [Time 100] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 1.
# +------------------------+------------+-------------------+
# | Match                  | Route      | Rule              |
# +========================+============+===================+
# | (0, (0.81, 1.01), 4)   | [1, 0]     | HighFidelityRoule |
# +------------------------+------------+-------------------+
# | (10, (0.54, 0.74), 10) | [1, 5, 10] | BasicRule         |
# +------------------------+------------+-------------------+
# [Time 102] Adicionando regra no Host 1
# Decisão aplicada: (High Fidelity,)
# +-------------------------------------+-------------+-------------------+
# | Match                               | Route       | Rule              |
# +=====================================+=============+===================+
# | (0, (0.81, 1.01), 4)                | [1, 0]      | HighFidelityRoule |
# +-------------------------------------+-------------+-------------------+
# | (10, (0.54, 0.74), 10)              | [1, 5, 10]  | BasicRule         |
# +-------------------------------------+-------------+-------------------+
# | (11, (0.8300000000000001, 1.03), 6) | [1, 10, 11] | HighFidelityRoule |
# +-------------------------------------+-------------+-------------------+
# [Time 102] Atendendo requisição REA9100:1-11:0.93:6 no Host 1.
# [Time 102] Request REA9100:1-11:0.93:6: Start Time = 99, End Time = 102
# [Time 102] Processando requisição REA9130:3-9:0.9:10...
# [HighFidelityRoule] Regra fechada e removida do Host 1.
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (7, (0.79, 0.99), 2)               | [3, 7]    | BasicRule |
# +------------------------------------+-----------+-----------+
# | (6, (0.72, 0.9199999999999999), 2) | [3, 2, 6] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 105] Adicionando regra no Host 3
# Decisão aplicada: (High Fidelity,)
# +------------------------------------+-----------+-------------------+
# | Match                              | Route     | Rule              |
# +====================================+===========+===================+
# | (7, (0.79, 0.99), 2)               | [3, 7]    | BasicRule         |
# +------------------------------------+-----------+-------------------+
# | (6, (0.72, 0.9199999999999999), 2) | [3, 2, 6] | BasicRule         |
# +------------------------------------+-----------+-------------------+
# | (9, (0.8, 1.0), 10)                | [3, 6, 9] | HighFidelityRoule |
# +------------------------------------+-----------+-------------------+
# [Time 105] Atendendo requisição REA9130:3-9:0.9:10 no Host 3.
# [Time 105] Request REA9130:3-9:0.9:10: Start Time = 102, End Time = 105
# [Time 105] Processando requisição REA9160:4-7:0.85:7...
# [BasicRule] Regra fechada e removida do Host 10.
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 108] Adicionando regra no Host 4
# Decisão aplicada: (Normal E2E,)
# +----------------------+---------+-----------+
# | Match                | Route   | Rule      |
# +======================+=========+===========+
# | (7, (0.75, 0.95), 7) | [4, 7]  | BasicRule |
# +----------------------+---------+-----------+
# [Time 108] Atendendo requisição REA9160:4-7:0.85:7 no Host 4.
# [BasicRule] Passo: 1
# [Time 108] Request REA9160:4-7:0.85:7: Start Time = 105, End Time = 108
# [Time 108] Processando requisição REA9190:10-7:0.85:2...
# [Time 110] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 6.
# +-------------------------------------+---------------+-----------+
# | Match                               | Route         | Rule      |
# +=====================================+===============+===========+
# | (3, (0.42000000000000004, 0.62), 3) | [10, 6, 2, 3] | BasicRule |
# +-------------------------------------+---------------+-----------+
# [Time 111] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+---------------+-----------+
# | Match                               | Route         | Rule      |
# +=====================================+===============+===========+
# | (3, (0.42000000000000004, 0.62), 3) | [10, 6, 2, 3] | BasicRule |
# +-------------------------------------+---------------+-----------+
# | (7, (0.75, 0.95), 2)                | [10, 6, 7]    | BasicRule |
# +-------------------------------------+---------------+-----------+
# [Time 111] Atendendo requisição REA9190:10-7:0.85:2 no Host 10.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(10-6-7)
# Running Swap(10-6-7)
# [Time 111] Request REA9190:10-7:0.85:2: Start Time = 108, End Time = 111
# [Time 111] Processando requisição REA91C0:3-2:0.73:8...
# [BasicRule] Regra fechada e removida do Host 0.
# +------------------------------------+-----------+-------------------+
# | Match                              | Route     | Rule              |
# +====================================+===========+===================+
# | (7, (0.79, 0.99), 2)               | [3, 7]    | BasicRule         |
# +------------------------------------+-----------+-------------------+
# | (6, (0.72, 0.9199999999999999), 2) | [3, 2, 6] | BasicRule         |
# +------------------------------------+-----------+-------------------+
# | (9, (0.8, 1.0), 10)                | [3, 6, 9] | HighFidelityRoule |
# +------------------------------------+-----------+-------------------+
# [Time 114] Adicionando regra no Host 3
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-------------------+
# | Match                              | Route     | Rule              |
# +====================================+===========+===================+
# | (7, (0.79, 0.99), 2)               | [3, 7]    | BasicRule         |
# +------------------------------------+-----------+-------------------+
# | (6, (0.72, 0.9199999999999999), 2) | [3, 2, 6] | BasicRule         |
# +------------------------------------+-----------+-------------------+
# | (9, (0.8, 1.0), 10)                | [3, 6, 9] | HighFidelityRoule |
# +------------------------------------+-----------+-------------------+
# | (2, (0.63, 0.83), 8)               | [3, 2]    | BasicRule         |
# +------------------------------------+-----------+-------------------+
# [Time 114] Atendendo requisição REA91C0:3-2:0.73:8 no Host 3.
# [BasicRule] Passo: 1
# [Time 114] Request REA91C0:3-2:0.73:8: Start Time = 111, End Time = 114
# [Time 114] Processando requisição REA91F0:9-2:0.7:6...
# [BasicRule] Regra fechada e removida do Host 9.
# +-----------------------+-----------+-------------------+
# | Match                 | Route     | Rule              |
# +=======================+===========+===================+
# | (4, (0.86, 1.06), 3)  | [9, 8, 4] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# | (2, (0.89, 1.09), 10) | [9, 6, 2] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# | (0, (0.89, 1.09), 10) | [9, 8, 0] | HighFidelityRoule |
# +-----------------------+-----------+-------------------+
# [Time 117] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +-----------------------------------+-----------+-------------------+
# | Match                             | Route     | Rule              |
# +===================================+===========+===================+
# | (4, (0.86, 1.06), 3)              | [9, 8, 4] | HighFidelityRoule |
# +-----------------------------------+-----------+-------------------+
# | (2, (0.89, 1.09), 10)             | [9, 6, 2] | HighFidelityRoule |
# +-----------------------------------+-----------+-------------------+
# | (0, (0.89, 1.09), 10)             | [9, 8, 0] | HighFidelityRoule |
# +-----------------------------------+-----------+-------------------+
# | (2, (0.6, 0.7999999999999999), 6) | [9, 6, 2] | BasicRule         |
# +-----------------------------------+-----------+-------------------+
# [Time 117] Atendendo requisição REA91F0:9-2:0.7:6 no Host 9.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(9-6-2)
# Running Swap(9-6-2)
# [Time 117] Request REA91F0:9-2:0.7:6: Start Time = 114, End Time = 117
# [Time 117] Processando requisição REA9220:5-6:0.74:7...
# [BasicRule] Regra fechada e removida do Host 10.
# [Time 120] Recursos atualizados
# +--------------------------------------+-------------+-----------+
# | Match                                | Route       | Rule      |
# +======================================+=============+===========+
# | (11, (0.45000000000000007, 0.65), 9) | [5, 10, 11] | BasicRule |
# +--------------------------------------+-------------+-----------+
# [Time 120] Adicionando regra no Host 5
# Decisão aplicada: (Normal E2E,)
# +--------------------------------------+-------------+-----------+
# | Match                                | Route       | Rule      |
# +======================================+=============+===========+
# | (11, (0.45000000000000007, 0.65), 9) | [5, 10, 11] | BasicRule |
# +--------------------------------------+-------------+-----------+
# | (6, (0.64, 0.84), 7)                 | [5, 6]      | BasicRule |
# +--------------------------------------+-------------+-----------+
# [Time 120] Atendendo requisição REA9220:5-6:0.74:7 no Host 5.
# [BasicRule] Passo: 1
# [Time 120] Request REA9220:5-6:0.74:7: Start Time = 117, End Time = 120
# [Time 120] Processando requisição REA9250:11-5:0.76:9...
# [BasicRule] Regra fechada e removida do Host 6.
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (7, (0.47, 0.6699999999999999), 9) | [11, 7]    | BasicRule |
# +------------------------------------+------------+-----------+
# | (3, (0.6900000000000001, 0.89), 3) | [11, 7, 3] | BasicRule |
# +------------------------------------+------------+-----------+
# | (7, (0.76, 0.96), 9)               | [11, 7]    | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 123] Adicionando regra no Host 11
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# ...
# +-------------------------------------+-----------+-------------------+
# | (5, (0.8300000000000001, 1.03), 4)  | [9, 5]    | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# [Time 257] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (1, (0.48, 0.6799999999999999), 10) | [9, 5, 1] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (8, (0.5700000000000001, 0.77), 8)  | [9, 8]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (6, (0.61, 0.8099999999999999), 3)  | [9, 6]    | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# | (5, (0.8300000000000001, 1.03), 4)  | [9, 5]    | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# | (3, (0.49, 0.69), 8)                | [9, 2, 3] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# [Time 257] Atendendo requisição REA9AF0:9-3:0.59:8 no Host 9.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(9-2-3)
# Running Swap(9-2-3)
# [Time 257] Request REA9AF0:9-3:0.59:8: Start Time = 254, End Time = 257
# [Time 257] Processando requisição REA9B20:10-11:0.78:7...
# [BasicRule] Regra fechada e removida do Host 6.
# [Time 260] Recursos atualizados
# +------------------------------------+---------+-----------+
# | Match                              | Route   | Rule      |
# +====================================+=========+===========+
# | (5, (0.74, 0.94), 4)               | [10, 5] | BasicRule |
# +------------------------------------+---------+-----------+
# | (7, (0.6900000000000001, 0.89), 9) | [10, 7] | BasicRule |
# +------------------------------------+---------+-----------+
# [Time 260] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+----------+-----------+
# | Match                              | Route    | Rule      |
# +====================================+==========+===========+
# | (5, (0.74, 0.94), 4)               | [10, 5]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (7, (0.6900000000000001, 0.89), 9) | [10, 7]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (11, (0.68, 0.88), 7)              | [10, 11] | BasicRule |
# +------------------------------------+----------+-----------+
# [Time 260] Atendendo requisição REA9B20:10-11:0.78:7 no Host 10.
# [BasicRule] Passo: 1
# [Time 260] Request REA9B20:10-11:0.78:7: Start Time = 257, End Time = 260
# [Time 260] Processando requisição REA9B50:4-9:0.86:6...
# [Time 260] Regra existente para REA9B50:4-9:0.86:6 no Host 4.
# [Time 261] Atendendo requisição REA9B50:4-9:0.86:6 no Host 4.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(4-5-9)
# Running Swap(4-5-9)
# [Time 261] Request REA9B50:4-9:0.86:6: Start Time = 260, End Time = 261
# [Time 261] Processando requisição REA9B80:9-8:0.63:5...
# [Time 261] Regra existente para REA9B80:9-8:0.63:5 no Host 9.
# [BasicRule] Regra fechada e removida do Host 0.
# [Time 262] Atendendo requisição REA9B80:9-8:0.63:5 no Host 9.
# [BasicRule] Passo: 1
# [Time 262] Request REA9B80:9-8:0.63:5: Start Time = 261, End Time = 262
# [Time 262] Processando requisição REA9BB0:2-6:0.77:4...
# [BasicRule] Regra fechada e removida do Host 6.
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (8, (0.66, 0.86), 5) | [2, 4, 8] | BasicRule |
# +----------------------+-----------+-----------+
# | (3, (0.62, 0.82), 6) | [2, 3]    | BasicRule |
# +----------------------+-----------+-----------+
# [Time 265] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (8, (0.66, 0.86), 5) | [2, 4, 8] | BasicRule |
# +----------------------+-----------+-----------+
# | (3, (0.62, 0.82), 6) | [2, 3]    | BasicRule |
# +----------------------+-----------+-----------+
# | (6, (0.67, 0.87), 4) | [2, 6]    | BasicRule |
# +----------------------+-----------+-----------+
# [Time 265] Atendendo requisição REA9BB0:2-6:0.77:4 no Host 2.
# [BasicRule] Passo: 1
# [Time 265] Request REA9BB0:2-6:0.77:4: Start Time = 262, End Time = 265
# [Time 265] Processando requisição REA9BE0:7-1:0.7:8...
# [BasicRule] Regra fechada e removida do Host 5.
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 268] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-----------------------------------+-----------+-----------+
# | Match                             | Route     | Rule      |
# +===================================+===========+===========+
# | (1, (0.6, 0.7999999999999999), 8) | [7, 0, 1] | BasicRule |
# +-----------------------------------+-----------+-----------+
# [Time 268] Atendendo requisição REA9BE0:7-1:0.7:8 no Host 7.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(7-0-1)
# Running Swap(7-0-1)
# [Time 268] Request REA9BE0:7-1:0.7:8: Start Time = 265, End Time = 268
# [Time 268] Processando requisição REA9C10:11-10:0.93:9...
# [Time 270] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 10.
# +-----------------------+---------+-----------+
# | Match                 | Route   | Rule      |
# +=======================+=========+===========+
# | (7, (0.77, 0.97), 10) | [11, 7] | BasicRule |
# +-----------------------+---------+-----------+
# [Time 271] Adicionando regra no Host 11
# Decisão aplicada: (High Fidelity,)
# +-------------------------------------+----------+-------------------+
# | Match                               | Route    | Rule              |
# +=====================================+==========+===================+
# | (7, (0.77, 0.97), 10)               | [11, 7]  | BasicRule         |
# +-------------------------------------+----------+-------------------+
# | (10, (0.8300000000000001, 1.03), 9) | [11, 10] | HighFidelityRoule |
# +-------------------------------------+----------+-------------------+
# [Time 271] Atendendo requisição REA9C10:11-10:0.93:9 no Host 11.
# [Time 271] Request REA9C10:11-10:0.93:9: Start Time = 268, End Time = 271
# [Time 271] Processando requisição REA9C40:6-11:0.78:10...
# [BasicRule] Regra fechada e removida do Host 9.
# +----------------------+---------+-----------+
# | Match                | Route   | Rule      |
# +======================+=========+===========+
# | (2, (0.68, 0.88), 8) | [6, 2]  | BasicRule |
# +----------------------+---------+-----------+
# [Time 274] Adicionando regra no Host 6
# Decisão aplicada: (Normal E2E,)
# +------------------------+---------+-----------+
# | Match                  | Route   | Rule      |
# +========================+=========+===========+
# | (2, (0.68, 0.88), 8)   | [6, 2]  | BasicRule |
# +------------------------+---------+-----------+
# | (11, (0.68, 0.88), 10) | [6, 11] | BasicRule |
# +------------------------+---------+-----------+
# [Time 274] Atendendo requisição REA9C40:6-11:0.78:10 no Host 6.
# [BasicRule] Passo: 1
# [Time 274] Request REA9C40:6-11:0.78:10: Start Time = 271, End Time = 274
# [Time 274] Processando requisição REA9C70:10-0:0.82:7...
# [BasicRule] Regra fechada e removida do Host 5.
# +------------------------------------+----------+-----------+
# | Match                              | Route    | Rule      |
# +====================================+==========+===========+
# | (7, (0.6900000000000001, 0.89), 9) | [10, 7]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (11, (0.68, 0.88), 7)              | [10, 11] | BasicRule |
# +------------------------------------+----------+-----------+
# [Time 277] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+----------+-----------+
# | Match                              | Route    | Rule      |
# +====================================+==========+===========+
# | (7, (0.6900000000000001, 0.89), 9) | [10, 7]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (11, (0.68, 0.88), 7)              | [10, 11] | BasicRule |
# +------------------------------------+----------+-----------+
# | (0, (0.72, 0.9199999999999999), 7) | [10, 0]  | BasicRule |
# +------------------------------------+----------+-----------+
# [Time 277] Atendendo requisição REA9C70:10-0:0.82:7 no Host 10.
# [BasicRule] Passo: 1
# [Time 277] Request REA9C70:10-0:0.82:7: Start Time = 274, End Time = 277
# [Time 277] Processando requisição REA9CA0:4-0:0.91:4...
# [BasicRule] Regra fechada e removida do Host 3.
# [Time 280] Recursos atualizados
# +-----------------------+------------+-------------------+
# | Match                 | Route      | Rule              |
# +=======================+============+===================+
# | (2, (0.49, 0.69), 5)  | [4, 2]     | BasicRule         |
# +-----------------------+------------+-------------------+
# | (7, (0.88, 1.08), 7)  | [4, 7]     | HighFidelityRoule |
# +-----------------------+------------+-------------------+
# | (9, (0.79, 0.99), 6)  | [4, 5, 9]  | BasicRule         |
# +-----------------------+------------+-------------------+
# | (10, (0.75, 0.95), 4) | [4, 6, 10] | BasicRule         |
# +-----------------------+------------+-------------------+
# [Time 280] Adicionando regra no Host 4
# Decisão aplicada: (High Fidelity,)
# +-----------------------+------------+-------------------+
# | Match                 | Route      | Rule              |
# +=======================+============+===================+
# | (2, (0.49, 0.69), 5)  | [4, 2]     | BasicRule         |
# +-----------------------+------------+-------------------+
# | (7, (0.88, 1.08), 7)  | [4, 7]     | HighFidelityRoule |
# +-----------------------+------------+-------------------+
# | (9, (0.79, 0.99), 6)  | [4, 5, 9]  | BasicRule         |
# +-----------------------+------------+-------------------+
# | (10, (0.75, 0.95), 4) | [4, 6, 10] | BasicRule         |
# +-----------------------+------------+-------------------+
# | (0, (0.81, 1.01), 4)  | [4, 0]     | HighFidelityRoule |
# +-----------------------+------------+-------------------+
# [Time 280] Atendendo requisição REA9CA0:4-0:0.91:4 no Host 4.
# [Time 280] Request REA9CA0:4-0:0.91:4: Start Time = 277, End Time = 280
# [Time 280] Processando requisição REA9CD0:10-0:0.5:3...
# [BasicRule] Regra fechada e removida do Host 4.
# +------------------------------------+----------+-----------+
# | Match                              | Route    | Rule      |
# +====================================+==========+===========+
# | (7, (0.6900000000000001, 0.89), 9) | [10, 7]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (11, (0.68, 0.88), 7)              | [10, 11] | BasicRule |
# +------------------------------------+----------+-----------+
# | (0, (0.72, 0.9199999999999999), 7) | [10, 0]  | BasicRule |
# +------------------------------------+----------+-----------+
# [Time 283] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+----------+-----------+
# | Match                              | Route    | Rule      |
# +====================================+==========+===========+
# | (7, (0.6900000000000001, 0.89), 9) | [10, 7]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (11, (0.68, 0.88), 7)              | [10, 11] | BasicRule |
# +------------------------------------+----------+-----------+
# | (0, (0.72, 0.9199999999999999), 7) | [10, 0]  | BasicRule |
# +------------------------------------+----------+-----------+
# | (0, (0.4, 0.6), 3)                 | [10, 0]  | BasicRule |
# +------------------------------------+----------+-----------+
# [Time 283] Atendendo requisição REA9CD0:10-0:0.5:3 no Host 10.
# [BasicRule] Passo: 1
# [Time 283] Request REA9CD0:10-0:0.5:3: Start Time = 280, End Time = 283
# [Time 283] Processando requisição REA9D00:8-11:0.94:1...
# [BasicRule] Regra fechada e removida do Host 2.
# +-------------------------------------+------------+-----------+
# | Match                               | Route      | Rule      |
# +=====================================+============+===========+
# | (3, (0.41000000000000003, 0.61), 8) | [8, 3]     | BasicRule |
# +-------------------------------------+------------+-----------+
# | (11, (0.6900000000000001, 0.89), 7) | [8, 6, 11] | BasicRule |
# +-------------------------------------+------------+-----------+
# [Time 286] Adicionando regra no Host 8
# Decisão aplicada: (High Fidelity,)
# +-------------------------------------+------------+-------------------+
# | Match                               | Route      | Rule              |
# +=====================================+============+===================+
# | (3, (0.41000000000000003, 0.61), 8) | [8, 3]     | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (11, (0.6900000000000001, 0.89), 7) | [8, 6, 11] | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (11, (0.84, 1.04), 1)               | [8, 11]    | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# [Time 286] Atendendo requisição REA9D00:8-11:0.94:1 no Host 8.
# [Time 286] Request REA9D00:8-11:0.94:1: Start Time = 283, End Time = 286
# [Time 286] Processando requisição REA9D30:0-1:0.58:9...
# [BasicRule] Regra fechada e removida do Host 8.
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (7, (0.5800000000000001, 0.78), 1) | [0, 4, 7] | BasicRule |
# +------------------------------------+-----------+-----------+
# | (2, (0.63, 0.83), 10)              | [0, 2]    | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 289] Adicionando regra no Host 0
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (7, (0.5800000000000001, 0.78), 1) | [0, 4, 7] | BasicRule |
# +------------------------------------+-----------+-----------+
# | (2, (0.63, 0.83), 10)              | [0, 2]    | BasicRule |
# +------------------------------------+-----------+-----------+
# | (1, (0.48, 0.6799999999999999), 9) | [0, 1]    | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 289] Atendendo requisição REA9D30:0-1:0.58:9 no Host 0.
# [BasicRule] Passo: 1
# [Time 289] Request REA9D30:0-1:0.58:9: Start Time = 286, End Time = 289
# [Time 289] Processando requisição REA9D60:7-0:0.7:9...
# [Time 290] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 0.
# +-----------------------------------+-----------+-----------+
# | Match                             | Route     | Rule      |
# +===================================+===========+===========+
# | (1, (0.6, 0.7999999999999999), 8) | [7, 0, 1] | BasicRule |
# +-----------------------------------+-----------+-----------+
# [Time 292] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-----------------------------------+-----------+-----------+
# | Match                             | Route     | Rule      |
# +===================================+===========+===========+
# | (1, (0.6, 0.7999999999999999), 8) | [7, 0, 1] | BasicRule |
# +-----------------------------------+-----------+-----------+
# | (0, (0.6, 0.7999999999999999), 9) | [7, 0]    | BasicRule |
# +-----------------------------------+-----------+-----------+
# [Time 292] Atendendo requisição REA9D60:7-0:0.7:9 no Host 7.
# [BasicRule] Passo: 1
# [Time 292] Request REA9D60:7-0:0.7:9: Start Time = 289, End Time = 292

# %% [markdown]
# ### <b>Preenchimento Híbrido</b>

# %%
# Parâmetros das simulações
network_info = {
    'n_initial_qubits': 10,
    'n_initial_eprs': 10,
    'topology_name': 'Grade',
    'topology_params': (3, 4),
    'time_to_refill': 10,
}
controller_info = {
    'default_ttl': 50,
}
request_info = {
    'num_hosts': 12,
    'n_requests': 100,
    'traffic_type': 'random',
    'burst_probability': 0.3,
    'burst_size': 25,
    'requests_per_burst': 5,
    'fmin_range': (0.5, 1.0),
    'eprs_range': (1, 10),
}
# Exclusivo para preenchimento proativo e hibrido
proactive_params = {
    1 : { 'frange': (0.6, 0.7), 'neprs': 10 },
    5:  { 'frange': (0.8, 0.9), 'neprs': 10 },
}

# %%
# Inicializando a simulação
sim = Sim(network_info, controller_info, request_info)

# Preenche as tabelas de forma proativa
for alice in sim.network.hosts:
    print(f"Adicionando regras para {alice}")
    for bob in sim.network.hosts:
        for key in proactive_params.keys():
            sim.controller.add_match_route_rule_in_host_proactive(alice, bob, proactive_params[key]['frange'], proactive_params[key]['neprs'])
    # Mostra as tabelas
    sim.network.get_host(alice).draw_flow_table()
# Out:
# Adicionando regras para 0
# +----------------------+----------------------+--------------------+
# | Match                | Route                | Rule               |
# +======================+======================+====================+
# | (0, (0.6, 0.7), 10)  | [0]                  | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [0]                  | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [0, 1]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [0, 1]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [0, 1, 2]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [0, 1, 2]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [0, 4]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [0, 4]               | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [0, 1, 5]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [0, 1, 5]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [0, 4, 8]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [0, 4, 8]            | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+----------------------+--------------------+
# Adicionando regras para 1
# +----------------------+-------------------+--------------------+
# | Match                | Route             | Rule               |
# +======================+===================+====================+
# | (0, (0.6, 0.7), 10)  | [1, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [1, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [1]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [1]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [1, 2]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [1, 2]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [1, 2, 3]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [1, 2, 3]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [1, 0, 4]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [1, 0, 4]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [1, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [1, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [1, 2, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [1, 2, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [1, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [1, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [1, 5, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [1, 5, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# Adicionando regras para 2
# +----------------------+-----------------+--------------------+
# | Match                | Route           | Rule               |
# +======================+=================+====================+
# | (0, (0.6, 0.7), 10)  | [2, 1, 0]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [2, 1, 0]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [2, 1]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [2, 1]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [2]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [2]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [2, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [2, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [2, 1, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [2, 1, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [2, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [2, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [2, 3, 7]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [2, 3, 7]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.6, 0.7), 10) | [2, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 10) | [2, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.6, 0.7), 10) | [2, 3, 7, 11]   | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 10) | [2, 3, 7, 11]   | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# Adicionando regras para 3
# +----------------------+--------------------+--------------------+
# | Match                | Route              | Rule               |
# +======================+====================+====================+
# | (0, (0.6, 0.7), 10)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [3, 2, 1]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [3, 2, 1]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [3, 2]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [3, 2]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [3]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [3]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [3, 2, 6]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [3, 2, 6]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [3, 7]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [3, 7]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [3, 2, 6, 10]      | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [3, 2, 6, 10]      | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [3, 7, 11]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [3, 7, 11]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# Adicionando regras para 4
# +----------------------+-------------------+--------------------+
# | Match                | Route             | Rule               |
# +======================+===================+====================+
# | (0, (0.6, 0.7), 10)  | [4, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [4, 0]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [4, 0, 1]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [4, 0, 1]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [4]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [4]               | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [4, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [4, 5]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [4, 5, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [4, 5, 6]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [4, 8]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [4, 8]            | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [4, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [4, 5, 9]         | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [4, 8, 9, 10]     | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +----------------------+-------------------+--------------------+
# Adicionando regras para 5
# +----------------------+---------------+--------------------+
# | Match                | Route         | Rule               |
# +======================+===============+====================+
# | (0, (0.6, 0.7), 10)  | [5, 4, 0]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [5, 4, 0]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [5, 1]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [5, 1]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [5, 1, 2]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [5, 1, 2]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [5, 4]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [5, 4]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [5]           | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [5]           | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [5, 6]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [5, 6]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [5, 6, 7]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [5, 6, 7]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [5, 4, 8]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [5, 4, 8]     | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [5, 9]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [5, 9]        | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (10, (0.6, 0.7), 10) | [5, 6, 10]    | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (10, (0.8, 0.9), 10) | [5, 6, 10]    | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (11, (0.6, 0.7), 10) | [5, 6, 7, 11] | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# | (11, (0.8, 0.9), 10) | [5, 6, 7, 11] | BasicRuleProactive |
# +----------------------+---------------+--------------------+
# Adicionando regras para 6
# +----------------------+--------------+--------------------+
# | Match                | Route        | Rule               |
# +======================+==============+====================+
# | (0, (0.6, 0.7), 10)  | [6, 5, 4, 0] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [6, 5, 4, 0] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [6, 5, 1]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [6, 5, 1]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [6, 2]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [6, 2]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [6, 2, 3]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [6, 2, 3]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [6, 5, 4]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [6, 5, 4]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [6, 5]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [6, 5]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [6]          | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [6]          | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [6, 7]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [6, 7]       | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [6, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [6, 5, 9]    | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (10, (0.6, 0.7), 10) | [6, 10]      | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (10, (0.8, 0.9), 10) | [6, 10]      | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (11, (0.6, 0.7), 10) | [6, 7, 11]   | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# | (11, (0.8, 0.9), 10) | [6, 7, 11]   | BasicRuleProactive |
# +----------------------+--------------+--------------------+
# Adicionando regras para 7
# +----------------------+-----------------+--------------------+
# | Match                | Route           | Rule               |
# +======================+=================+====================+
# | (0, (0.6, 0.7), 10)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [7, 6, 2]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [7, 6, 2]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [7, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [7, 3]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [7, 6, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [7, 6, 5]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [7, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [7, 6]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [7]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [7]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.6, 0.7), 10) | [7, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 10) | [7, 6, 10]      | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.6, 0.7), 10) | [7, 11]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 10) | [7, 11]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# Adicionando regras para 8
# +----------------------+--------------------+--------------------+
# | Match                | Route              | Rule               |
# +======================+====================+====================+
# | (0, (0.6, 0.7), 10)  | [8, 4, 0]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [8, 4, 0]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [8, 4]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [8, 4]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [8, 4, 5]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [8, 4, 5]          | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [8]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [8]                | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [8, 9]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [8, 9]             | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [8, 9, 10]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [8, 9, 10]         | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [8, 9, 10, 11]     | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [8, 9, 10, 11]     | BasicRuleProactive |
# +----------------------+--------------------+--------------------+
# Adicionando regras para 9
# +----------------------+-----------------+--------------------+
# | Match                | Route           | Rule               |
# +======================+=================+====================+
# | (0, (0.6, 0.7), 10)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [9, 5, 1]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [9, 5, 1]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [9, 8, 4]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [9, 8, 4]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [9, 5]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [9, 5]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [9, 5, 6]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [9, 5, 6]       | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [9, 8]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [9, 8]          | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [9]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [9]             | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.6, 0.7), 10) | [9, 10]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 10) | [9, 10]         | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.6, 0.7), 10) | [9, 10, 11]     | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 10) | [9, 10, 11]     | BasicRuleProactive |
# +----------------------+-----------------+--------------------+
# Adicionando regras para 10
# +----------------------+------------------+--------------------+
# | Match                | Route            | Rule               |
# +======================+==================+====================+
# | (0, (0.6, 0.7), 10)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [10, 6, 2]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [10, 6, 2]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [10, 9, 5]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [10, 9, 5]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [10, 6]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [10, 6]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [10, 6, 7]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [10, 6, 7]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [10, 9, 8]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [10, 9, 8]       | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [10, 9]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [10, 9]          | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [10]             | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [10]             | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [10, 11]         | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [10, 11]         | BasicRuleProactive |
# +----------------------+------------------+--------------------+
# Adicionando regras para 11
# +----------------------+---------------------+--------------------+
# | Match                | Route               | Rule               |
# +======================+=====================+====================+
# | (0, (0.6, 0.7), 10)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (0, (0.8, 0.9), 10)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (1, (0.6, 0.7), 10)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (1, (0.8, 0.9), 10)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (2, (0.6, 0.7), 10)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (2, (0.8, 0.9), 10)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (3, (0.6, 0.7), 10)  | [11, 7, 3]          | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (3, (0.8, 0.9), 10)  | [11, 7, 3]          | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (4, (0.6, 0.7), 10)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (4, (0.8, 0.9), 10)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (5, (0.6, 0.7), 10)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (5, (0.8, 0.9), 10)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (6, (0.6, 0.7), 10)  | [11, 10, 6]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (6, (0.8, 0.9), 10)  | [11, 10, 6]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (7, (0.6, 0.7), 10)  | [11, 7]             | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (7, (0.8, 0.9), 10)  | [11, 7]             | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (8, (0.6, 0.7), 10)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (8, (0.8, 0.9), 10)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (9, (0.6, 0.7), 10)  | [11, 10, 9]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (9, (0.8, 0.9), 10)  | [11, 10, 9]         | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (10, (0.6, 0.7), 10) | [11, 10]            | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (10, (0.8, 0.9), 10) | [11, 10]            | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (11, (0.6, 0.7), 10) | [11]                | BasicRuleProactive |
# +----------------------+---------------------+--------------------+
# | (11, (0.8, 0.9), 10) | [11]                | BasicRuleProactive |
# +----------------------+---------------------+--------------------+

# %%
# Inicializando a simulação
sim = Sim(network_info, controller_info, request_info)
print("Requests:", sim.requests)

for request in sim.requests:
        print(f"[Time {time.get_current_time()}] Processando requisição {request}...")
        alice = sim.network.get_host(request.alice)
        rule = alice.find_rule_by_request(request)

        if rule == False:  # Caso não exista um match na tabela
            request.starttime = time.get_current_time()
            sim.update_time(3)
            alice.draw_flow_table()
            print(f"[Time {time.get_current_time()}] Adicionando regra no Host {alice}")
            sim.controller.add_match_route_rule_in_host_reactive(request)
            alice.draw_flow_table()
            rule = alice.find_rule_by_request(request)
            
        else:  # Caso já exista a regra
            print(f"[Time {time.get_current_time()}] Regra existente para {request} no Host {alice}.")
            request.starttime = time.get_current_time()
            sim.update_time(1)
                
        # Executa a regra
        print(f"[Time {time.get_current_time()}] Atendendo requisição {request} no Host {alice}.")
        sim.controller.run_rule(rule[1])
        request.endtime = time.get_current_time()
        # Registra a requisição atendida
        sim.controller.successful_request(request)
        
        # Exibir informações da requisição
        print(f"[Time {time.get_current_time()}] Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")

# Salva as requisições
received_requests['hibrido'] = sim.requests.copy()
successful_requests['hibrido'] = sim.controller.successful_requests
fulfilled_requests['hibrido'] = sim.controller.fulfilled_requests

# Fim da simulação
time.reset()
# Out:
# Requests: [RF84380:1-0:0.75:10, RF84470:5-11:0.52:8, RF844A0:0-1:0.8:6, RF844D0:6-1:0.84:2, RF84500:9-10:0.96:2, RF84530:11-2:0.97:4, RF84560:2-0:0.83:2, RF84590:7-0:0.85:5, RF845C0:11-3:0.57:8, RF845F0:7-9:0.9:10, RF84620:11-3:0.66:8, RF84650:0-1:0.75:6, RF84680:10-4:0.51:5, RF846B0:8-1:0.64:1, RF846E0:2-11:0.7:7, RF84710:8-7:0.68:5, RF84740:5-10:0.84:6, RF84770:0-7:0.75:8, RF847A0:11-6:1.0:1, RF847D0:10-3:0.54:2, RF84800:7-8:0.62:2, RF84830:9-8:0.84:2, RF84860:0-9:0.78:4, RF84890:2-6:0.8:3, RF848C0:6-2:0.77:8, RF848F0:2-0:0.65:6, RF84920:5-10:0.89:8, RF84950:3-7:0.9:9, RF84980:7-1:0.65:9, RF849B0:2-0:0.72:8, RF849E0:0-1:0.51:4, RF84A10:0-11:0.76:7, RF84A40:3-2:0.62:10, RF84A70:5-6:0.95:4, RF84AA0:4-8:0.65:7, RF84AD0:7-11:0.88:4, RF84B00:7-2:0.7:1, RF84B30:8-11:0.9:5, RF84B60:0-9:0.73:3, RF84B90:3-7:0.86:6, RF84BC0:9-0:0.67:6, RF84BF0:2-11:0.78:6, RF84C20:10-1:0.6:5, RF84C50:8-7:0.61:5, RF84C80:4-9:0.58:2, RF84CB0:10-11:0.68:8, RF84CE0:2-1:0.55:7, RF84D10:11-0:0.6:1, RF84D40:10-0:0.75:10, RF84D70:8-5:0.77:1, RF84DA0:5-4:0.98:5, RF84DD0:1-4:0.64:6, RF84E00:11-7:0.75:4, RF84E30:9-0:0.54:1, RF84E60:7-5:0.69:6, RF84E90:3-5:0.54:6, RF84EC0:6-3:0.66:5, RF84EF0:4-8:0.61:1, RF84F20:4-6:0.87:1, RF84F50:6-4:0.88:8, RF84F80:11-0:0.76:6, RF84FB0:0-8:0.65:4, RF84FE0:6-7:0.78:6, RF85010:10-3:0.76:2, RF85040:3-5:0.79:3, RF85070:1-6:0.58:2, RF850A0:7-9:0.87:9, RF850D0:8-10:0.56:1, RF85100:11-3:0.71:8, RF85130:7-10:0.62:8, RF85160:5-2:0.57:7, RF85190:5-2:0.77:9, RF851C0:8-7:0.61:1, RF851F0:8-7:0.91:6, RF85220:8-9:0.93:5, RF85250:0-9:0.58:9, RF85280:7-0:0.63:3, RF852B0:7-2:0.63:5, RF852E0:0-8:0.66:10, RF85310:1-5:0.63:1, RF85340:8-7:0.71:7, RF85370:11-1:0.89:9, RF853A0:11-2:0.9:5, RF853D0:7-11:0.64:9, RF85400:5-1:0.5:3, RF85430:4-3:0.64:9, RF85460:7-11:0.98:5, RF85490:7-3:0.64:6, RF854C0:11-10:0.52:8, RF854F0:8-10:0.94:9, RF85520:3-9:0.97:9, RF85550:2-6:1.0:6, RF85580:1-0:0.92:6, RF855B0:9-2:0.62:4, RF855E0:4-7:0.64:7, RF85610:3-1:0.51:2, RF85640:6-3:0.84:3, RF85670:7-3:0.66:10, RF856A0:10-0:0.6:1, RF856D0:11-5:0.97:6]
# [Time 0] Processando requisição RF84380:1-0:0.75:10...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 3] Adicionando regra no Host 1
# Decisão aplicada: (Normal E2E,)
# +-----------------------+---------+-----------+
# | Match                 | Route   | Rule      |
# +=======================+=========+===========+
# | (0, (0.65, 0.85), 10) | [1, 0]  | BasicRule |
# +-----------------------+---------+-----------+
# [Time 3] Atendendo requisição RF84380:1-0:0.75:10 no Host 1.
# [BasicRule] Passo: 1
# [Time 3] Request RF84380:1-0:0.75:10: Start Time = 0, End Time = 3
# [Time 3] Processando requisição RF84470:5-11:0.52:8...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 6] Adicionando regra no Host 5
# Decisão aplicada: (Normal E2E,)
# +--------------------------------------+---------------+-----------+
# | Match                                | Route         | Rule      |
# +======================================+===============+===========+
# | (11, (0.42000000000000004, 0.62), 8) | [5, 6, 7, 11] | BasicRule |
# +--------------------------------------+---------------+-----------+
# [Time 6] Atendendo requisição RF84470:5-11:0.52:8 no Host 5.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(5-6-7)
# Running Swap(5-6-7)
# [Time 6] Request RF84470:5-11:0.52:8: Start Time = 3, End Time = 6
# [Time 6] Processando requisição RF844A0:0-1:0.8:6...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 9] Adicionando regra no Host 0
# Decisão aplicada: (Normal E2E,)
# +-----------------------------------+---------+-----------+
# | Match                             | Route   | Rule      |
# +===================================+=========+===========+
# | (1, (0.7000000000000001, 0.9), 6) | [0, 1]  | BasicRule |
# +-----------------------------------+---------+-----------+
# [Time 9] Atendendo requisição RF844A0:0-1:0.8:6 no Host 0.
# [BasicRule] Passo: 1
# [Time 9] Request RF844A0:0-1:0.8:6: Start Time = 6, End Time = 9
# [Time 9] Processando requisição RF844D0:6-1:0.84:2...
# [Time 10] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 12] Adicionando regra no Host 6
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (1, (0.74, 0.94), 2) | [6, 5, 1] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 12] Atendendo requisição RF844D0:6-1:0.84:2 no Host 6.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(6-5-1)
# Running Swap(6-5-1)
# [Time 12] Request RF844D0:6-1:0.84:2: Start Time = 9, End Time = 12
# [Time 12] Processando requisição RF84500:9-10:0.96:2...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 15] Adicionando regra no Host 9
# Decisão aplicada: (High Fidelity,)
# +-----------------------+---------+-------------------+
# | Match                 | Route   | Rule              |
# +=======================+=========+===================+
# | (10, (0.86, 1.06), 2) | [9, 10] | HighFidelityRoule |
# +-----------------------+---------+-------------------+
# [Time 15] Atendendo requisição RF84500:9-10:0.96:2 no Host 9.
# [Time 15] Request RF84500:9-10:0.96:2: Start Time = 12, End Time = 15
# [Time 15] Processando requisição RF84530:11-2:0.97:4...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 18] Adicionando regra no Host 11
# Decisão aplicada: (High Fidelity,)
# +----------------------+---------------+-------------------+
# | Match                | Route         | Rule              |
# +======================+===============+===================+
# | (2, (0.87, 1.07), 4) | [11, 7, 3, 2] | HighFidelityRoule |
# +----------------------+---------------+-------------------+
# [Time 18] Atendendo requisição RF84530:11-2:0.97:4 no Host 11.
# [Time 18] Request RF84530:11-2:0.97:4: Start Time = 15, End Time = 18
# [Time 18] Processando requisição RF84560:2-0:0.83:2...
# [Time 20] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 21] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 21] Atendendo requisição RF84560:2-0:0.83:2 no Host 2.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# [Time 21] Request RF84560:2-0:0.83:2: Start Time = 18, End Time = 21
# [Time 21] Processando requisição RF84590:7-0:0.85:5...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 24] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +----------------------+--------------+-----------+
# | Match                | Route        | Rule      |
# +======================+==============+===========+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule |
# +----------------------+--------------+-----------+
# [Time 24] Atendendo requisição RF84590:7-0:0.85:5 no Host 7.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(7-5-4)
# Running Swap(7-5-4)
# [Time 24] Request RF84590:7-0:0.85:5: Start Time = 21, End Time = 24
# [Time 24] Processando requisição RF845C0:11-3:0.57:8...
# +----------------------+---------------+-------------------+
# | Match                | Route         | Rule              |
# +======================+===============+===================+
# | (2, (0.87, 1.07), 4) | [11, 7, 3, 2] | HighFidelityRoule |
# +----------------------+---------------+-------------------+
# [Time 27] Adicionando regra no Host 11
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+---------------+-------------------+
# | Match                              | Route         | Rule              |
# +====================================+===============+===================+
# | (2, (0.87, 1.07), 4)               | [11, 7, 3, 2] | HighFidelityRoule |
# +------------------------------------+---------------+-------------------+
# | (3, (0.47, 0.6699999999999999), 8) | [11, 7, 3]    | BasicRule         |
# +------------------------------------+---------------+-------------------+
# [Time 27] Atendendo requisição RF845C0:11-3:0.57:8 no Host 11.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(11-7-3)
# Running Swap(11-7-3)
# [Time 27] Request RF845C0:11-3:0.57:8: Start Time = 24, End Time = 27
# [Time 27] Processando requisição RF845F0:7-9:0.9:10...
# [Time 30] Recursos atualizados
# +----------------------+--------------+-----------+
# | Match                | Route        | Rule      |
# +======================+==============+===========+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule |
# +----------------------+--------------+-----------+
# [Time 30] Adicionando regra no Host 7
# Decisão aplicada: (High Fidelity,)
# +----------------------+--------------+-------------------+
# | Match                | Route        | Rule              |
# +======================+==============+===================+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule         |
# +----------------------+--------------+-------------------+
# | (9, (0.8, 1.0), 10)  | [7, 5, 9]    | HighFidelityRoule |
# +----------------------+--------------+-------------------+
# [Time 30] Atendendo requisição RF845F0:7-9:0.9:10 no Host 7.
# [Time 30] Request RF845F0:7-9:0.9:10: Start Time = 27, End Time = 30
# [Time 30] Processando requisição RF84620:11-3:0.66:8...
# [Time 30] Regra existente para RF84620:11-3:0.66:8 no Host 11.
# [Time 31] Atendendo requisição RF84620:11-3:0.66:8 no Host 11.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(11-7-3)
# Running Swap(11-7-3)
# [Time 31] Request RF84620:11-3:0.66:8: Start Time = 30, End Time = 31
# [Time 31] Processando requisição RF84650:0-1:0.75:6...
# [Time 31] Regra existente para RF84650:0-1:0.75:6 no Host 0.
# [Time 32] Atendendo requisição RF84650:0-1:0.75:6 no Host 0.
# [BasicRule] Passo: 1
# [Time 32] Request RF84650:0-1:0.75:6: Start Time = 31, End Time = 32
# [Time 32] Processando requisição RF84680:10-4:0.51:5...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 35] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+---------------+-----------+
# | Match                               | Route         | Rule      |
# +=====================================+===============+===========+
# | (4, (0.41000000000000003, 0.61), 5) | [10, 6, 5, 4] | BasicRule |
# +-------------------------------------+---------------+-----------+
# [Time 35] Atendendo requisição RF84680:10-4:0.51:5 no Host 10.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(10-6-5)
# Running Swap(10-6-5)
# [Time 35] Request RF84680:10-4:0.51:5: Start Time = 32, End Time = 35
# [Time 35] Processando requisição RF846B0:8-1:0.64:1...
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 38] Adicionando regra no Host 8
# Decisão aplicada: (Normal E2E,)
# +----------------------+--------------+-----------+
# | Match                | Route        | Rule      |
# +======================+==============+===========+
# | (1, (0.54, 0.74), 1) | [8, 4, 0, 1] | BasicRule |
# +----------------------+--------------+-----------+
# [Time 38] Atendendo requisição RF846B0:8-1:0.64:1 no Host 8.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# [Time 38] Request RF846B0:8-1:0.64:1: Start Time = 35, End Time = 38
# [Time 38] Processando requisição RF846E0:2-11:0.7:7...
# [Time 40] Recursos atualizados
# +------------------------------------+-----------+-----------+
# | Match                              | Route     | Rule      |
# +====================================+===========+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0] | BasicRule |
# +------------------------------------+-----------+-----------+
# [Time 41] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 41] Atendendo requisição RF846E0:2-11:0.7:7 no Host 2.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(2-3-11)
# Running Swap(2-3-11)
# [Time 41] Request RF846E0:2-11:0.7:7: Start Time = 38, End Time = 41
# [Time 41] Processando requisição RF84710:8-7:0.68:5...
# +----------------------+--------------+-----------+
# | Match                | Route        | Rule      |
# +======================+==============+===========+
# | (1, (0.54, 0.74), 1) | [8, 4, 0, 1] | BasicRule |
# +----------------------+--------------+-----------+
# [Time 44] Adicionando regra no Host 8
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+--------------+-----------+
# | Match                              | Route        | Rule      |
# +====================================+==============+===========+
# | (1, (0.54, 0.74), 1)               | [8, 4, 0, 1] | BasicRule |
# +------------------------------------+--------------+-----------+
# | (7, (0.5800000000000001, 0.78), 5) | [8, 4, 7]    | BasicRule |
# +------------------------------------+--------------+-----------+
# [Time 44] Atendendo requisição RF84710:8-7:0.68:5 no Host 8.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(8-4-7)
# Running Swap(8-4-7)
# [Time 44] Request RF84710:8-7:0.68:5: Start Time = 41, End Time = 44
# [Time 44] Processando requisição RF84740:5-10:0.84:6...
# +--------------------------------------+---------------+-----------+
# | Match                                | Route         | Rule      |
# +======================================+===============+===========+
# | (11, (0.42000000000000004, 0.62), 8) | [5, 6, 7, 11] | BasicRule |
# +--------------------------------------+---------------+-----------+
# [Time 47] Adicionando regra no Host 5
# Decisão aplicada: (Normal E2E,)
# +--------------------------------------+---------------+-----------+
# | Match                                | Route         | Rule      |
# +======================================+===============+===========+
# | (11, (0.42000000000000004, 0.62), 8) | [5, 6, 7, 11] | BasicRule |
# +--------------------------------------+---------------+-----------+
# | (10, (0.74, 0.94), 6)                | [5, 10]       | BasicRule |
# +--------------------------------------+---------------+-----------+
# [Time 47] Atendendo requisição RF84740:5-10:0.84:6 no Host 5.
# [BasicRule] Passo: 1
# [Time 47] Request RF84740:5-10:0.84:6: Start Time = 44, End Time = 47
# [Time 47] Processando requisição RF84770:0-7:0.75:8...
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [Time 50] Recursos atualizados
# +-----------------------------------+---------+-----------+
# | Match                             | Route   | Rule      |
# +===================================+=========+===========+
# | (1, (0.7000000000000001, 0.9), 6) | [0, 1]  | BasicRule |
# +-----------------------------------+---------+-----------+
# [Time 50] Adicionando regra no Host 0
# Decisão aplicada: (Normal E2E,)
# +-----------------------------------+-----------+-----------+
# | Match                             | Route     | Rule      |
# +===================================+===========+===========+
# | (1, (0.7000000000000001, 0.9), 6) | [0, 1]    | BasicRule |
# +-----------------------------------+-----------+-----------+
# | (7, (0.65, 0.85), 8)              | [0, 4, 7] | BasicRule |
# +-----------------------------------+-----------+-----------+
# [Time 50] Atendendo requisição RF84770:0-7:0.75:8 no Host 0.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(0-4-7)
# Running Swap(0-4-7)
# [Time 50] Request RF84770:0-7:0.75:8: Start Time = 47, End Time = 50
# [Time 50] Processando requisição RF847A0:11-6:1.0:1...
# +------------------------------------+---------------+-------------------+
# | Match                              | Route         | Rule              |
# +====================================+===============+===================+
# | (2, (0.87, 1.07), 4)               | [11, 7, 3, 2] | HighFidelityRoule |
# +------------------------------------+---------------+-------------------+
# | (3, (0.47, 0.6699999999999999), 8) | [11, 7, 3]    | BasicRule         |
# +------------------------------------+---------------+-------------------+
# [Time 53] Adicionando regra no Host 11
# Decisão aplicada: (High Fidelity,)
# +------------------------------------+---------------+-------------------+
# | Match                              | Route         | Rule              |
# +====================================+===============+===================+
# | (2, (0.87, 1.07), 4)               | [11, 7, 3, 2] | HighFidelityRoule |
# +------------------------------------+---------------+-------------------+
# | (3, (0.47, 0.6699999999999999), 8) | [11, 7, 3]    | BasicRule         |
# +------------------------------------+---------------+-------------------+
# | (6, (0.9, 1.1), 1)                 | [11, 2, 6]    | HighFidelityRoule |
# +------------------------------------+---------------+-------------------+
# [Time 53] Atendendo requisição RF847A0:11-6:1.0:1 no Host 11.
# [Time 53] Request RF847A0:11-6:1.0:1: Start Time = 50, End Time = 53
# [Time 53] Processando requisição RF847D0:10-3:0.54:2...
# +-------------------------------------+---------------+-----------+
# | Match                               | Route         | Rule      |
# +=====================================+===============+===========+
# | (4, (0.41000000000000003, 0.61), 5) | [10, 6, 5, 4] | BasicRule |
# +-------------------------------------+---------------+-----------+
# [Time 56] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+---------------+-----------+
# | Match                               | Route         | Rule      |
# +=====================================+===============+===========+
# | (4, (0.41000000000000003, 0.61), 5) | [10, 6, 5, 4] | BasicRule |
# +-------------------------------------+---------------+-----------+
# | (3, (0.44000000000000006, 0.64), 2) | [10, 11, 3]   | BasicRule |
# +-------------------------------------+---------------+-----------+
# [Time 56] Atendendo requisição RF847D0:10-3:0.54:2 no Host 10.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(10-11-3)
# Running Swap(10-11-3)
# [Time 56] Request RF847D0:10-3:0.54:2: Start Time = 53, End Time = 56
# [Time 56] Processando requisição RF84800:7-8:0.62:2...
# +----------------------+--------------+-------------------+
# | Match                | Route        | Rule              |
# +======================+==============+===================+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule         |
# +----------------------+--------------+-------------------+
# | (9, (0.8, 1.0), 10)  | [7, 5, 9]    | HighFidelityRoule |
# +----------------------+--------------+-------------------+
# [Time 59] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +----------------------+--------------+-------------------+
# | Match                | Route        | Rule              |
# +======================+==============+===================+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule         |
# +----------------------+--------------+-------------------+
# | (9, (0.8, 1.0), 10)  | [7, 5, 9]    | HighFidelityRoule |
# +----------------------+--------------+-------------------+
# | (8, (0.52, 0.72), 2) | [7, 8]       | BasicRule         |
# +----------------------+--------------+-------------------+
# [Time 59] Atendendo requisição RF84800:7-8:0.62:2 no Host 7.
# [BasicRule] Passo: 1
# [Time 59] Request RF84800:7-8:0.62:2: Start Time = 56, End Time = 59
# [Time 59] Processando requisição RF84830:9-8:0.84:2...
# [Time 60] Recursos atualizados
# +-----------------------+---------+-------------------+
# | Match                 | Route   | Rule              |
# +=======================+=========+===================+
# | (10, (0.86, 1.06), 2) | [9, 10] | HighFidelityRoule |
# +-----------------------+---------+-------------------+
# [Time 62] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +-----------------------+---------+-------------------+
# | Match                 | Route   | Rule              |
# +=======================+=========+===================+
# | (10, (0.86, 1.06), 2) | [9, 10] | HighFidelityRoule |
# +-----------------------+---------+-------------------+
# | (8, (0.74, 0.94), 2)  | [9, 8]  | BasicRule         |
# +-----------------------+---------+-------------------+
# [Time 62] Atendendo requisição RF84830:9-8:0.84:2 no Host 9.
# [BasicRule] Passo: 1
# [Time 62] Request RF84830:9-8:0.84:2: Start Time = 59, End Time = 62
# [Time 62] Processando requisição RF84860:0-9:0.78:4...
# +-----------------------------------+-----------+-----------+
# | Match                             | Route     | Rule      |
# +===================================+===========+===========+
# | (1, (0.7000000000000001, 0.9), 6) | [0, 1]    | BasicRule |
# +-----------------------------------+-----------+-----------+
# | (7, (0.65, 0.85), 8)              | [0, 4, 7] | BasicRule |
# +-----------------------------------+-----------+-----------+
# [Time 65] Adicionando regra no Host 0
# Decisão aplicada: (Normal E2E,)
# +-----------------------------------+-----------+-----------+
# | Match                             | Route     | Rule      |
# +===================================+===========+===========+
# | (1, (0.7000000000000001, 0.9), 6) | [0, 1]    | BasicRule |
# +-----------------------------------+-----------+-----------+
# | (7, (0.65, 0.85), 8)              | [0, 4, 7] | BasicRule |
# +-----------------------------------+-----------+-----------+
# | (9, (0.68, 0.88), 4)              | [0, 8, 9] | BasicRule |
# +-----------------------------------+-----------+-----------+
# [Time 65] Atendendo requisição RF84860:0-9:0.78:4 no Host 0.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(0-8-9)
# Running Swap(0-8-9)
# [Time 65] Request RF84860:0-9:0.78:4: Start Time = 62, End Time = 65
# [Time 65] Processando requisição RF84890:2-6:0.8:3...
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 68] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# | (6, (0.7000000000000001, 0.9), 3)  | [2, 6]     | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 68] Atendendo requisição RF84890:2-6:0.8:3 no Host 2.
# [BasicRule] Passo: 1
# [Time 68] Request RF84890:2-6:0.8:3: Start Time = 65, End Time = 68
# [Time 68] Processando requisição RF848C0:6-2:0.77:8...
# [Time 70] Recursos atualizados
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (1, (0.74, 0.94), 2) | [6, 5, 1] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 71] Adicionando regra no Host 6
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (1, (0.74, 0.94), 2) | [6, 5, 1] | BasicRule |
# +----------------------+-----------+-----------+
# | (2, (0.67, 0.87), 8) | [6, 2]    | BasicRule |
# +----------------------+-----------+-----------+
# [Time 71] Atendendo requisição RF848C0:6-2:0.77:8 no Host 6.
# [BasicRule] Passo: 1
# [Time 71] Request RF848C0:6-2:0.77:8: Start Time = 68, End Time = 71
# [Time 71] Processando requisição RF848F0:2-0:0.65:6...
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# | (6, (0.7000000000000001, 0.9), 3)  | [2, 6]     | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 74] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# | (6, (0.7000000000000001, 0.9), 3)  | [2, 6]     | BasicRule |
# +------------------------------------+------------+-----------+
# | (0, (0.55, 0.75), 6)               | [2, 0]     | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 74] Atendendo requisição RF848F0:2-0:0.65:6 no Host 2.
# [BasicRule] Passo: 1
# [Time 74] Request RF848F0:2-0:0.65:6: Start Time = 71, End Time = 74
# [Time 74] Processando requisição RF84920:5-10:0.89:8...
# +--------------------------------------+---------------+-----------+
# | Match                                | Route         | Rule      |
# +======================================+===============+===========+
# | (11, (0.42000000000000004, 0.62), 8) | [5, 6, 7, 11] | BasicRule |
# +--------------------------------------+---------------+-----------+
# | (10, (0.74, 0.94), 6)                | [5, 10]       | BasicRule |
# +--------------------------------------+---------------+-----------+
# [Time 77] Adicionando regra no Host 5
# Decisão aplicada: (Normal E2E,)
# +--------------------------------------+---------------+-----------+
# | Match                                | Route         | Rule      |
# +======================================+===============+===========+
# | (11, (0.42000000000000004, 0.62), 8) | [5, 6, 7, 11] | BasicRule |
# +--------------------------------------+---------------+-----------+
# | (10, (0.74, 0.94), 6)                | [5, 10]       | BasicRule |
# +--------------------------------------+---------------+-----------+
# | (10, (0.79, 0.99), 8)                | [5, 10]       | BasicRule |
# +--------------------------------------+---------------+-----------+
# [Time 77] Atendendo requisição RF84920:5-10:0.89:8 no Host 5.
# [BasicRule] Passo: 1
# [Time 77] Request RF84920:5-10:0.89:8: Start Time = 74, End Time = 77
# [Time 77] Processando requisição RF84950:3-7:0.9:9...
# [BasicRule] Regra fechada e removida do Host 1.
# [Time 80] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 80] Adicionando regra no Host 3
# Decisão aplicada: (High Fidelity,)
# +--------------------+---------+-------------------+
# | Match              | Route   | Rule              |
# +====================+=========+===================+
# | (7, (0.8, 1.0), 9) | [3, 7]  | HighFidelityRoule |
# +--------------------+---------+-------------------+
# [Time 80] Atendendo requisição RF84950:3-7:0.9:9 no Host 3.
# [Time 80] Request RF84950:3-7:0.9:9: Start Time = 77, End Time = 80
# [Time 80] Processando requisição RF84980:7-1:0.65:9...
# [BasicRule] Regra fechada e removida do Host 5.
# +----------------------+--------------+-------------------+
# | Match                | Route        | Rule              |
# +======================+==============+===================+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule         |
# +----------------------+--------------+-------------------+
# | (9, (0.8, 1.0), 10)  | [7, 5, 9]    | HighFidelityRoule |
# +----------------------+--------------+-------------------+
# | (8, (0.52, 0.72), 2) | [7, 8]       | BasicRule         |
# +----------------------+--------------+-------------------+
# [Time 83] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +----------------------+--------------+-------------------+
# | Match                | Route        | Rule              |
# +======================+==============+===================+
# | (0, (0.75, 0.95), 5) | [7, 5, 4, 0] | BasicRule         |
# +----------------------+--------------+-------------------+
# | (9, (0.8, 1.0), 10)  | [7, 5, 9]    | HighFidelityRoule |
# +----------------------+--------------+-------------------+
# | (8, (0.52, 0.72), 2) | [7, 8]       | BasicRule         |
# +----------------------+--------------+-------------------+
# | (1, (0.55, 0.75), 9) | [7, 0, 1]    | BasicRule         |
# +----------------------+--------------+-------------------+
# [Time 83] Atendendo requisição RF84980:7-1:0.65:9 no Host 7.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(7-0-1)
# Running Swap(7-0-1)
# [Time 83] Request RF84980:7-1:0.65:9: Start Time = 80, End Time = 83
# [Time 83] Processando requisição RF849B0:2-0:0.72:8...
# [BasicRule] Regra fechada e removida do Host 0.
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# | (6, (0.7000000000000001, 0.9), 3)  | [2, 6]     | BasicRule |
# +------------------------------------+------------+-----------+
# | (0, (0.55, 0.75), 6)               | [2, 0]     | BasicRule |
# +------------------------------------+------------+-----------+
# [Time 86] Adicionando regra no Host 2
# Decisão aplicada: (Normal E2E,)
# +------------------------------------+------------+-----------+
# | Match                              | Route      | Rule      |
# +====================================+============+===========+
# | (0, (0.73, 0.9299999999999999), 2) | [2, 1, 0]  | BasicRule |
# +------------------------------------+------------+-----------+
# | (11, (0.6, 0.7999999999999999), 7) | [2, 3, 11] | BasicRule |
# +------------------------------------+------------+-----------+
# ...
# +-----------------------+------------+-------------------+
# [Time 252] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-----------------------+------------+-------------------+
# | Match                 | Route      | Rule              |
# +=======================+============+===================+
# | (9, (0.77, 0.97), 9)  | [7, 5, 9]  | BasicRule         |
# +-----------------------+------------+-------------------+
# | (10, (0.52, 0.72), 8) | [7, 6, 10] | BasicRule         |
# +-----------------------+------------+-------------------+
# | (0, (0.53, 0.73), 3)  | [7, 0]     | BasicRule         |
# +-----------------------+------------+-------------------+
# | (2, (0.53, 0.73), 5)  | [7, 2]     | BasicRule         |
# +-----------------------+------------+-------------------+
# | (11, (0.54, 0.74), 9) | [7, 11]    | BasicRule         |
# +-----------------------+------------+-------------------+
# | (11, (0.88, 1.08), 5) | [7, 11]    | HighFidelityRoule |
# +-----------------------+------------+-------------------+
# | (3, (0.54, 0.74), 6)  | [7, 3]     | BasicRule         |
# +-----------------------+------------+-------------------+
# [Time 252] Atendendo requisição RF85490:7-3:0.64:6 no Host 7.
# [BasicRule] Passo: 1
# [Time 252] Request RF85490:7-3:0.64:6: Start Time = 249, End Time = 252
# [Time 252] Processando requisição RF854C0:11-10:0.52:8...
# [BasicRule] Regra fechada e removida do Host 10.
# +------------------------------------+------------+-------------------+
# | Match                              | Route      | Rule              |
# +====================================+============+===================+
# | (3, (0.61, 0.8099999999999999), 8) | [11, 3]    | BasicRule         |
# +------------------------------------+------------+-------------------+
# | (1, (0.79, 0.99), 9)               | [11, 0, 1] | BasicRule         |
# +------------------------------------+------------+-------------------+
# | (2, (0.8, 1.0), 5)                 | [11, 2]    | HighFidelityRoule |
# +------------------------------------+------------+-------------------+
# [Time 255] Adicionando regra no Host 11
# Decisão aplicada: (Normal E2E,)
# +--------------------------------------+------------+-------------------+
# | Match                                | Route      | Rule              |
# +======================================+============+===================+
# | (3, (0.61, 0.8099999999999999), 8)   | [11, 3]    | BasicRule         |
# +--------------------------------------+------------+-------------------+
# | (1, (0.79, 0.99), 9)                 | [11, 0, 1] | BasicRule         |
# +--------------------------------------+------------+-------------------+
# | (2, (0.8, 1.0), 5)                   | [11, 2]    | HighFidelityRoule |
# +--------------------------------------+------------+-------------------+
# | (10, (0.42000000000000004, 0.62), 8) | [11, 10]   | BasicRule         |
# +--------------------------------------+------------+-------------------+
# [Time 255] Atendendo requisição RF854C0:11-10:0.52:8 no Host 11.
# [BasicRule] Passo: 1
# [Time 255] Request RF854C0:11-10:0.52:8: Start Time = 252, End Time = 255
# [Time 255] Processando requisição RF854F0:8-10:0.94:9...
# [BasicRule] Regra fechada e removida do Host 3.
# +-------------------------------------+------------+-------------------+
# | Match                               | Route      | Rule              |
# +=====================================+============+===================+
# | (10, (0.4600000000000001, 0.66), 1) | [8, 9, 10] | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (7, (0.51, 0.71), 1)                | [8, 7]     | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (7, (0.81, 1.01), 6)                | [8, 7]     | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# | (9, (0.8300000000000001, 1.03), 5)  | [8, 9]     | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# | (7, (0.61, 0.8099999999999999), 7)  | [8, 7]     | BasicRule         |
# +-------------------------------------+------------+-------------------+
# [Time 258] Adicionando regra no Host 8
# Decisão aplicada: (High Fidelity,)
# +-------------------------------------+------------+-------------------+
# | Match                               | Route      | Rule              |
# +=====================================+============+===================+
# | (10, (0.4600000000000001, 0.66), 1) | [8, 9, 10] | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (7, (0.51, 0.71), 1)                | [8, 7]     | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (7, (0.81, 1.01), 6)                | [8, 7]     | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# | (9, (0.8300000000000001, 1.03), 5)  | [8, 9]     | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# | (7, (0.61, 0.8099999999999999), 7)  | [8, 7]     | BasicRule         |
# +-------------------------------------+------------+-------------------+
# | (10, (0.84, 1.04), 9)               | [8, 10]    | HighFidelityRoule |
# +-------------------------------------+------------+-------------------+
# [Time 258] Atendendo requisição RF854F0:8-10:0.94:9 no Host 8.
# [Time 258] Request RF854F0:8-10:0.94:9: Start Time = 255, End Time = 258
# [Time 258] Processando requisição RF85520:3-9:0.97:9...
# [Time 260] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 1.
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 261] Adicionando regra no Host 3
# Decisão aplicada: (High Fidelity,)
# +----------------------+-----------+-------------------+
# | Match                | Route     | Rule              |
# +======================+===========+===================+
# | (9, (0.87, 1.07), 9) | [3, 5, 9] | HighFidelityRoule |
# +----------------------+-----------+-------------------+
# [Time 261] Atendendo requisição RF85520:3-9:0.97:9 no Host 3.
# [Time 261] Request RF85520:3-9:0.97:9: Start Time = 258, End Time = 261
# [Time 261] Processando requisição RF85550:2-6:1.0:6...
# [BasicRule] Regra fechada e removida do Host 7.
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 264] Adicionando regra no Host 2
# Decisão aplicada: (High Fidelity,)
# +--------------------+---------+-------------------+
# | Match              | Route   | Rule              |
# +====================+=========+===================+
# | (6, (0.9, 1.1), 6) | [2, 6]  | HighFidelityRoule |
# +--------------------+---------+-------------------+
# [Time 264] Atendendo requisição RF85550:2-6:1.0:6 no Host 2.
# [Time 264] Request RF85550:2-6:1.0:6: Start Time = 261, End Time = 264
# [Time 264] Processando requisição RF85580:1-0:0.92:6...
# [BasicRule] Regra fechada e removida do Host 8.
# +----------------------+---------+-----------+
# | Match                | Route   | Rule      |
# +======================+=========+===========+
# | (5, (0.53, 0.73), 1) | [1, 5]  | BasicRule |
# +----------------------+---------+-----------+
# [Time 267] Adicionando regra no Host 1
# Decisão aplicada: (High Fidelity,)
# +------------------------------------+---------+-------------------+
# | Match                              | Route   | Rule              |
# +====================================+=========+===================+
# | (5, (0.53, 0.73), 1)               | [1, 5]  | BasicRule         |
# +------------------------------------+---------+-------------------+
# | (0, (0.8200000000000001, 1.02), 6) | [1, 0]  | HighFidelityRoule |
# +------------------------------------+---------+-------------------+
# [Time 267] Atendendo requisição RF85580:1-0:0.92:6 no Host 1.
# [Time 267] Request RF85580:1-0:0.92:6: Start Time = 264, End Time = 267
# [Time 267] Processando requisição RF855B0:9-2:0.62:4...
# [BasicRule] Regra fechada e removida do Host 11.
# [Time 270] Recursos atualizados
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 270] Adicionando regra no Host 9
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (2, (0.52, 0.72), 4) | [9, 0, 2] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 270] Atendendo requisição RF855B0:9-2:0.62:4 no Host 9.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(9-0-2)
# Running Swap(9-0-2)
# [Time 270] Request RF855B0:9-2:0.62:4: Start Time = 267, End Time = 270
# [Time 270] Processando requisição RF855E0:4-7:0.64:7...
# [BasicRule] Regra fechada e removida do Host 7.
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (3, (0.54, 0.74), 9) | [4, 7, 3] | BasicRule |
# +----------------------+-----------+-----------+
# [Time 273] Adicionando regra no Host 4
# Decisão aplicada: (Normal E2E,)
# +----------------------+-----------+-----------+
# | Match                | Route     | Rule      |
# +======================+===========+===========+
# | (3, (0.54, 0.74), 9) | [4, 7, 3] | BasicRule |
# +----------------------+-----------+-----------+
# | (7, (0.54, 0.74), 7) | [4, 7]    | BasicRule |
# +----------------------+-----------+-----------+
# [Time 273] Atendendo requisição RF855E0:4-7:0.64:7 no Host 4.
# [BasicRule] Passo: 1
# [Time 273] Request RF855E0:4-7:0.64:7: Start Time = 270, End Time = 273
# [Time 273] Processando requisição RF85610:3-1:0.51:2...
# [BasicRule] Regra fechada e removida do Host 5.
# +----------------------+-----------+-------------------+
# | Match                | Route     | Rule              |
# +======================+===========+===================+
# | (9, (0.87, 1.07), 9) | [3, 5, 9] | HighFidelityRoule |
# +----------------------+-----------+-------------------+
# [Time 276] Adicionando regra no Host 3
# Decisão aplicada: (Normal E2E,)
# +-------------------------------------+-----------+-------------------+
# | Match                               | Route     | Rule              |
# +=====================================+===========+===================+
# | (9, (0.87, 1.07), 9)                | [3, 5, 9] | HighFidelityRoule |
# +-------------------------------------+-----------+-------------------+
# | (1, (0.41000000000000003, 0.61), 2) | [3, 5, 1] | BasicRule         |
# +-------------------------------------+-----------+-------------------+
# [Time 276] Atendendo requisição RF85610:3-1:0.51:2 no Host 3.
# [BasicRule] Passo: 1
# [BasicRule] Passo: 2
# [BasicRule] Ação: Swap(3-5-1)
# Running Swap(3-5-1)
# [Time 276] Request RF85610:3-1:0.51:2: Start Time = 273, End Time = 276
# [Time 276] Processando requisição RF85640:6-3:0.84:3...
# [BasicRule] Regra fechada e removida do Host 5.
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 279] Adicionando regra no Host 6
# Decisão aplicada: (Normal E2E,)
# +----------------------+---------+-----------+
# | Match                | Route   | Rule      |
# +======================+=========+===========+
# | (3, (0.74, 0.94), 3) | [6, 3]  | BasicRule |
# +----------------------+---------+-----------+
# [Time 279] Atendendo requisição RF85640:6-3:0.84:3 no Host 6.
# [BasicRule] Passo: 1
# [Time 279] Request RF85640:6-3:0.84:3: Start Time = 276, End Time = 279
# [Time 279] Processando requisição RF85670:7-3:0.66:10...
# [Time 280] Recursos atualizados
# [BasicRule] Regra fechada e removida do Host 8.
# +-----------------------+---------+-------------------+
# | Match                 | Route   | Rule              |
# +=======================+=========+===================+
# | (0, (0.53, 0.73), 3)  | [7, 0]  | BasicRule         |
# +-----------------------+---------+-------------------+
# | (2, (0.53, 0.73), 5)  | [7, 2]  | BasicRule         |
# +-----------------------+---------+-------------------+
# | (11, (0.54, 0.74), 9) | [7, 11] | BasicRule         |
# +-----------------------+---------+-------------------+
# | (11, (0.88, 1.08), 5) | [7, 11] | HighFidelityRoule |
# +-----------------------+---------+-------------------+
# | (3, (0.54, 0.74), 6)  | [7, 3]  | BasicRule         |
# +-----------------------+---------+-------------------+
# [Time 282] Adicionando regra no Host 7
# Decisão aplicada: (Normal E2E,)
# +-----------------------+---------+-------------------+
# | Match                 | Route   | Rule              |
# +=======================+=========+===================+
# | (0, (0.53, 0.73), 3)  | [7, 0]  | BasicRule         |
# +-----------------------+---------+-------------------+
# | (2, (0.53, 0.73), 5)  | [7, 2]  | BasicRule         |
# +-----------------------+---------+-------------------+
# | (11, (0.54, 0.74), 9) | [7, 11] | BasicRule         |
# +-----------------------+---------+-------------------+
# | (11, (0.88, 1.08), 5) | [7, 11] | HighFidelityRoule |
# +-----------------------+---------+-------------------+
# | (3, (0.54, 0.74), 6)  | [7, 3]  | BasicRule         |
# +-----------------------+---------+-------------------+
# | (3, (0.56, 0.76), 10) | [7, 3]  | BasicRule         |
# +-----------------------+---------+-------------------+
# [Time 282] Atendendo requisição RF85670:7-3:0.66:10 no Host 7.
# [BasicRule] Passo: 1
# [Time 282] Request RF85670:7-3:0.66:10: Start Time = 279, End Time = 282
# [Time 282] Processando requisição RF856A0:10-0:0.6:1...
# [HighFidelityRoule] Regra fechada e removida do Host 8.
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# [Time 285] Adicionando regra no Host 10
# Decisão aplicada: (Normal E2E,)
# +--------------------+---------+-----------+
# | Match              | Route   | Rule      |
# +====================+=========+===========+
# | (0, (0.5, 0.7), 1) | [10, 0] | BasicRule |
# +--------------------+---------+-----------+
# [Time 285] Atendendo requisição RF856A0:10-0:0.6:1 no Host 10.
# [BasicRule] Passo: 1
# [Time 285] Request RF856A0:10-0:0.6:1: Start Time = 282, End Time = 285
# [Time 285] Processando requisição RF856D0:11-5:0.97:6...
# [HighFidelityRoule] Regra fechada e removida do Host 8.
# +--------------------------------------+------------+-------------------+
# | Match                                | Route      | Rule              |
# +======================================+============+===================+
# | (1, (0.79, 0.99), 9)                 | [11, 0, 1] | BasicRule         |
# +--------------------------------------+------------+-------------------+
# | (2, (0.8, 1.0), 5)                   | [11, 2]    | HighFidelityRoule |
# +--------------------------------------+------------+-------------------+
# | (10, (0.42000000000000004, 0.62), 8) | [11, 10]   | BasicRule         |
# +--------------------------------------+------------+-------------------+
# [Time 288] Adicionando regra no Host 11
# Decisão aplicada: (High Fidelity,)
# +--------------------------------------+------------+-------------------+
# | Match                                | Route      | Rule              |
# +======================================+============+===================+
# | (1, (0.79, 0.99), 9)                 | [11, 0, 1] | BasicRule         |
# +--------------------------------------+------------+-------------------+
# | (2, (0.8, 1.0), 5)                   | [11, 2]    | HighFidelityRoule |
# +--------------------------------------+------------+-------------------+
# | (10, (0.42000000000000004, 0.62), 8) | [11, 10]   | BasicRule         |
# +--------------------------------------+------------+-------------------+
# | (5, (0.87, 1.07), 6)                 | [11, 1, 5] | HighFidelityRoule |
# +--------------------------------------+------------+-------------------+
# [Time 288] Atendendo requisição RF856D0:11-5:0.97:6 no Host 11.
# [Time 288] Request RF856D0:11-5:0.97:6: Start Time = 285, End Time = 288

# %%
import matplotlib.pyplot as plt

def calcular_percentual_atendimento(requisicoes_recebidas, requisicoes_atendidas):
    # Cálculo do percentual de atendimento por modo
    percentual_atendido = {}
    for modo in requisicoes_recebidas:
        total_recebidas = len(requisicoes_recebidas[modo])
        total_atendidas = len(requisicoes_atendidas[modo])
        percentual_atendido[modo] = (total_atendidas / total_recebidas) * 100 if total_recebidas > 0 else 0
    return percentual_atendido

percentual = calcular_percentual_atendimento(received_requests, successful_requests)

# Plotagem do gráfico
plt.figure(figsize=(8, 6))
plt.bar(percentual.keys(), percentual.values(), color=['#4c72b0', '#55a868', '#c44e52'])

plt.xlabel('Modo de Preenchimento')
plt.ylabel('Percentual de Requisições Atendidas (%)')
plt.ylim(0, 100)

# Exibe o valor de cada barra
for i, v in enumerate(percentual.values()):
    plt.text(i, v + 1, f'{v:.1f}%', ha='center')

plt.show()

# %%
def plotar_latencia(requisicoes_por_modo):
    latencias = {'reativo': [], 'proativo': [], 'hibrido': []}
    
    for modo, requisicoes in requisicoes_por_modo.items():
        for request in requisicoes:
            latencia = request.endtime - request.starttime
            latencias[modo].append(latencia)
    
    plt.figure(figsize=(10, 6))
    
    for modo, dados in latencias.items():
        ids = list(range(len(dados)))  # Criar uma sequência de 0 a n para o eixo X
        plt.plot(ids, dados, marker='o', label=modo)
    
    plt.xlabel('Número da Requisição')
    plt.ylabel('Latência (time-slots)')
    plt.title('Comparação de Latência entre Modos')
    plt.legend()
    plt.grid(True)
    plt.show()

plotar_latencia(received_requests)
