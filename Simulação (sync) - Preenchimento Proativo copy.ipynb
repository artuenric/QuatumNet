# %%
from quantumnet.components import Controller, Network
from quantumnet.utils import generate_random_request, register_request
from quantumnet.objects import Request
import asyncio
path = "resultados/proativo/sync.csv"
rede = Network()
controlador = Controller(rede)
row, col = 3, 4
rede.set_ready_topology("Grade", row, col)
# Criação de requisições
fmin_range = (0.5, 1)
neprs_range = (2, 4)
num_requests = 1000
requests = list(generate_random_request(len(rede.hosts)-1, fmin_range, neprs_range) for i in range(num_requests))
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %%
hosts = rede.hosts
for alice in hosts:
    print(f"Adicionando regras para {alice}")
    for bob in hosts:
        controlador.add_match_route_rule_in_host_proactive(alice, bob, 0.5, 5)
        controlador.add_match_route_rule_in_host_proactive(alice, bob, 0.9, 5)
    rede.get_host(alice).draw_flow_table()
# Out:
# Adicionando regras para 0
# +--------------+----------------------+--------------------+
# | Match        | Route                | Rule               |
# +==============+======================+====================+
# | (0, 0.5, 5)  | [0]                  | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (0, 0.9, 5)  | [0]                  | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (1, 0.5, 5)  | [0, 1]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (1, 0.9, 5)  | [0, 1]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (2, 0.5, 5)  | [0, 1, 2]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (2, 0.9, 5)  | [0, 1, 2]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (3, 0.5, 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (3, 0.9, 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (4, 0.5, 5)  | [0, 4]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (4, 0.9, 5)  | [0, 4]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (5, 0.5, 5)  | [0, 1, 5]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (5, 0.9, 5)  | [0, 1, 5]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (6, 0.5, 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (6, 0.9, 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (7, 0.5, 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (7, 0.9, 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (8, 0.5, 5)  | [0, 4, 8]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (8, 0.9, 5)  | [0, 4, 8]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (9, 0.5, 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (9, 0.9, 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (10, 0.5, 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (10, 0.9, 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (11, 0.5, 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (11, 0.9, 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# Adicionando regras para 1
# +--------------+-------------------+--------------------+
# | Match        | Route             | Rule               |
# +==============+===================+====================+
# | (0, 0.5, 5)  | [1, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (0, 0.9, 5)  | [1, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.5, 5)  | [1]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.9, 5)  | [1]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.5, 5)  | [1, 2]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.9, 5)  | [1, 2]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.5, 5)  | [1, 2, 3]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.9, 5)  | [1, 2, 3]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.5, 5)  | [1, 0, 4]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.9, 5)  | [1, 0, 4]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.5, 5)  | [1, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.9, 5)  | [1, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.5, 5)  | [1, 2, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.9, 5)  | [1, 2, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.5, 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.9, 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.5, 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.9, 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.5, 5)  | [1, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.9, 5)  | [1, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.5, 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.9, 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.5, 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.9, 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# Adicionando regras para 2
# +--------------+-----------------+--------------------+
# | Match        | Route           | Rule               |
# +==============+=================+====================+
# | (0, 0.5, 5)  | [2, 1, 0]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (0, 0.9, 5)  | [2, 1, 0]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.5, 5)  | [2, 1]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.9, 5)  | [2, 1]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.5, 5)  | [2]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.9, 5)  | [2]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.5, 5)  | [2, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.9, 5)  | [2, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.5, 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.9, 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.5, 5)  | [2, 1, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.9, 5)  | [2, 1, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.5, 5)  | [2, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.9, 5)  | [2, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.5, 5)  | [2, 3, 7]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.9, 5)  | [2, 3, 7]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.5, 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.9, 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.5, 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.9, 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.5, 5) | [2, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.9, 5) | [2, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.5, 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.9, 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# Adicionando regras para 3
# +--------------+--------------------+--------------------+
# | Match        | Route              | Rule               |
# +==============+====================+====================+
# | (0, 0.5, 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (0, 0.9, 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.5, 5)  | [3, 2, 1]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.9, 5)  | [3, 2, 1]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.5, 5)  | [3, 2]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.9, 5)  | [3, 2]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.5, 5)  | [3]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.9, 5)  | [3]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.5, 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.9, 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.5, 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.9, 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.5, 5)  | [3, 2, 6]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.9, 5)  | [3, 2, 6]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.5, 5)  | [3, 7]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.9, 5)  | [3, 7]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.5, 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.9, 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.5, 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.9, 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.5, 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.9, 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.5, 5) | [3, 7, 11]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.9, 5) | [3, 7, 11]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# Adicionando regras para 4
# +--------------+-------------------+--------------------+
# | Match        | Route             | Rule               |
# +==============+===================+====================+
# | (0, 0.5, 5)  | [4, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (0, 0.9, 5)  | [4, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.5, 5)  | [4, 0, 1]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.9, 5)  | [4, 0, 1]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.5, 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.9, 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.5, 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.9, 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.5, 5)  | [4]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.9, 5)  | [4]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.5, 5)  | [4, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.9, 5)  | [4, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.5, 5)  | [4, 5, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.9, 5)  | [4, 5, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.5, 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.9, 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.5, 5)  | [4, 8]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.9, 5)  | [4, 8]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.5, 5)  | [4, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.9, 5)  | [4, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.5, 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.9, 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.5, 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.9, 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# Adicionando regras para 5
# +--------------+---------------+--------------------+
# | Match        | Route         | Rule               |
# +==============+===============+====================+
# | (0, 0.5, 5)  | [5, 4, 0]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (0, 0.9, 5)  | [5, 4, 0]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (1, 0.5, 5)  | [5, 1]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (1, 0.9, 5)  | [5, 1]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (2, 0.5, 5)  | [5, 1, 2]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (2, 0.9, 5)  | [5, 1, 2]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (3, 0.5, 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (3, 0.9, 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (4, 0.5, 5)  | [5, 4]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (4, 0.9, 5)  | [5, 4]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (5, 0.5, 5)  | [5]           | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (5, 0.9, 5)  | [5]           | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (6, 0.5, 5)  | [5, 6]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (6, 0.9, 5)  | [5, 6]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (7, 0.5, 5)  | [5, 6, 7]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (7, 0.9, 5)  | [5, 6, 7]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (8, 0.5, 5)  | [5, 4, 8]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (8, 0.9, 5)  | [5, 4, 8]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (9, 0.5, 5)  | [5, 9]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (9, 0.9, 5)  | [5, 9]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (10, 0.5, 5) | [5, 6, 10]    | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (10, 0.9, 5) | [5, 6, 10]    | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (11, 0.5, 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (11, 0.9, 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +--------------+---------------+--------------------+
# Adicionando regras para 6
# +--------------+--------------+--------------------+
# | Match        | Route        | Rule               |
# +==============+==============+====================+
# | (0, 0.5, 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (0, 0.9, 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (1, 0.5, 5)  | [6, 5, 1]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (1, 0.9, 5)  | [6, 5, 1]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (2, 0.5, 5)  | [6, 2]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (2, 0.9, 5)  | [6, 2]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (3, 0.5, 5)  | [6, 2, 3]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (3, 0.9, 5)  | [6, 2, 3]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (4, 0.5, 5)  | [6, 5, 4]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (4, 0.9, 5)  | [6, 5, 4]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (5, 0.5, 5)  | [6, 5]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (5, 0.9, 5)  | [6, 5]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (6, 0.5, 5)  | [6]          | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (6, 0.9, 5)  | [6]          | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (7, 0.5, 5)  | [6, 7]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (7, 0.9, 5)  | [6, 7]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (8, 0.5, 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (8, 0.9, 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (9, 0.5, 5)  | [6, 5, 9]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (9, 0.9, 5)  | [6, 5, 9]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (10, 0.5, 5) | [6, 10]      | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (10, 0.9, 5) | [6, 10]      | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (11, 0.5, 5) | [6, 7, 11]   | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (11, 0.9, 5) | [6, 7, 11]   | BasicRuleProactive |
# +--------------+--------------+--------------------+
# Adicionando regras para 7
# +--------------+-----------------+--------------------+
# | Match        | Route           | Rule               |
# +==============+=================+====================+
# | (0, 0.5, 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (0, 0.9, 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.5, 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.9, 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.5, 5)  | [7, 6, 2]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.9, 5)  | [7, 6, 2]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.5, 5)  | [7, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.9, 5)  | [7, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.5, 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.9, 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.5, 5)  | [7, 6, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.9, 5)  | [7, 6, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.5, 5)  | [7, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.9, 5)  | [7, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.5, 5)  | [7]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.9, 5)  | [7]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.5, 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.9, 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.5, 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.9, 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.5, 5) | [7, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.9, 5) | [7, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.5, 5) | [7, 11]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.9, 5) | [7, 11]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# Adicionando regras para 8
# +--------------+--------------------+--------------------+
# | Match        | Route              | Rule               |
# +==============+====================+====================+
# | (0, 0.5, 5)  | [8, 4, 0]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (0, 0.9, 5)  | [8, 4, 0]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.5, 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.9, 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.5, 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.9, 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.5, 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.9, 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.5, 5)  | [8, 4]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.9, 5)  | [8, 4]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.5, 5)  | [8, 4, 5]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.9, 5)  | [8, 4, 5]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.5, 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.9, 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.5, 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.9, 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.5, 5)  | [8]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.9, 5)  | [8]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.5, 5)  | [8, 9]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.9, 5)  | [8, 9]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.5, 5) | [8, 9, 10]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.9, 5) | [8, 9, 10]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.5, 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.9, 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# Adicionando regras para 9
# +--------------+-----------------+--------------------+
# | Match        | Route           | Rule               |
# +==============+=================+====================+
# | (0, 0.5, 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (0, 0.9, 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.5, 5)  | [9, 5, 1]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.9, 5)  | [9, 5, 1]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.5, 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.9, 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.5, 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.9, 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.5, 5)  | [9, 8, 4]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.9, 5)  | [9, 8, 4]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.5, 5)  | [9, 5]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.9, 5)  | [9, 5]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.5, 5)  | [9, 5, 6]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.9, 5)  | [9, 5, 6]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.5, 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.9, 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.5, 5)  | [9, 8]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.9, 5)  | [9, 8]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.5, 5)  | [9]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.9, 5)  | [9]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.5, 5) | [9, 10]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.9, 5) | [9, 10]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.5, 5) | [9, 10, 11]     | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.9, 5) | [9, 10, 11]     | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# Adicionando regras para 10
# +--------------+------------------+--------------------+
# | Match        | Route            | Rule               |
# +==============+==================+====================+
# | (0, 0.5, 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (0, 0.9, 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (1, 0.5, 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (1, 0.9, 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (2, 0.5, 5)  | [10, 6, 2]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (2, 0.9, 5)  | [10, 6, 2]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (3, 0.5, 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (3, 0.9, 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (4, 0.5, 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (4, 0.9, 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (5, 0.5, 5)  | [10, 9, 5]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (5, 0.9, 5)  | [10, 9, 5]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (6, 0.5, 5)  | [10, 6]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (6, 0.9, 5)  | [10, 6]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (7, 0.5, 5)  | [10, 6, 7]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (7, 0.9, 5)  | [10, 6, 7]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (8, 0.5, 5)  | [10, 9, 8]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (8, 0.9, 5)  | [10, 9, 8]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (9, 0.5, 5)  | [10, 9]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (9, 0.9, 5)  | [10, 9]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (10, 0.5, 5) | [10]             | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (10, 0.9, 5) | [10]             | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (11, 0.5, 5) | [10, 11]         | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (11, 0.9, 5) | [10, 11]         | BasicRuleProactive |
# +--------------+------------------+--------------------+
# Adicionando regras para 11
# +--------------+---------------------+--------------------+
# | Match        | Route               | Rule               |
# +==============+=====================+====================+
# | (0, 0.5, 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (0, 0.9, 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (1, 0.5, 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (1, 0.9, 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (2, 0.5, 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (2, 0.9, 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (3, 0.5, 5)  | [11, 7, 3]          | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (3, 0.9, 5)  | [11, 7, 3]          | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (4, 0.5, 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (4, 0.9, 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (5, 0.5, 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (5, 0.9, 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (6, 0.5, 5)  | [11, 10, 6]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (6, 0.9, 5)  | [11, 10, 6]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (7, 0.5, 5)  | [11, 7]             | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (7, 0.9, 5)  | [11, 7]             | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (8, 0.5, 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (8, 0.9, 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (9, 0.5, 5)  | [11, 10, 9]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (9, 0.9, 5)  | [11, 10, 9]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (10, 0.5, 5) | [11, 10]            | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (10, 0.9, 5) | [11, 10]            | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (11, 0.5, 5) | [11]                | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (11, 0.9, 5) | [11]                | BasicRuleProactive |
# +--------------+---------------------+--------------------+

# %%
def simulate_requests_with_timeslots(rede, requests, controlador):
    """
    Simula o processamento de requests com a introdução de timeslots.
    - Demora 1 time-slot se a regra existe.
    - Demora 3 time-slots se uma nova regra precisa ser adicionada.
    """
    current_time = 0  # Tempo global da simulação
    for request in requests:
        print(f"[Time {current_time}]")
        print(f"Request: {request}, Alice: {request.alice}, Bob: {request.bob}, Fmin: {request.fmin}, Neprs: {request.neprs}")
        alice = rede.get_host(request.alice)
        rule = alice.find_rule_by_request(request)

        if rule == False:  # Caso não exista um match na tabela
            request.endtime = current_time
            # Registra no CSV como um novo registro
            register_request(request, "Descartado", path)
        else:  # Caso já exista a regra
            request.starttime = current_time
            controlador.run_rule(rule[1])
            request.endtime = current_time
            
            # Registra no CSV como já registrado
            register_request(request, "Já Registrado", path)
        
        current_time += 1  # Delay de 1 time-slot para execução
        # Exibir informações da requisição
        print(f"Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")

simulate_requests_with_timeslots(rede, requests, controlador)
# Out:
# [Time 0]
# Request: R-197E50, Alice: 5, Bob: 2, Fmin: 0.66, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-197E50: Start Time = 0, End Time = 0
# [Time 1]
# Request: R-19C050, Alice: 10, Bob: 0, Fmin: 0.6, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(10-2-0)
# Running Swap(10-2-0)
# Request R-19C050: Start Time = 1, End Time = 1
# [Time 2]
# Request: R-19C0D0, Alice: 7, Bob: 2, Fmin: 0.67, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(7-6-2)
# Running Swap(7-6-2)
# Request R-19C0D0: Start Time = 2, End Time = 2
# [Time 3]
# Request: R-19C150, Alice: 9, Bob: 4, Fmin: 0.54, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-19C150: Start Time = 3, End Time = 3
# [Time 4]
# Request: R-19C1D0, Alice: 2, Bob: 6, Fmin: 0.52, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Request R-19C1D0: Start Time = 4, End Time = 4
# [Time 5]
# Request: R-19C250, Alice: 9, Bob: 8, Fmin: 0.82, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-19C250: Start Time = 5, End Time = 5
# [Time 6]
# Request: R-19C2D0, Alice: 4, Bob: 5, Fmin: 0.6, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Request R-19C2D0: Start Time = 6, End Time = 6
# [Time 7]
# Request: R-19C350, Alice: 5, Bob: 4, Fmin: 0.67, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Request R-19C350: Start Time = 7, End Time = 7
# [Time 8]
# Request: R-19C3D0, Alice: 0, Bob: 3, Fmin: 0.98, Neprs: 3
# Request R-19C3D0: Start Time = 0, End Time = 8
# [Time 9]
# Request: R-19C4D0, Alice: 5, Bob: 4, Fmin: 0.84, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Request R-19C4D0: Start Time = 9, End Time = 9
# [Time 10]
# Request: R-19C550, Alice: 10, Bob: 1, Fmin: 0.82, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-19C550: Start Time = 10, End Time = 10
# [Time 11]
# Request: R-19C5D0, Alice: 2, Bob: 7, Fmin: 0.71, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Executando ação: CreateEPR(3-7)
# Tempo: 2
# Executando ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request R-19C5D0: Start Time = 11, End Time = 11
# [Time 12]
# Request: R-19C650, Alice: 9, Bob: 10, Fmin: 0.86, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-19C650: Start Time = 12, End Time = 12
# [Time 13]
# Request: R-19C6D0, Alice: 7, Bob: 3, Fmin: 0.91, Neprs: 3
# Request R-19C6D0: Start Time = 0, End Time = 13
# [Time 14]
# Request: R-19C750, Alice: 1, Bob: 3, Fmin: 0.57, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-19C750: Start Time = 14, End Time = 14
# [Time 15]
# Request: R-19C7D0, Alice: 5, Bob: 8, Fmin: 0.52, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(5-4-8)
# Running Swap(5-4-8)
# Request R-19C7D0: Start Time = 15, End Time = 15
# [Time 16]
# Request: R-19C850, Alice: 7, Bob: 0, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(7-2-0)
# Running Swap(7-2-0)
# Request R-19C850: Start Time = 16, End Time = 16
# [Time 17]
# Request: R-19C450, Alice: 9, Bob: 1, Fmin: 0.53, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-19C450: Start Time = 17, End Time = 17
# [Time 18]
# Request: R-19C8D0, Alice: 6, Bob: 8, Fmin: 0.68, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-19C8D0: Start Time = 18, End Time = 18
# [Time 19]
# Request: R-19C950, Alice: 2, Bob: 8, Fmin: 0.6, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Tempo: 3
# Executando ação: Swap(2-0-8)
# Running Swap(2-0-8)
# Request R-19C950: Start Time = 19, End Time = 19
# [Time 20]
# Request: R-19C9D0, Alice: 1, Bob: 6, Fmin: 0.95, Neprs: 2
# Request R-19C9D0: Start Time = 0, End Time = 20
# [Time 21]
# Request: R-19CA50, Alice: 7, Bob: 1, Fmin: 0.9, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Request R-19CA50: Start Time = 21, End Time = 21
# [Time 22]
# Request: R-19CAD0, Alice: 9, Bob: 7, Fmin: 0.99, Neprs: 4
# Request R-19CAD0: Start Time = 0, End Time = 22
# [Time 23]
# Request: R-19CB50, Alice: 5, Bob: 3, Fmin: 0.71, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-19CB50: Start Time = 23, End Time = 23
# [Time 24]
# Request: R-19CBD0, Alice: 1, Bob: 2, Fmin: 0.89, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Request R-19CBD0: Start Time = 24, End Time = 24
# [Time 25]
# Request: R-19CC50, Alice: 9, Bob: 10, Fmin: 0.73, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-19CC50: Start Time = 25, End Time = 25
# [Time 26]
# Request: R-19CCD0, Alice: 9, Bob: 5, Fmin: 0.83, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Request R-19CCD0: Start Time = 26, End Time = 26
# [Time 27]
# Request: R-19CD50, Alice: 10, Bob: 7, Fmin: 0.76, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(10-6-7)
# Running Swap(10-6-7)
# Request R-19CD50: Start Time = 27, End Time = 27
# [Time 28]
# Request: R-19CDD0, Alice: 4, Bob: 8, Fmin: 0.62, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Request R-19CDD0: Start Time = 28, End Time = 28
# [Time 29]
# Request: R-19CE50, Alice: 9, Bob: 5, Fmin: 0.85, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Request R-19CE50: Start Time = 29, End Time = 29
# [Time 30]
# Request: R-19CED0, Alice: 8, Bob: 2, Fmin: 0.76, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-19CED0: Start Time = 30, End Time = 30
# [Time 31]
# Request: R-19CF50, Alice: 6, Bob: 10, Fmin: 0.61, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-10)
# Request R-19CF50: Start Time = 31, End Time = 31
# [Time 32]
# Request: R-19CFD0, Alice: 6, Bob: 8, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-19CFD0: Start Time = 32, End Time = 32
# [Time 33]
# Request: R-19D050, Alice: 9, Bob: 4, Fmin: 0.62, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-19D050: Start Time = 33, End Time = 33
# [Time 34]
# Request: R-19D0D0, Alice: 6, Bob: 5, Fmin: 0.53, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Request R-19D0D0: Start Time = 34, End Time = 34
# [Time 35]
# Request: R-19D150, Alice: 3, Bob: 5, Fmin: 0.99, Neprs: 2
# Request R-19D150: Start Time = 0, End Time = 35
# [Time 36]
# Request: R-19D1D0, Alice: 8, Bob: 5, Fmin: 0.96, Neprs: 4
# Request R-19D1D0: Start Time = 0, End Time = 36
# [Time 37]
# Request: R-19D250, Alice: 7, Bob: 2, Fmin: 0.52, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(7-6-2)
# Running Swap(7-6-2)
# Request R-19D250: Start Time = 37, End Time = 37
# [Time 38]
# Request: R-19D2D0, Alice: 0, Bob: 2, Fmin: 0.62, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-19D2D0: Start Time = 38, End Time = 38
# [Time 39]
# Request: R-19D350, Alice: 9, Bob: 8, Fmin: 0.51, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-19D350: Start Time = 39, End Time = 39
# [Time 40]
# Request: R-19D3D0, Alice: 1, Bob: 9, Fmin: 0.93, Neprs: 2
# Request R-19D3D0: Start Time = 0, End Time = 40
# [Time 41]
# Request: R-19D450, Alice: 7, Bob: 10, Fmin: 0.63, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(7-6-10)
# Running Swap(7-6-10)
# Request R-19D450: Start Time = 41, End Time = 41
# [Time 42]
# Request: R-19D4D0, Alice: 10, Bob: 3, Fmin: 0.86, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-19D4D0: Start Time = 42, End Time = 42
# [Time 43]
# Request: R-19D550, Alice: 4, Bob: 10, Fmin: 0.58, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(4-8-9)
# Running Swap(4-8-9)
# Request R-19D550: Start Time = 43, End Time = 43
# [Time 44]
# Request: R-19D5D0, Alice: 3, Bob: 2, Fmin: 0.76, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Request R-19D5D0: Start Time = 44, End Time = 44
# [Time 45]
# Request: R-19D650, Alice: 6, Bob: 8, Fmin: 0.8, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-19D650: Start Time = 45, End Time = 45
# [Time 46]
# Request: R-19D6D0, Alice: 1, Bob: 10, Fmin: 0.7, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-19D6D0: Start Time = 46, End Time = 46
# [Time 47]
# Request: R-19D750, Alice: 7, Bob: 6, Fmin: 0.86, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Request R-19D750: Start Time = 47, End Time = 47
# [Time 48]
# Request: R-19D7D0, Alice: 3, Bob: 2, Fmin: 0.9, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Request R-19D7D0: Start Time = 48, End Time = 48
# [Time 49]
# Request: R-19D850, Alice: 6, Bob: 1, Fmin: 0.97, Neprs: 3
# Request R-19D850: Start Time = 0, End Time = 49
# [Time 50]
# Request: R-19D8D0, Alice: 4, Bob: 3, Fmin: 0.82, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-19D8D0: Start Time = 50, End Time = 50
# [Time 51]
# Request: R-19D950, Alice: 5, Bob: 10, Fmin: 0.74, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(5-6-10)
# Running Swap(5-6-10)
# Request R-19D950: Start Time = 51, End Time = 51
# [Time 52]
# Request: R-19D9D0, Alice: 6, Bob: 1, Fmin: 0.74, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(6-5-1)
# Running Swap(6-5-1)
# Request R-19D9D0: Start Time = 52, End Time = 52
# [Time 53]
# Request: R-19DA50, Alice: 4, Bob: 9, Fmin: 0.58, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-19DA50: Start Time = 53, End Time = 53
# [Time 54]
# Request: R-19DAD0, Alice: 10, Bob: 8, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-19DAD0: Start Time = 54, End Time = 54
# [Time 55]
# Request: R-19DB50, Alice: 2, Bob: 8, Fmin: 0.58, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Tempo: 3
# Executando ação: Swap(2-0-8)
# Running Swap(2-0-8)
# Request R-19DB50: Start Time = 55, End Time = 55
# [Time 56]
# Request: R-19DBD0, Alice: 8, Bob: 2, Fmin: 0.54, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-19DBD0: Start Time = 56, End Time = 56
# [Time 57]
# Request: R-19DC50, Alice: 8, Bob: 0, Fmin: 0.69, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-19DC50: Start Time = 57, End Time = 57
# [Time 58]
# Request: R-19DCD0, Alice: 0, Bob: 6, Fmin: 0.71, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-19DCD0: Start Time = 58, End Time = 58
# [Time 59]
# Request: R-19DD50, Alice: 10, Bob: 0, Fmin: 0.87, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(10-2-0)
# Running Swap(10-2-0)
# Request R-19DD50: Start Time = 59, End Time = 59
# [Time 60]
# Request: R-19DDD0, Alice: 5, Bob: 10, Fmin: 0.97, Neprs: 4
# Request R-19DDD0: Start Time = 0, End Time = 60
# [Time 61]
# Request: R-19DE50, Alice: 1, Bob: 7, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(1-5-6)
# Running Swap(1-5-6)
# Request R-19DE50: Start Time = 61, End Time = 61
# [Time 62]
# Request: R-19DED0, Alice: 0, Bob: 9, Fmin: 1.0, Neprs: 3
# Request R-19DED0: Start Time = 0, End Time = 62
# [Time 63]
# Request: R-19DF50, Alice: 10, Bob: 8, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-19DF50: Start Time = 63, End Time = 63
# [Time 64]
# Request: R-19DFD0, Alice: 9, Bob: 10, Fmin: 0.85, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-19DFD0: Start Time = 64, End Time = 64
# [Time 65]
# Request: R-19E050, Alice: 1, Bob: 4, Fmin: 0.72, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Request R-19E050: Start Time = 65, End Time = 65
# [Time 66]
# Request: R-19E0D0, Alice: 3, Bob: 2, Fmin: 0.78, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Request R-19E0D0: Start Time = 66, End Time = 66
# [Time 67]
# Request: R-19E150, Alice: 3, Bob: 8, Fmin: 0.76, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-19E150: Start Time = 67, End Time = 67
# [Time 68]
# Request: R-19E1D0, Alice: 1, Bob: 10, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-19E1D0: Start Time = 68, End Time = 68
# [Time 69]
# Request: R-19E250, Alice: 8, Bob: 2, Fmin: 0.69, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-19E250: Start Time = 69, End Time = 69
# [Time 70]
# Request: R-19E2D0, Alice: 2, Bob: 8, Fmin: 0.86, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Tempo: 3
# Executando ação: Swap(2-0-8)
# Running Swap(2-0-8)
# Request R-19E2D0: Start Time = 70, End Time = 70
# [Time 71]
# Request: R-19E350, Alice: 2, Bob: 7, Fmin: 0.99, Neprs: 3
# Request R-19E350: Start Time = 0, End Time = 71
# [Time 72]
# Request: R-19E3D0, Alice: 5, Bob: 0, Fmin: 0.98, Neprs: 2
# Request R-19E3D0: Start Time = 0, End Time = 72
# [Time 73]
# Request: R-19E450, Alice: 10, Bob: 1, Fmin: 0.72, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-19E450: Start Time = 73, End Time = 73
# [Time 74]
# Request: R-19E4D0, Alice: 4, Bob: 7, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-19E4D0: Start Time = 74, End Time = 74
# [Time 75]
# Request: R-19E550, Alice: 2, Bob: 3, Fmin: 0.6, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Request R-19E550: Start Time = 75, End Time = 75
# [Time 76]
# Request: R-19E5D0, Alice: 1, Bob: 0, Fmin: 0.97, Neprs: 3
# Request R-19E5D0: Start Time = 0, End Time = 76
# [Time 77]
# Request: R-19E650, Alice: 5, Bob: 3, Fmin: 0.5, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-19E650: Start Time = 77, End Time = 77
# [Time 78]
# Request: R-19E6D0, Alice: 0, Bob: 10, Fmin: 0.54, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Tempo: 3
# Executando ação: Swap(0-8-10)
# Running Swap(0-8-10)
# Request R-19E6D0: Start Time = 78, End Time = 78
# [Time 79]
# Request: R-19E750, Alice: 6, Bob: 0, Fmin: 0.79, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-19E750: Start Time = 79, End Time = 79
# [Time 80]
# Request: R-19E7D0, Alice: 7, Bob: 0, Fmin: 0.86, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(7-2-0)
# Running Swap(7-2-0)
# Request R-19E7D0: Start Time = 80, End Time = 80
# [Time 81]
# Request: R-19E850, Alice: 6, Bob: 5, Fmin: 0.83, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Request R-19E850: Start Time = 81, End Time = 81
# [Time 82]
# Request: R-19E8D0, Alice: 4, Bob: 2, Fmin: 0.97, Neprs: 4
# Request R-19E8D0: Start Time = 0, End Time = 82
# [Time 83]
# Request: R-19E950, Alice: 10, Bob: 3, Fmin: 0.55, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-19E950: Start Time = 83, End Time = 83
# [Time 84]
# Request: R-19E9D0, Alice: 8, Bob: 5, Fmin: 0.84, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-19E9D0: Start Time = 84, End Time = 84
# [Time 85]
# Request: R-19EA50, Alice: 10, Bob: 6, Fmin: 0.68, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Request R-19EA50: Start Time = 85, End Time = 85
# [Time 86]
# Request: R-19EAD0, Alice: 6, Bob: 10, Fmin: 0.79, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-10)
# Request R-19EAD0: Start Time = 86, End Time = 86
# [Time 87]
# Request: R-19EB50, Alice: 4, Bob: 1, Fmin: 0.56, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-19EB50: Start Time = 87, End Time = 87
# [Time 88]
# Request: R-19EBD0, Alice: 0, Bob: 8, Fmin: 0.52, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-19EBD0: Start Time = 88, End Time = 88
# [Time 89]
# Request: R-19EC50, Alice: 6, Bob: 7, Fmin: 0.7, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-7)
# Request R-19EC50: Start Time = 89, End Time = 89
# [Time 90]
# Request: R-19ECD0, Alice: 3, Bob: 8, Fmin: 0.56, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-19ECD0: Start Time = 90, End Time = 90
# [Time 91]
# Request: R-19ED50, Alice: 4, Bob: 5, Fmin: 0.99, Neprs: 4
# Request R-19ED50: Start Time = 0, End Time = 91
# [Time 92]
# Request: R-19EDD0, Alice: 6, Bob: 8, Fmin: 0.69, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-19EDD0: Start Time = 92, End Time = 92
# [Time 93]
# Request: R-19EE50, Alice: 10, Bob: 8, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-19EE50: Start Time = 93, End Time = 93
# [Time 94]
# Request: R-19EED0, Alice: 8, Bob: 10, Fmin: 0.89, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-19EED0: Start Time = 94, End Time = 94
# [Time 95]
# Request: R-19EF50, Alice: 9, Bob: 4, Fmin: 0.57, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-19EF50: Start Time = 95, End Time = 95
# [Time 96]
# Request: R-19EFD0, Alice: 4, Bob: 1, Fmin: 0.62, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-19EFD0: Start Time = 96, End Time = 96
# [Time 97]
# Request: R-19F050, Alice: 2, Bob: 7, Fmin: 0.71, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Executando ação: CreateEPR(3-7)
# Tempo: 2
# Executando ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request R-19F050: Start Time = 97, End Time = 97
# [Time 98]
# Request: R-19F0D0, Alice: 2, Bob: 6, Fmin: 0.65, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Request R-19F0D0: Start Time = 98, End Time = 98
# [Time 99]
# Request: R-19F150, Alice: 1, Bob: 0, Fmin: 0.77, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Request R-19F150: Start Time = 99, End Time = 99
# [Time 100]
# Request: R-19F1D0, Alice: 10, Bob: 8, Fmin: 0.58, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-19F1D0: Start Time = 100, End Time = 100
# [Time 101]
# Request: R-19F250, Alice: 8, Bob: 4, Fmin: 0.99, Neprs: 2
# Request R-19F250: Start Time = 0, End Time = 101
# [Time 102]
# Request: R-19F2D0, Alice: 7, Bob: 10, Fmin: 0.7, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(7-6-10)
# Running Swap(7-6-10)
# Request R-19F2D0: Start Time = 102, End Time = 102
# [Time 103]
# Request: R-19F350, Alice: 6, Bob: 2, Fmin: 0.61, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-2)
# Request R-19F350: Start Time = 103, End Time = 103
# [Time 104]
# Request: R-19F3D0, Alice: 2, Bob: 3, Fmin: 0.66, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Request R-19F3D0: Start Time = 104, End Time = 104
# [Time 105]
# Request: R-19F450, Alice: 10, Bob: 5, Fmin: 0.75, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-5)
# Tempo: 2
# Executando ação: Swap(10-9-5)
# Running Swap(10-9-5)
# Request R-19F450: Start Time = 105, End Time = 105
# [Time 106]
# Request: R-19F4D0, Alice: 1, Bob: 3, Fmin: 0.76, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-19F4D0: Start Time = 106, End Time = 106
# [Time 107]
# Request: R-19F550, Alice: 9, Bob: 5, Fmin: 0.69, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Request R-19F550: Start Time = 107, End Time = 107
# [Time 108]
# Request: R-19F5D0, Alice: 5, Bob: 4, Fmin: 0.92, Neprs: 3
# Request R-19F5D0: Start Time = 0, End Time = 108
# [Time 109]
# Request: R-19F650, Alice: 8, Bob: 7, Fmin: 0.71, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Tempo: 3
# Executando ação: Swap(8-5-7)
# Running Swap(8-5-7)
# Request R-19F650: Start Time = 109, End Time = 109
# [Time 110]
# Request: R-19F6D0, Alice: 0, Bob: 3, Fmin: 0.58, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-19F6D0: Start Time = 110, End Time = 110
# [Time 111]
# Request: R-19F750, Alice: 2, Bob: 7, Fmin: 0.67, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Executando ação: CreateEPR(3-7)
# Tempo: 2
# Executando ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request R-19F750: Start Time = 111, End Time = 111
# [Time 112]
# Request: R-19F7D0, Alice: 7, Bob: 4, Fmin: 0.52, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-19F7D0: Start Time = 112, End Time = 112
# [Time 113]
# Request: R-19F850, Alice: 4, Bob: 0, Fmin: 0.68, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Request R-19F850: Start Time = 113, End Time = 113
# [Time 114]
# Request: R-19F8D0, Alice: 10, Bob: 2, Fmin: 0.72, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-19F8D0: Start Time = 114, End Time = 114
# [Time 115]
# Request: R-19F950, Alice: 9, Bob: 0, Fmin: 0.51, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-19F950: Start Time = 115, End Time = 115
# [Time 116]
# Request: R-19F9D0, Alice: 10, Bob: 6, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Request R-19F9D0: Start Time = 116, End Time = 116
# [Time 117]
# Request: R-19FA50, Alice: 1, Bob: 5, Fmin: 0.66, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Request R-19FA50: Start Time = 117, End Time = 117
# [Time 118]
# Request: R-19FAD0, Alice: 2, Bob: 5, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Tempo: 2
# Executando ação: Swap(2-1-5)
# Running Swap(2-1-5)
# Request R-19FAD0: Start Time = 118, End Time = 118
# [Time 119]
# Request: R-19FB50, Alice: 7, Bob: 0, Fmin: 0.79, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(7-2-0)
# Running Swap(7-2-0)
# Request R-19FB50: Start Time = 119, End Time = 119
# [Time 120]
# Request: R-19FBD0, Alice: 6, Bob: 8, Fmin: 0.83, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-19FBD0: Start Time = 120, End Time = 120
# [Time 121]
# Request: R-19FC50, Alice: 2, Bob: 8, Fmin: 0.93, Neprs: 2
# Request R-19FC50: Start Time = 0, End Time = 121
# [Time 122]
# Request: R-19FCD0, Alice: 1, Bob: 2, Fmin: 0.81, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Request R-19FCD0: Start Time = 122, End Time = 122
# [Time 123]
# Request: R-19FD50, Alice: 5, Bob: 1, Fmin: 0.66, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-19FD50: Start Time = 123, End Time = 123
# [Time 124]
# Request: R-19FDD0, Alice: 9, Bob: 1, Fmin: 0.84, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-19FDD0: Start Time = 124, End Time = 124
# [Time 125]
# Request: R-19FE50, Alice: 1, Bob: 2, Fmin: 0.84, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Request R-19FE50: Start Time = 125, End Time = 125
# [Time 126]
# Request: R-19FED0, Alice: 2, Bob: 7, Fmin: 0.52, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Executando ação: CreateEPR(3-7)
# Tempo: 2
# Executando ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request R-19FED0: Start Time = 126, End Time = 126
# [Time 127]
# Request: R-19FF50, Alice: 9, Bob: 8, Fmin: 0.63, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-19FF50: Start Time = 127, End Time = 127
# [Time 128]
# Request: R-1A4050, Alice: 1, Bob: 10, Fmin: 0.62, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-1A4050: Start Time = 128, End Time = 128
# [Time 129]
# Request: R-1A40D0, Alice: 2, Bob: 4, Fmin: 0.57, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-1A40D0: Start Time = 129, End Time = 129
# [Time 130]
# Request: R-1A4150, Alice: 6, Bob: 8, Fmin: 0.72, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-1A4150: Start Time = 130, End Time = 130
# [Time 131]
# Request: R-1A41D0, Alice: 4, Bob: 9, Fmin: 0.6, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-1A41D0: Start Time = 131, End Time = 131
# [Time 132]
# Request: R-1A4250, Alice: 1, Bob: 7, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(1-5-6)
# Running Swap(1-5-6)
# Request R-1A4250: Start Time = 132, End Time = 132
# [Time 133]
# Request: R-1A42D0, Alice: 5, Bob: 7, Fmin: 0.99, Neprs: 2
# Request R-1A42D0: Start Time = 0, End Time = 133
# [Time 134]
# Request: R-1A4350, Alice: 9, Bob: 10, Fmin: 0.97, Neprs: 3
# Request R-1A4350: Start Time = 0, End Time = 134
# [Time 135]
# Request: R-1A43D0, Alice: 3, Bob: 0, Fmin: 0.73, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request R-1A43D0: Start Time = 135, End Time = 135
# [Time 136]
# Request: R-1A4450, Alice: 9, Bob: 0, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-1A4450: Start Time = 136, End Time = 136
# [Time 137]
# Request: R-1A44D0, Alice: 3, Bob: 8, Fmin: 0.54, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-1A44D0: Start Time = 137, End Time = 137
# [Time 138]
# Request: R-1A4550, Alice: 8, Bob: 9, Fmin: 0.89, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Request R-1A4550: Start Time = 138, End Time = 138
# [Time 139]
# Request: R-1A45D0, Alice: 8, Bob: 5, Fmin: 0.68, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-1A45D0: Start Time = 139, End Time = 139
# [Time 140]
# Request: R-1A4650, Alice: 1, Bob: 0, Fmin: 0.81, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Request R-1A4650: Start Time = 140, End Time = 140
# [Time 141]
# Request: R-1A46D0, Alice: 7, Bob: 9, Fmin: 0.77, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-1A46D0: Start Time = 141, End Time = 141
# [Time 142]
# Request: R-1A4750, Alice: 0, Bob: 9, Fmin: 0.72, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-1A4750: Start Time = 142, End Time = 142
# [Time 143]
# Request: R-1A47D0, Alice: 0, Bob: 4, Fmin: 0.63, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Request R-1A47D0: Start Time = 143, End Time = 143
# [Time 144]
# Request: R-1A4850, Alice: 5, Bob: 8, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(5-4-8)
# Running Swap(5-4-8)
# Request R-1A4850: Start Time = 144, End Time = 144
# [Time 145]
# Request: R-1A48D0, Alice: 4, Bob: 8, Fmin: 0.88, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Request R-1A48D0: Start Time = 145, End Time = 145
# [Time 146]
# Request: R-1A4950, Alice: 6, Bob: 9, Fmin: 0.82, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(6-5-9)
# Running Swap(6-5-9)
# Request R-1A4950: Start Time = 146, End Time = 146
# [Time 147]
# Request: R-1A49D0, Alice: 10, Bob: 5, Fmin: 0.82, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-5)
# Tempo: 2
# Executando ação: Swap(10-9-5)
# Running Swap(10-9-5)
# Request R-1A49D0: Start Time = 147, End Time = 147
# [Time 148]
# Request: R-1A4A50, Alice: 7, Bob: 0, Fmin: 0.89, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(7-2-0)
# Running Swap(7-2-0)
# Request R-1A4A50: Start Time = 148, End Time = 148
# [Time 149]
# Request: R-1A4AD0, Alice: 8, Bob: 4, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Request R-1A4AD0: Start Time = 149, End Time = 149
# [Time 150]
# Request: R-1A4B50, Alice: 7, Bob: 10, Fmin: 0.7, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(7-6-10)
# Running Swap(7-6-10)
# Request R-1A4B50: Start Time = 150, End Time = 150
# [Time 151]
# Request: R-1A4BD0, Alice: 0, Bob: 4, Fmin: 0.7, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Request R-1A4BD0: Start Time = 151, End Time = 151
# [Time 152]
# Request: R-1A4C50, Alice: 1, Bob: 2, Fmin: 0.7, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Request R-1A4C50: Start Time = 152, End Time = 152
# [Time 153]
# Request: R-1A4CD0, Alice: 4, Bob: 6, Fmin: 0.88, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-1A4CD0: Start Time = 153, End Time = 153
# [Time 154]
# Request: R-1A4D50, Alice: 7, Bob: 3, Fmin: 0.83, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Request R-1A4D50: Start Time = 154, End Time = 154
# [Time 155]
# Request: R-1A4DD0, Alice: 9, Bob: 0, Fmin: 0.79, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-1A4DD0: Start Time = 155, End Time = 155
# [Time 156]
# Request: R-1A4E50, Alice: 2, Bob: 10, Fmin: 0.7, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(2-6-10)
# Running Swap(2-6-10)
# Request R-1A4E50: Start Time = 156, End Time = 156
# [Time 157]
# Request: R-1A4ED0, Alice: 10, Bob: 7, Fmin: 0.91, Neprs: 3
# Request R-1A4ED0: Start Time = 0, End Time = 157
# [Time 158]
# Request: R-1A4F50, Alice: 5, Bob: 0, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(5-4-0)
# Running Swap(5-4-0)
# Request R-1A4F50: Start Time = 158, End Time = 158
# [Time 159]
# Request: R-1A4FD0, Alice: 3, Bob: 4, Fmin: 0.95, Neprs: 3
# Request R-1A4FD0: Start Time = 0, End Time = 159
# [Time 160]
# Request: R-1A5050, Alice: 7, Bob: 3, Fmin: 0.62, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Request R-1A5050: Start Time = 160, End Time = 160
# [Time 161]
# Request: R-1A50D0, Alice: 8, Bob: 10, Fmin: 0.91, Neprs: 2
# Request R-1A50D0: Start Time = 0, End Time = 161
# [Time 162]
# Request: R-1A5150, Alice: 4, Bob: 1, Fmin: 0.7, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-1A5150: Start Time = 162, End Time = 162
# [Time 163]
# Request: R-1A51D0, Alice: 0, Bob: 6, Fmin: 0.85, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-1A51D0: Start Time = 163, End Time = 163
# [Time 164]
# Request: R-1A5250, Alice: 8, Bob: 2, Fmin: 0.78, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-1A5250: Start Time = 164, End Time = 164
# [Time 165]
# Request: R-1A52D0, Alice: 6, Bob: 5, Fmin: 0.58, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Request R-1A52D0: Start Time = 165, End Time = 165
# [Time 166]
# Request: R-1A5350, Alice: 6, Bob: 9, Fmin: 0.51, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(6-5-9)
# Running Swap(6-5-9)
# Request R-1A5350: Start Time = 166, End Time = 166
# [Time 167]
# Request: R-1A53D0, Alice: 0, Bob: 5, Fmin: 0.97, Neprs: 3
# Request R-1A53D0: Start Time = 0, End Time = 167
# [Time 168]
# Request: R-1A5450, Alice: 9, Bob: 2, Fmin: 0.67, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-1A5450: Start Time = 168, End Time = 168
# [Time 169]
# Request: R-1A54D0, Alice: 5, Bob: 10, Fmin: 0.97, Neprs: 3
# Request R-1A54D0: Start Time = 0, End Time = 169
# [Time 170]
# Request: R-1A5550, Alice: 5, Bob: 2, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-1A5550: Start Time = 170, End Time = 170
# [Time 171]
# Request: R-1A55D0, Alice: 8, Bob: 6, Fmin: 0.93, Neprs: 3
# Request R-1A55D0: Start Time = 0, End Time = 171
# [Time 172]
# Request: R-1A5650, Alice: 9, Bob: 6, Fmin: 0.83, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-1A5650: Start Time = 172, End Time = 172
# [Time 173]
# Request: R-1A56D0, Alice: 10, Bob: 0, Fmin: 0.62, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(10-2-0)
# Running Swap(10-2-0)
# Request R-1A56D0: Start Time = 173, End Time = 173
# [Time 174]
# Request: R-1A5750, Alice: 2, Bob: 8, Fmin: 0.95, Neprs: 2
# Request R-1A5750: Start Time = 0, End Time = 174
# [Time 175]
# Request: R-1A57D0, Alice: 8, Bob: 7, Fmin: 0.85, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Tempo: 3
# Executando ação: Swap(8-5-7)
# Running Swap(8-5-7)
# Request R-1A57D0: Start Time = 175, End Time = 175
# [Time 176]
# Request: R-1A5850, Alice: 9, Bob: 0, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-1A5850: Start Time = 176, End Time = 176
# [Time 177]
# Request: R-1A58D0, Alice: 1, Bob: 8, Fmin: 0.73, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Request R-1A58D0: Start Time = 177, End Time = 177
# [Time 178]
# Request: R-1A5950, Alice: 8, Bob: 0, Fmin: 0.68, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-1A5950: Start Time = 178, End Time = 178
# [Time 179]
# Request: R-1A59D0, Alice: 4, Bob: 2, Fmin: 0.59, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-1A59D0: Start Time = 179, End Time = 179
# [Time 180]
# Request: R-1A5A50, Alice: 3, Bob: 9, Fmin: 0.77, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Tempo: 3
# Executando ação: Swap(3-1-9)
# Running Swap(3-1-9)
# Request R-1A5A50: Start Time = 180, End Time = 180
# [Time 181]
# Request: R-1A5AD0, Alice: 6, Bob: 5, Fmin: 0.76, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Request R-1A5AD0: Start Time = 181, End Time = 181
# [Time 182]
# Request: R-1A5B50, Alice: 9, Bob: 10, Fmin: 0.8, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-1A5B50: Start Time = 182, End Time = 182
# [Time 183]
# Request: R-1A5BD0, Alice: 4, Bob: 10, Fmin: 0.81, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(4-8-9)
# Running Swap(4-8-9)
# Request R-1A5BD0: Start Time = 183, End Time = 183
# [Time 184]
# Request: R-1A5C50, Alice: 4, Bob: 9, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-1A5C50: Start Time = 184, End Time = 184
# [Time 185]
# Request: R-1A5CD0, Alice: 4, Bob: 9, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-1A5CD0: Start Time = 185, End Time = 185
# [Time 186]
# Request: R-1A5D50, Alice: 6, Bob: 2, Fmin: 0.67, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-2)
# Request R-1A5D50: Start Time = 186, End Time = 186
# [Time 187]
# Request: R-1A5DD0, Alice: 4, Bob: 8, Fmin: 0.53, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Request R-1A5DD0: Start Time = 187, End Time = 187
# [Time 188]
# Request: R-1A5E50, Alice: 1, Bob: 3, Fmin: 0.95, Neprs: 3
# Request R-1A5E50: Start Time = 0, End Time = 188
# [Time 189]
# Request: R-1A5ED0, Alice: 1, Bob: 0, Fmin: 0.83, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Request R-1A5ED0: Start Time = 189, End Time = 189
# [Time 190]
# Request: R-1A5F50, Alice: 10, Bob: 4, Fmin: 0.73, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request R-1A5F50: Start Time = 190, End Time = 190
# [Time 191]
# Request: R-1A5FD0, Alice: 8, Bob: 10, Fmin: 0.86, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-1A5FD0: Start Time = 191, End Time = 191
# [Time 192]
# Request: R-1A6050, Alice: 9, Bob: 1, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-1A6050: Start Time = 192, End Time = 192
# [Time 193]
# Request: R-1A60D0, Alice: 9, Bob: 4, Fmin: 0.58, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-1A60D0: Start Time = 193, End Time = 193
# [Time 194]
# Request: R-1A6150, Alice: 6, Bob: 10, Fmin: 0.86, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-10)
# Request R-1A6150: Start Time = 194, End Time = 194
# [Time 195]
# Request: R-1A61D0, Alice: 5, Bob: 3, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-1A61D0: Start Time = 195, End Time = 195
# [Time 196]
# Request: R-1A6250, Alice: 0, Bob: 6, Fmin: 0.55, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-1A6250: Start Time = 196, End Time = 196
# [Time 197]
# Request: R-1A62D0, Alice: 1, Bob: 5, Fmin: 0.77, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Request R-1A62D0: Start Time = 197, End Time = 197
# [Time 198]
# Request: R-1A6350, Alice: 3, Bob: 0, Fmin: 0.84, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request R-1A6350: Start Time = 198, End Time = 198
# [Time 199]
# Request: R-1A63D0, Alice: 2, Bob: 4, Fmin: 0.92, Neprs: 4
# Request R-1A63D0: Start Time = 0, End Time = 199
# [Time 200]
# Request: R-1A6450, Alice: 4, Bob: 2, Fmin: 0.78, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-1A6450: Start Time = 200, End Time = 200
# [Time 201]
# Request: R-1A64D0, Alice: 1, Bob: 6, Fmin: 0.72, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-1A64D0: Start Time = 201, End Time = 201
# [Time 202]
# Request: R-1A6550, Alice: 0, Bob: 2, Fmin: 0.85, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-1A6550: Start Time = 202, End Time = 202
# [Time 203]
# Request: R-1A65D0, Alice: 5, Bob: 3, Fmin: 0.65, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-1A65D0: Start Time = 203, End Time = 203
# [Time 204]
# Request: R-1A6650, Alice: 5, Bob: 2, Fmin: 0.54, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-1A6650: Start Time = 204, End Time = 204
# [Time 205]
# Request: R-1A66D0, Alice: 8, Bob: 2, Fmin: 0.77, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# ...
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-1C15D0: Start Time = 933, End Time = 933
# [Time 934]
# Request: R-1C1650, Alice: 10, Bob: 4, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request R-1C1650: Start Time = 934, End Time = 934
# [Time 935]
# Request: R-1C16D0, Alice: 8, Bob: 6, Fmin: 0.71, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-1C16D0: Start Time = 935, End Time = 935
# [Time 936]
# Request: R-1C1750, Alice: 10, Bob: 4, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request R-1C1750: Start Time = 936, End Time = 936
# [Time 937]
# Request: R-1C17D0, Alice: 9, Bob: 10, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-1C17D0: Start Time = 937, End Time = 937
# [Time 938]
# Request: R-1C1850, Alice: 0, Bob: 8, Fmin: 0.81, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-1C1850: Start Time = 938, End Time = 938
# [Time 939]
# Request: R-1C18D0, Alice: 4, Bob: 2, Fmin: 0.72, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-1C18D0: Start Time = 939, End Time = 939
# [Time 940]
# Request: R-1C1950, Alice: 0, Bob: 9, Fmin: 0.61, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-1C1950: Start Time = 940, End Time = 940
# [Time 941]
# Request: R-1C19D0, Alice: 7, Bob: 0, Fmin: 0.7, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(7-2-0)
# Running Swap(7-2-0)
# Request R-1C19D0: Start Time = 941, End Time = 941
# [Time 942]
# Request: R-1C1A50, Alice: 6, Bob: 4, Fmin: 0.54, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-1C1A50: Start Time = 942, End Time = 942
# [Time 943]
# Request: R-1C1AD0, Alice: 6, Bob: 10, Fmin: 0.75, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-10)
# Request R-1C1AD0: Start Time = 943, End Time = 943
# [Time 944]
# Request: R-1C1B50, Alice: 5, Bob: 8, Fmin: 0.55, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(5-4-8)
# Running Swap(5-4-8)
# Request R-1C1B50: Start Time = 944, End Time = 944
# [Time 945]
# Request: R-1C1BD0, Alice: 6, Bob: 0, Fmin: 0.51, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-1C1BD0: Start Time = 945, End Time = 945
# [Time 946]
# Request: R-1C1C50, Alice: 4, Bob: 7, Fmin: 0.79, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-1C1C50: Start Time = 946, End Time = 946
# [Time 947]
# Request: R-1C1CD0, Alice: 3, Bob: 9, Fmin: 0.55, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Tempo: 3
# Executando ação: Swap(3-1-9)
# Running Swap(3-1-9)
# Request R-1C1CD0: Start Time = 947, End Time = 947
# [Time 948]
# Request: R-1C1D50, Alice: 8, Bob: 4, Fmin: 0.75, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Request R-1C1D50: Start Time = 948, End Time = 948
# [Time 949]
# Request: R-1C1DD0, Alice: 6, Bob: 9, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(6-5-9)
# Running Swap(6-5-9)
# Request R-1C1DD0: Start Time = 949, End Time = 949
# [Time 950]
# Request: R-1C1E50, Alice: 2, Bob: 0, Fmin: 0.59, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-1C1E50: Start Time = 950, End Time = 950
# [Time 951]
# Request: R-1C1ED0, Alice: 9, Bob: 2, Fmin: 0.53, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-1C1ED0: Start Time = 951, End Time = 951
# [Time 952]
# Request: R-1C1F50, Alice: 7, Bob: 9, Fmin: 0.65, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-1C1F50: Start Time = 952, End Time = 952
# [Time 953]
# Request: R-1C1FD0, Alice: 5, Bob: 4, Fmin: 0.87, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Request R-1C1FD0: Start Time = 953, End Time = 953
# [Time 954]
# Request: R-1C2050, Alice: 8, Bob: 1, Fmin: 0.54, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-1C2050: Start Time = 954, End Time = 954
# [Time 955]
# Request: R-1C20D0, Alice: 8, Bob: 1, Fmin: 1.0, Neprs: 3
# Request R-1C20D0: Start Time = 0, End Time = 955
# [Time 956]
# Request: R-1C2150, Alice: 3, Bob: 10, Fmin: 0.93, Neprs: 4
# Request R-1C2150: Start Time = 0, End Time = 956
# [Time 957]
# Request: R-1C21D0, Alice: 9, Bob: 6, Fmin: 0.97, Neprs: 4
# Request R-1C21D0: Start Time = 0, End Time = 957
# [Time 958]
# Request: R-1C2250, Alice: 10, Bob: 1, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-1C2250: Start Time = 958, End Time = 958
# [Time 959]
# Request: R-1C22D0, Alice: 4, Bob: 7, Fmin: 0.88, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-1C22D0: Start Time = 959, End Time = 959
# [Time 960]
# Request: R-1C2350, Alice: 2, Bob: 3, Fmin: 0.8, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Request R-1C2350: Start Time = 960, End Time = 960
# [Time 961]
# Request: R-1C23D0, Alice: 7, Bob: 6, Fmin: 0.88, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Request R-1C23D0: Start Time = 961, End Time = 961
# [Time 962]
# Request: R-1C2450, Alice: 6, Bob: 7, Fmin: 0.86, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-7)
# Request R-1C2450: Start Time = 962, End Time = 962
# [Time 963]
# Request: R-1C24D0, Alice: 1, Bob: 9, Fmin: 0.79, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-1C24D0: Start Time = 963, End Time = 963
# [Time 964]
# Request: R-1C2550, Alice: 2, Bob: 3, Fmin: 0.9, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Request R-1C2550: Start Time = 964, End Time = 964
# [Time 965]
# Request: R-1C25D0, Alice: 2, Bob: 1, Fmin: 0.98, Neprs: 2
# Request R-1C25D0: Start Time = 0, End Time = 965
# [Time 966]
# Request: R-1C2650, Alice: 4, Bob: 3, Fmin: 0.69, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-1C2650: Start Time = 966, End Time = 966
# [Time 967]
# Request: R-1C26D0, Alice: 4, Bob: 2, Fmin: 0.98, Neprs: 4
# Request R-1C26D0: Start Time = 0, End Time = 967
# [Time 968]
# Request: R-1C2750, Alice: 4, Bob: 1, Fmin: 0.57, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Request R-1C2750: Start Time = 968, End Time = 968
# [Time 969]
# Request: R-1C27D0, Alice: 8, Bob: 6, Fmin: 0.51, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-1C27D0: Start Time = 969, End Time = 969
# [Time 970]
# Request: R-1C2850, Alice: 2, Bob: 3, Fmin: 0.98, Neprs: 3
# Request R-1C2850: Start Time = 0, End Time = 970
# [Time 971]
# Request: R-1C28D0, Alice: 7, Bob: 2, Fmin: 0.55, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(7-6-2)
# Running Swap(7-6-2)
# Request R-1C28D0: Start Time = 971, End Time = 971
# [Time 972]
# Request: R-1C2950, Alice: 9, Bob: 3, Fmin: 0.99, Neprs: 2
# Request R-1C2950: Start Time = 0, End Time = 972
# [Time 973]
# Request: R-1C29D0, Alice: 8, Bob: 3, Fmin: 0.9, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-1C29D0: Start Time = 973, End Time = 973
# [Time 974]
# Request: R-1C2A50, Alice: 5, Bob: 3, Fmin: 0.72, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-1C2A50: Start Time = 974, End Time = 974
# [Time 975]
# Request: R-1C2AD0, Alice: 8, Bob: 10, Fmin: 0.87, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-1C2AD0: Start Time = 975, End Time = 975
# [Time 976]
# Request: R-1C2B50, Alice: 2, Bob: 5, Fmin: 0.67, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Tempo: 2
# Executando ação: Swap(2-1-5)
# Running Swap(2-1-5)
# Request R-1C2B50: Start Time = 976, End Time = 976
# [Time 977]
# Request: R-1C2BD0, Alice: 10, Bob: 4, Fmin: 0.88, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request R-1C2BD0: Start Time = 977, End Time = 977
# [Time 978]
# Request: R-1C2C50, Alice: 3, Bob: 4, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-1C2C50: Start Time = 978, End Time = 978
# [Time 979]
# Request: R-1C2CD0, Alice: 3, Bob: 4, Fmin: 0.54, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-1C2CD0: Start Time = 979, End Time = 979
# [Time 980]
# Request: R-1C2D50, Alice: 0, Bob: 3, Fmin: 0.75, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-1C2D50: Start Time = 980, End Time = 980
# [Time 981]
# Request: R-1C2DD0, Alice: 10, Bob: 9, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Request R-1C2DD0: Start Time = 981, End Time = 981
# [Time 982]
# Request: R-1C2E50, Alice: 9, Bob: 4, Fmin: 0.55, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-1C2E50: Start Time = 982, End Time = 982
# [Time 983]
# Request: R-1C2ED0, Alice: 5, Bob: 4, Fmin: 0.94, Neprs: 2
# Request R-1C2ED0: Start Time = 0, End Time = 983
# [Time 984]
# Request: R-1C2F50, Alice: 9, Bob: 5, Fmin: 0.76, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Request R-1C2F50: Start Time = 984, End Time = 984
# [Time 985]
# Request: R-1C2FD0, Alice: 3, Bob: 4, Fmin: 0.73, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-1C2FD0: Start Time = 985, End Time = 985
# [Time 986]
# Request: R-1C3050, Alice: 8, Bob: 0, Fmin: 0.89, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-1C3050: Start Time = 986, End Time = 986
# [Time 987]
# Request: R-1C30D0, Alice: 1, Bob: 6, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-1C30D0: Start Time = 987, End Time = 987
# [Time 988]
# Request: R-1C3150, Alice: 9, Bob: 6, Fmin: 0.86, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-1C3150: Start Time = 988, End Time = 988
# [Time 989]
# Request: R-1C31D0, Alice: 0, Bob: 4, Fmin: 0.78, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Request R-1C31D0: Start Time = 989, End Time = 989
# [Time 990]
# Request: R-1C3250, Alice: 1, Bob: 0, Fmin: 0.97, Neprs: 2
# Request R-1C3250: Start Time = 0, End Time = 990
# [Time 991]
# Request: R-1C32D0, Alice: 6, Bob: 3, Fmin: 0.88, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(6-2-3)
# Running Swap(6-2-3)
# Request R-1C32D0: Start Time = 991, End Time = 991
# [Time 992]
# Request: R-1C3350, Alice: 6, Bob: 9, Fmin: 0.69, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(6-5-9)
# Running Swap(6-5-9)
# Request R-1C3350: Start Time = 992, End Time = 992
# [Time 993]
# Request: R-1C33D0, Alice: 10, Bob: 2, Fmin: 0.89, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-1C33D0: Start Time = 993, End Time = 993
# [Time 994]
# Request: R-1C3450, Alice: 0, Bob: 8, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-1C3450: Start Time = 994, End Time = 994
# [Time 995]
# Request: R-1C34D0, Alice: 10, Bob: 1, Fmin: 0.56, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-1C34D0: Start Time = 995, End Time = 995
# [Time 996]
# Request: R-1C3550, Alice: 3, Bob: 0, Fmin: 0.94, Neprs: 4
# Request R-1C3550: Start Time = 0, End Time = 996
# [Time 997]
# Request: R-1C35D0, Alice: 4, Bob: 10, Fmin: 0.58, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(4-8-9)
# Running Swap(4-8-9)
# Request R-1C35D0: Start Time = 997, End Time = 997
# [Time 998]
# Request: R-1C3650, Alice: 8, Bob: 9, Fmin: 0.78, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Request R-1C3650: Start Time = 998, End Time = 998
# [Time 999]
# Request: R-1C36D0, Alice: 7, Bob: 10, Fmin: 0.95, Neprs: 4
# Request R-1C36D0: Start Time = 0, End Time = 999
