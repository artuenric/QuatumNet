# %%
from quantumnet.components import Controller, Network
from quantumnet.utils import generate_random_request, register_request
from quantumnet.objects import Request
import asyncio
path = "resultados/proativo/sync.csv"
rede = Network()
controlador = Controller(rede)
row, col = 3, 4
rede.set_ready_topology("Grade", row, col)
# Criação de requisições
fmin_range = (0.5, 1)
neprs_range = (2, 4)
num_requests = 1000
requests = list(generate_random_request(len(rede.hosts)-1, fmin_range, neprs_range) for i in range(num_requests))
# Out:
# Hosts inicializados
# Canais inicializados
# Pares EPRs adicionados

# %%
hosts = rede.hosts
for alice in hosts:
    print(f"Adicionando regras para {alice}")
    for bob in hosts:
        controlador.add_match_route_rule_in_host_proactive(alice, bob, 0.5, 5)
        controlador.add_match_route_rule_in_host_proactive(alice, bob, 0.9, 5)
    rede.get_host(alice).draw_flow_table()
# Out:
# Adicionando regras para 0
# +--------------+----------------------+--------------------+
# | Match        | Route                | Rule               |
# +==============+======================+====================+
# | (0, 0.5, 5)  | [0]                  | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (0, 0.9, 5)  | [0]                  | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (1, 0.5, 5)  | [0, 1]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (1, 0.9, 5)  | [0, 1]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (2, 0.5, 5)  | [0, 1, 2]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (2, 0.9, 5)  | [0, 1, 2]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (3, 0.5, 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (3, 0.9, 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (4, 0.5, 5)  | [0, 4]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (4, 0.9, 5)  | [0, 4]               | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (5, 0.5, 5)  | [0, 1, 5]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (5, 0.9, 5)  | [0, 1, 5]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (6, 0.5, 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (6, 0.9, 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (7, 0.5, 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (7, 0.9, 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (8, 0.5, 5)  | [0, 4, 8]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (8, 0.9, 5)  | [0, 4, 8]            | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (9, 0.5, 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (9, 0.9, 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (10, 0.5, 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (10, 0.9, 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (11, 0.5, 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# | (11, 0.9, 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+----------------------+--------------------+
# Adicionando regras para 1
# +--------------+-------------------+--------------------+
# | Match        | Route             | Rule               |
# +==============+===================+====================+
# | (0, 0.5, 5)  | [1, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (0, 0.9, 5)  | [1, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.5, 5)  | [1]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.9, 5)  | [1]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.5, 5)  | [1, 2]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.9, 5)  | [1, 2]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.5, 5)  | [1, 2, 3]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.9, 5)  | [1, 2, 3]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.5, 5)  | [1, 0, 4]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.9, 5)  | [1, 0, 4]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.5, 5)  | [1, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.9, 5)  | [1, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.5, 5)  | [1, 2, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.9, 5)  | [1, 2, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.5, 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.9, 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.5, 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.9, 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.5, 5)  | [1, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.9, 5)  | [1, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.5, 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.9, 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.5, 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.9, 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# Adicionando regras para 2
# +--------------+-----------------+--------------------+
# | Match        | Route           | Rule               |
# +==============+=================+====================+
# | (0, 0.5, 5)  | [2, 1, 0]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (0, 0.9, 5)  | [2, 1, 0]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.5, 5)  | [2, 1]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.9, 5)  | [2, 1]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.5, 5)  | [2]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.9, 5)  | [2]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.5, 5)  | [2, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.9, 5)  | [2, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.5, 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.9, 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.5, 5)  | [2, 1, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.9, 5)  | [2, 1, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.5, 5)  | [2, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.9, 5)  | [2, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.5, 5)  | [2, 3, 7]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.9, 5)  | [2, 3, 7]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.5, 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.9, 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.5, 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.9, 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.5, 5) | [2, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.9, 5) | [2, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.5, 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.9, 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# Adicionando regras para 3
# +--------------+--------------------+--------------------+
# | Match        | Route              | Rule               |
# +==============+====================+====================+
# | (0, 0.5, 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (0, 0.9, 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.5, 5)  | [3, 2, 1]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.9, 5)  | [3, 2, 1]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.5, 5)  | [3, 2]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.9, 5)  | [3, 2]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.5, 5)  | [3]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.9, 5)  | [3]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.5, 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.9, 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.5, 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.9, 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.5, 5)  | [3, 2, 6]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.9, 5)  | [3, 2, 6]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.5, 5)  | [3, 7]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.9, 5)  | [3, 7]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.5, 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.9, 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.5, 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.9, 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.5, 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.9, 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.5, 5) | [3, 7, 11]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.9, 5) | [3, 7, 11]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# Adicionando regras para 4
# +--------------+-------------------+--------------------+
# | Match        | Route             | Rule               |
# +==============+===================+====================+
# | (0, 0.5, 5)  | [4, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (0, 0.9, 5)  | [4, 0]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.5, 5)  | [4, 0, 1]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (1, 0.9, 5)  | [4, 0, 1]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.5, 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (2, 0.9, 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.5, 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (3, 0.9, 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.5, 5)  | [4]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (4, 0.9, 5)  | [4]               | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.5, 5)  | [4, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (5, 0.9, 5)  | [4, 5]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.5, 5)  | [4, 5, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (6, 0.9, 5)  | [4, 5, 6]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.5, 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (7, 0.9, 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.5, 5)  | [4, 8]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (8, 0.9, 5)  | [4, 8]            | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.5, 5)  | [4, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (9, 0.9, 5)  | [4, 5, 9]         | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.5, 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (10, 0.9, 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.5, 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# | (11, 0.9, 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +--------------+-------------------+--------------------+
# Adicionando regras para 5
# +--------------+---------------+--------------------+
# | Match        | Route         | Rule               |
# +==============+===============+====================+
# | (0, 0.5, 5)  | [5, 4, 0]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (0, 0.9, 5)  | [5, 4, 0]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (1, 0.5, 5)  | [5, 1]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (1, 0.9, 5)  | [5, 1]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (2, 0.5, 5)  | [5, 1, 2]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (2, 0.9, 5)  | [5, 1, 2]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (3, 0.5, 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (3, 0.9, 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (4, 0.5, 5)  | [5, 4]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (4, 0.9, 5)  | [5, 4]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (5, 0.5, 5)  | [5]           | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (5, 0.9, 5)  | [5]           | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (6, 0.5, 5)  | [5, 6]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (6, 0.9, 5)  | [5, 6]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (7, 0.5, 5)  | [5, 6, 7]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (7, 0.9, 5)  | [5, 6, 7]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (8, 0.5, 5)  | [5, 4, 8]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (8, 0.9, 5)  | [5, 4, 8]     | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (9, 0.5, 5)  | [5, 9]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (9, 0.9, 5)  | [5, 9]        | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (10, 0.5, 5) | [5, 6, 10]    | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (10, 0.9, 5) | [5, 6, 10]    | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (11, 0.5, 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +--------------+---------------+--------------------+
# | (11, 0.9, 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +--------------+---------------+--------------------+
# Adicionando regras para 6
# +--------------+--------------+--------------------+
# | Match        | Route        | Rule               |
# +==============+==============+====================+
# | (0, 0.5, 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (0, 0.9, 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (1, 0.5, 5)  | [6, 5, 1]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (1, 0.9, 5)  | [6, 5, 1]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (2, 0.5, 5)  | [6, 2]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (2, 0.9, 5)  | [6, 2]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (3, 0.5, 5)  | [6, 2, 3]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (3, 0.9, 5)  | [6, 2, 3]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (4, 0.5, 5)  | [6, 5, 4]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (4, 0.9, 5)  | [6, 5, 4]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (5, 0.5, 5)  | [6, 5]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (5, 0.9, 5)  | [6, 5]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (6, 0.5, 5)  | [6]          | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (6, 0.9, 5)  | [6]          | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (7, 0.5, 5)  | [6, 7]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (7, 0.9, 5)  | [6, 7]       | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (8, 0.5, 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (8, 0.9, 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (9, 0.5, 5)  | [6, 5, 9]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (9, 0.9, 5)  | [6, 5, 9]    | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (10, 0.5, 5) | [6, 10]      | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (10, 0.9, 5) | [6, 10]      | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (11, 0.5, 5) | [6, 7, 11]   | BasicRuleProactive |
# +--------------+--------------+--------------------+
# | (11, 0.9, 5) | [6, 7, 11]   | BasicRuleProactive |
# +--------------+--------------+--------------------+
# Adicionando regras para 7
# +--------------+-----------------+--------------------+
# | Match        | Route           | Rule               |
# +==============+=================+====================+
# | (0, 0.5, 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (0, 0.9, 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.5, 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.9, 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.5, 5)  | [7, 6, 2]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.9, 5)  | [7, 6, 2]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.5, 5)  | [7, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.9, 5)  | [7, 3]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.5, 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.9, 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.5, 5)  | [7, 6, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.9, 5)  | [7, 6, 5]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.5, 5)  | [7, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.9, 5)  | [7, 6]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.5, 5)  | [7]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.9, 5)  | [7]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.5, 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.9, 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.5, 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.9, 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.5, 5) | [7, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.9, 5) | [7, 6, 10]      | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.5, 5) | [7, 11]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.9, 5) | [7, 11]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# Adicionando regras para 8
# +--------------+--------------------+--------------------+
# | Match        | Route              | Rule               |
# +==============+====================+====================+
# | (0, 0.5, 5)  | [8, 4, 0]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (0, 0.9, 5)  | [8, 4, 0]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.5, 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (1, 0.9, 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.5, 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (2, 0.9, 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.5, 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (3, 0.9, 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.5, 5)  | [8, 4]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (4, 0.9, 5)  | [8, 4]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.5, 5)  | [8, 4, 5]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (5, 0.9, 5)  | [8, 4, 5]          | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.5, 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (6, 0.9, 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.5, 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (7, 0.9, 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.5, 5)  | [8]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (8, 0.9, 5)  | [8]                | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.5, 5)  | [8, 9]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (9, 0.9, 5)  | [8, 9]             | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.5, 5) | [8, 9, 10]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (10, 0.9, 5) | [8, 9, 10]         | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.5, 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# | (11, 0.9, 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +--------------+--------------------+--------------------+
# Adicionando regras para 9
# +--------------+-----------------+--------------------+
# | Match        | Route           | Rule               |
# +==============+=================+====================+
# | (0, 0.5, 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (0, 0.9, 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.5, 5)  | [9, 5, 1]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (1, 0.9, 5)  | [9, 5, 1]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.5, 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (2, 0.9, 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.5, 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (3, 0.9, 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.5, 5)  | [9, 8, 4]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (4, 0.9, 5)  | [9, 8, 4]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.5, 5)  | [9, 5]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (5, 0.9, 5)  | [9, 5]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.5, 5)  | [9, 5, 6]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (6, 0.9, 5)  | [9, 5, 6]       | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.5, 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (7, 0.9, 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.5, 5)  | [9, 8]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (8, 0.9, 5)  | [9, 8]          | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.5, 5)  | [9]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (9, 0.9, 5)  | [9]             | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.5, 5) | [9, 10]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (10, 0.9, 5) | [9, 10]         | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.5, 5) | [9, 10, 11]     | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# | (11, 0.9, 5) | [9, 10, 11]     | BasicRuleProactive |
# +--------------+-----------------+--------------------+
# Adicionando regras para 10
# +--------------+------------------+--------------------+
# | Match        | Route            | Rule               |
# +==============+==================+====================+
# | (0, 0.5, 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (0, 0.9, 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (1, 0.5, 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (1, 0.9, 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (2, 0.5, 5)  | [10, 6, 2]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (2, 0.9, 5)  | [10, 6, 2]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (3, 0.5, 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (3, 0.9, 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (4, 0.5, 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (4, 0.9, 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (5, 0.5, 5)  | [10, 9, 5]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (5, 0.9, 5)  | [10, 9, 5]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (6, 0.5, 5)  | [10, 6]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (6, 0.9, 5)  | [10, 6]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (7, 0.5, 5)  | [10, 6, 7]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (7, 0.9, 5)  | [10, 6, 7]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (8, 0.5, 5)  | [10, 9, 8]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (8, 0.9, 5)  | [10, 9, 8]       | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (9, 0.5, 5)  | [10, 9]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (9, 0.9, 5)  | [10, 9]          | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (10, 0.5, 5) | [10]             | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (10, 0.9, 5) | [10]             | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (11, 0.5, 5) | [10, 11]         | BasicRuleProactive |
# +--------------+------------------+--------------------+
# | (11, 0.9, 5) | [10, 11]         | BasicRuleProactive |
# +--------------+------------------+--------------------+
# Adicionando regras para 11
# +--------------+---------------------+--------------------+
# | Match        | Route               | Rule               |
# +==============+=====================+====================+
# | (0, 0.5, 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (0, 0.9, 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (1, 0.5, 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (1, 0.9, 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (2, 0.5, 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (2, 0.9, 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (3, 0.5, 5)  | [11, 7, 3]          | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (3, 0.9, 5)  | [11, 7, 3]          | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (4, 0.5, 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (4, 0.9, 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (5, 0.5, 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (5, 0.9, 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (6, 0.5, 5)  | [11, 10, 6]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (6, 0.9, 5)  | [11, 10, 6]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (7, 0.5, 5)  | [11, 7]             | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (7, 0.9, 5)  | [11, 7]             | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (8, 0.5, 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (8, 0.9, 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (9, 0.5, 5)  | [11, 10, 9]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (9, 0.9, 5)  | [11, 10, 9]         | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (10, 0.5, 5) | [11, 10]            | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (10, 0.9, 5) | [11, 10]            | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (11, 0.5, 5) | [11]                | BasicRuleProactive |
# +--------------+---------------------+--------------------+
# | (11, 0.9, 5) | [11]                | BasicRuleProactive |
# +--------------+---------------------+--------------------+

# %%
def simulate_requests_with_timeslots(rede, requests, controlador):
    """
    Simula o processamento de requests com a introdução de timeslots.
    - Demora 1 time-slot se a regra existe.
    - Demora 3 time-slots se uma nova regra precisa ser adicionada.
    """
    current_time = 0  # Tempo global da simulação
    for request in requests:
        print(f"[Time {current_time}]")
        print(f"Request: {request}, Alice: {request.alice}, Bob: {request.bob}, Fmin: {request.fmin}, Neprs: {request.neprs}")
        alice = rede.get_host(request.alice)
        rule = alice.find_rule_by_request(request)

        if rule == False:  # Caso não exista um match na tabela
            request.endtime = current_time
            # Registra no CSV como um novo registro
            register_request(request, "Descartado", path)
        else:  # Caso já exista a regra
            request.starttime = current_time
            controlador.run_rule(rule[1])
            request.endtime = current_time
            
            # Registra no CSV como já registrado
            register_request(request, "Já Registrado", path)
        
        current_time += 1  # Delay de 1 time-slot para execução
        # Exibir informações da requisição
        print(f"Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")

simulate_requests_with_timeslots(rede, requests, controlador)
# Out:
# [Time 0]
# Request: R-AD7FB0, Alice: 10, Bob: 6, Fmin: 0.57, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Request R-AD7FB0: Start Time = 0, End Time = 0
# [Time 1]
# Request: R-BE2AE0, Alice: 5, Bob: 1, Fmin: 0.56, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-BE2AE0: Start Time = 1, End Time = 1
# [Time 2]
# Request: R-53C1D0, Alice: 7, Bob: 5, Fmin: 0.97, Neprs: 4
# Request R-53C1D0: Start Time = 0, End Time = 2
# [Time 3]
# Request: R-53C140, Alice: 2, Bob: 8, Fmin: 0.61, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Tempo: 3
# Executando ação: Swap(2-0-8)
# Running Swap(2-0-8)
# Request R-53C140: Start Time = 3, End Time = 3
# [Time 4]
# Request: R-53C1A0, Alice: 4, Bob: 0, Fmin: 0.54, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Request R-53C1A0: Start Time = 4, End Time = 4
# [Time 5]
# Request: R-53C170, Alice: 2, Bob: 6, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Request R-53C170: Start Time = 5, End Time = 5
# [Time 6]
# Request: R-53C260, Alice: 7, Bob: 9, Fmin: 0.98, Neprs: 2
# Request R-53C260: Start Time = 0, End Time = 6
# [Time 7]
# Request: R-53C290, Alice: 7, Bob: 10, Fmin: 0.56, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(7-6-10)
# Running Swap(7-6-10)
# Request R-53C290: Start Time = 7, End Time = 7
# [Time 8]
# Request: R-53C2C0, Alice: 7, Bob: 1, Fmin: 0.94, Neprs: 4
# Request R-53C2C0: Start Time = 0, End Time = 8
# [Time 9]
# Request: R-53C2F0, Alice: 8, Bob: 3, Fmin: 0.67, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-53C2F0: Start Time = 9, End Time = 9
# [Time 10]
# Request: R-53C320, Alice: 7, Bob: 9, Fmin: 0.72, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-53C320: Start Time = 10, End Time = 10
# [Time 11]
# Request: R-53C350, Alice: 1, Bob: 3, Fmin: 0.88, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-53C350: Start Time = 11, End Time = 11
# [Time 12]
# Request: R-53C380, Alice: 8, Bob: 6, Fmin: 0.51, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-53C380: Start Time = 12, End Time = 12
# [Time 13]
# Request: R-53C3B0, Alice: 5, Bob: 1, Fmin: 0.83, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-53C3B0: Start Time = 13, End Time = 13
# [Time 14]
# Request: R-53C3E0, Alice: 6, Bob: 7, Fmin: 0.51, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-7)
# Request R-53C3E0: Start Time = 14, End Time = 14
# [Time 15]
# Request: R-53C410, Alice: 0, Bob: 3, Fmin: 0.88, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-53C410: Start Time = 15, End Time = 15
# [Time 16]
# Request: R-53C440, Alice: 8, Bob: 2, Fmin: 0.79, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-53C440: Start Time = 16, End Time = 16
# [Time 17]
# Request: R-53C470, Alice: 4, Bob: 3, Fmin: 0.68, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-53C470: Start Time = 17, End Time = 17
# [Time 18]
# Request: R-53C4A0, Alice: 5, Bob: 0, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(5-4-0)
# Running Swap(5-4-0)
# Request R-53C4A0: Start Time = 18, End Time = 18
# [Time 19]
# Request: R-53C4D0, Alice: 10, Bob: 7, Fmin: 0.94, Neprs: 4
# Request R-53C4D0: Start Time = 0, End Time = 19
# [Time 20]
# Request: R-53C500, Alice: 8, Bob: 6, Fmin: 0.77, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-53C500: Start Time = 20, End Time = 20
# [Time 21]
# Request: R-53C530, Alice: 7, Bob: 2, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(7-6-2)
# Running Swap(7-6-2)
# Request R-53C530: Start Time = 21, End Time = 21
# [Time 22]
# Request: R-53C560, Alice: 1, Bob: 3, Fmin: 0.55, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-53C560: Start Time = 22, End Time = 22
# [Time 23]
# Request: R-53C590, Alice: 4, Bob: 8, Fmin: 0.87, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Request R-53C590: Start Time = 23, End Time = 23
# [Time 24]
# Request: R-53C5C0, Alice: 8, Bob: 10, Fmin: 0.67, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-53C5C0: Start Time = 24, End Time = 24
# [Time 25]
# Request: R-53C5F0, Alice: 3, Bob: 9, Fmin: 0.78, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Tempo: 3
# Executando ação: Swap(3-1-9)
# Running Swap(3-1-9)
# Request R-53C5F0: Start Time = 25, End Time = 25
# [Time 26]
# Request: R-53C620, Alice: 9, Bob: 4, Fmin: 0.54, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-53C620: Start Time = 26, End Time = 26
# [Time 27]
# Request: R-53C650, Alice: 8, Bob: 1, Fmin: 0.74, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-53C650: Start Time = 27, End Time = 27
# [Time 28]
# Request: R-53C680, Alice: 10, Bob: 6, Fmin: 0.76, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Request R-53C680: Start Time = 28, End Time = 28
# [Time 29]
# Request: R-53C6B0, Alice: 10, Bob: 6, Fmin: 0.63, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Request R-53C6B0: Start Time = 29, End Time = 29
# [Time 30]
# Request: R-53C6E0, Alice: 3, Bob: 2, Fmin: 0.69, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Request R-53C6E0: Start Time = 30, End Time = 30
# [Time 31]
# Request: R-53C710, Alice: 9, Bob: 8, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-53C710: Start Time = 31, End Time = 31
# [Time 32]
# Request: R-53C740, Alice: 8, Bob: 1, Fmin: 0.65, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-53C740: Start Time = 32, End Time = 32
# [Time 33]
# Request: R-53C770, Alice: 9, Bob: 10, Fmin: 0.52, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-53C770: Start Time = 33, End Time = 33
# [Time 34]
# Request: R-53C7A0, Alice: 10, Bob: 9, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Request R-53C7A0: Start Time = 34, End Time = 34
# [Time 35]
# Request: R-53C7D0, Alice: 4, Bob: 3, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-53C7D0: Start Time = 35, End Time = 35
# [Time 36]
# Request: R-53C800, Alice: 6, Bob: 3, Fmin: 0.89, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(6-2-3)
# Running Swap(6-2-3)
# Request R-53C800: Start Time = 36, End Time = 36
# [Time 37]
# Request: R-53C830, Alice: 9, Bob: 3, Fmin: 0.65, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(9-1-3)
# Running Swap(9-1-3)
# Request R-53C830: Start Time = 37, End Time = 37
# [Time 38]
# Request: R-53C860, Alice: 3, Bob: 8, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-53C860: Start Time = 38, End Time = 38
# [Time 39]
# Request: R-53C890, Alice: 2, Bob: 0, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-53C890: Start Time = 39, End Time = 39
# [Time 40]
# Request: R-53C8C0, Alice: 10, Bob: 9, Fmin: 0.76, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Request R-53C8C0: Start Time = 40, End Time = 40
# [Time 41]
# Request: R-53C8F0, Alice: 0, Bob: 9, Fmin: 0.51, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-53C8F0: Start Time = 41, End Time = 41
# [Time 42]
# Request: R-53C920, Alice: 6, Bob: 10, Fmin: 0.83, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-10)
# Request R-53C920: Start Time = 42, End Time = 42
# [Time 43]
# Request: R-53C950, Alice: 3, Bob: 9, Fmin: 0.91, Neprs: 3
# Request R-53C950: Start Time = 0, End Time = 43
# [Time 44]
# Request: R-53C980, Alice: 3, Bob: 4, Fmin: 0.78, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-53C980: Start Time = 44, End Time = 44
# [Time 45]
# Request: R-53C9B0, Alice: 10, Bob: 7, Fmin: 0.7, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(10-6-7)
# Running Swap(10-6-7)
# Request R-53C9B0: Start Time = 45, End Time = 45
# [Time 46]
# Request: R-53C9E0, Alice: 9, Bob: 3, Fmin: 0.63, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(9-1-3)
# Running Swap(9-1-3)
# Request R-53C9E0: Start Time = 46, End Time = 46
# [Time 47]
# Request: R-53CA10, Alice: 10, Bob: 9, Fmin: 0.85, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Request R-53CA10: Start Time = 47, End Time = 47
# [Time 48]
# Request: R-53CA40, Alice: 3, Bob: 6, Fmin: 0.54, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(3-2-6)
# Running Swap(3-2-6)
# Request R-53CA40: Start Time = 48, End Time = 48
# [Time 49]
# Request: R-53CA70, Alice: 7, Bob: 3, Fmin: 0.57, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Request R-53CA70: Start Time = 49, End Time = 49
# [Time 50]
# Request: R-53CAA0, Alice: 5, Bob: 3, Fmin: 0.51, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-53CAA0: Start Time = 50, End Time = 50
# [Time 51]
# Request: R-53CAD0, Alice: 1, Bob: 9, Fmin: 0.59, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-53CAD0: Start Time = 51, End Time = 51
# [Time 52]
# Request: R-53CB00, Alice: 1, Bob: 7, Fmin: 0.76, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(1-5-6)
# Running Swap(1-5-6)
# Request R-53CB00: Start Time = 52, End Time = 52
# [Time 53]
# Request: R-53CB30, Alice: 5, Bob: 8, Fmin: 0.79, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(5-4-8)
# Running Swap(5-4-8)
# Request R-53CB30: Start Time = 53, End Time = 53
# [Time 54]
# Request: R-53CB60, Alice: 10, Bob: 5, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-5)
# Tempo: 2
# Executando ação: Swap(10-9-5)
# Running Swap(10-9-5)
# Request R-53CB60: Start Time = 54, End Time = 54
# [Time 55]
# Request: R-53CB90, Alice: 10, Bob: 4, Fmin: 1.0, Neprs: 2
# Request R-53CB90: Start Time = 0, End Time = 55
# [Time 56]
# Request: R-53CBC0, Alice: 9, Bob: 1, Fmin: 0.8, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-53CBC0: Start Time = 56, End Time = 56
# [Time 57]
# Request: R-53CBF0, Alice: 4, Bob: 7, Fmin: 0.82, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53CBF0: Start Time = 57, End Time = 57
# [Time 58]
# Request: R-53CC20, Alice: 7, Bob: 6, Fmin: 0.87, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Request R-53CC20: Start Time = 58, End Time = 58
# [Time 59]
# Request: R-53CC50, Alice: 9, Bob: 1, Fmin: 0.74, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-53CC50: Start Time = 59, End Time = 59
# [Time 60]
# Request: R-53CC80, Alice: 10, Bob: 3, Fmin: 0.6, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-53CC80: Start Time = 60, End Time = 60
# [Time 61]
# Request: R-53CCB0, Alice: 8, Bob: 9, Fmin: 0.79, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Request R-53CCB0: Start Time = 61, End Time = 61
# [Time 62]
# Request: R-53CCE0, Alice: 0, Bob: 9, Fmin: 0.95, Neprs: 4
# Request R-53CCE0: Start Time = 0, End Time = 62
# [Time 63]
# Request: R-53CD10, Alice: 2, Bob: 3, Fmin: 0.87, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Request R-53CD10: Start Time = 63, End Time = 63
# [Time 64]
# Request: R-53CD40, Alice: 0, Bob: 2, Fmin: 0.77, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-53CD40: Start Time = 64, End Time = 64
# [Time 65]
# Request: R-53CD70, Alice: 2, Bob: 5, Fmin: 0.87, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Tempo: 2
# Executando ação: Swap(2-1-5)
# Running Swap(2-1-5)
# Request R-53CD70: Start Time = 65, End Time = 65
# [Time 66]
# Request: R-53CDA0, Alice: 7, Bob: 8, Fmin: 0.97, Neprs: 4
# Request R-53CDA0: Start Time = 0, End Time = 66
# [Time 67]
# Request: R-53CDD0, Alice: 7, Bob: 2, Fmin: 0.9, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-2)
# Tempo: 2
# Executando ação: Swap(7-6-2)
# Running Swap(7-6-2)
# Request R-53CDD0: Start Time = 67, End Time = 67
# [Time 68]
# Request: R-53CE00, Alice: 1, Bob: 6, Fmin: 0.55, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-53CE00: Start Time = 68, End Time = 68
# [Time 69]
# Request: R-53CE30, Alice: 10, Bob: 9, Fmin: 0.92, Neprs: 4
# Request R-53CE30: Start Time = 0, End Time = 69
# [Time 70]
# Request: R-53CE60, Alice: 10, Bob: 6, Fmin: 0.86, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Request R-53CE60: Start Time = 70, End Time = 70
# [Time 71]
# Request: R-53CE90, Alice: 5, Bob: 6, Fmin: 0.82, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Request R-53CE90: Start Time = 71, End Time = 71
# [Time 72]
# Request: R-53CEC0, Alice: 6, Bob: 0, Fmin: 0.73, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-53CEC0: Start Time = 72, End Time = 72
# [Time 73]
# Request: R-53CEF0, Alice: 7, Bob: 5, Fmin: 0.77, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-53CEF0: Start Time = 73, End Time = 73
# [Time 74]
# Request: R-53CF20, Alice: 1, Bob: 10, Fmin: 0.87, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-53CF20: Start Time = 74, End Time = 74
# [Time 75]
# Request: R-53CF50, Alice: 4, Bob: 8, Fmin: 0.77, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Request R-53CF50: Start Time = 75, End Time = 75
# [Time 76]
# Request: R-53CF80, Alice: 8, Bob: 2, Fmin: 0.91, Neprs: 4
# Request R-53CF80: Start Time = 0, End Time = 76
# [Time 77]
# Request: R-53CFB0, Alice: 4, Bob: 6, Fmin: 0.62, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53CFB0: Start Time = 77, End Time = 77
# [Time 78]
# Request: R-53CFE0, Alice: 9, Bob: 3, Fmin: 0.52, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(9-1-3)
# Running Swap(9-1-3)
# Request R-53CFE0: Start Time = 78, End Time = 78
# [Time 79]
# Request: R-53D010, Alice: 10, Bob: 5, Fmin: 0.7, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-5)
# Tempo: 2
# Executando ação: Swap(10-9-5)
# Running Swap(10-9-5)
# Request R-53D010: Start Time = 79, End Time = 79
# [Time 80]
# Request: R-53D040, Alice: 8, Bob: 10, Fmin: 0.65, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-53D040: Start Time = 80, End Time = 80
# [Time 81]
# Request: R-53D070, Alice: 9, Bob: 8, Fmin: 0.54, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-53D070: Start Time = 81, End Time = 81
# [Time 82]
# Request: R-53D0A0, Alice: 9, Bob: 8, Fmin: 0.98, Neprs: 4
# Request R-53D0A0: Start Time = 0, End Time = 82
# [Time 83]
# Request: R-53D0D0, Alice: 5, Bob: 6, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Request R-53D0D0: Start Time = 83, End Time = 83
# [Time 84]
# Request: R-53D100, Alice: 3, Bob: 4, Fmin: 0.8, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-53D100: Start Time = 84, End Time = 84
# [Time 85]
# Request: R-53D130, Alice: 3, Bob: 9, Fmin: 0.95, Neprs: 2
# Request R-53D130: Start Time = 0, End Time = 85
# [Time 86]
# Request: R-53D160, Alice: 5, Bob: 10, Fmin: 0.75, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(5-6-10)
# Running Swap(5-6-10)
# Request R-53D160: Start Time = 86, End Time = 86
# [Time 87]
# Request: R-53D190, Alice: 1, Bob: 8, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Request R-53D190: Start Time = 87, End Time = 87
# [Time 88]
# Request: R-53D1C0, Alice: 10, Bob: 1, Fmin: 0.59, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-53D1C0: Start Time = 88, End Time = 88
# [Time 89]
# Request: R-53D1F0, Alice: 6, Bob: 0, Fmin: 0.87, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-53D1F0: Start Time = 89, End Time = 89
# [Time 90]
# Request: R-53D220, Alice: 5, Bob: 0, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(5-4-0)
# Running Swap(5-4-0)
# Request R-53D220: Start Time = 90, End Time = 90
# [Time 91]
# Request: R-53D250, Alice: 8, Bob: 0, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-53D250: Start Time = 91, End Time = 91
# [Time 92]
# Request: R-53D280, Alice: 8, Bob: 10, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-53D280: Start Time = 92, End Time = 92
# [Time 93]
# Request: R-53D2B0, Alice: 1, Bob: 5, Fmin: 0.71, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Request R-53D2B0: Start Time = 93, End Time = 93
# [Time 94]
# Request: R-53D2E0, Alice: 0, Bob: 9, Fmin: 0.63, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-53D2E0: Start Time = 94, End Time = 94
# [Time 95]
# Request: R-53D310, Alice: 10, Bob: 1, Fmin: 0.91, Neprs: 2
# Request R-53D310: Start Time = 0, End Time = 95
# [Time 96]
# Request: R-53D340, Alice: 6, Bob: 7, Fmin: 0.63, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-7)
# Request R-53D340: Start Time = 96, End Time = 96
# [Time 97]
# Request: R-53D370, Alice: 4, Bob: 9, Fmin: 1.0, Neprs: 4
# Request R-53D370: Start Time = 0, End Time = 97
# [Time 98]
# Request: R-53D3A0, Alice: 0, Bob: 1, Fmin: 0.94, Neprs: 3
# Request R-53D3A0: Start Time = 0, End Time = 98
# [Time 99]
# Request: R-53D3D0, Alice: 8, Bob: 7, Fmin: 0.94, Neprs: 2
# Request R-53D3D0: Start Time = 0, End Time = 99
# [Time 100]
# Request: R-53D400, Alice: 8, Bob: 0, Fmin: 0.93, Neprs: 3
# Request R-53D400: Start Time = 0, End Time = 100
# [Time 101]
# Request: R-53D430, Alice: 1, Bob: 0, Fmin: 0.81, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Request R-53D430: Start Time = 101, End Time = 101
# [Time 102]
# Request: R-53D460, Alice: 9, Bob: 8, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-53D460: Start Time = 102, End Time = 102
# [Time 103]
# Request: R-53D490, Alice: 5, Bob: 0, Fmin: 0.57, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(5-4-0)
# Running Swap(5-4-0)
# Request R-53D490: Start Time = 103, End Time = 103
# [Time 104]
# Request: R-53D4C0, Alice: 4, Bob: 7, Fmin: 0.53, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53D4C0: Start Time = 104, End Time = 104
# [Time 105]
# Request: R-53D4F0, Alice: 5, Bob: 3, Fmin: 0.89, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-53D4F0: Start Time = 105, End Time = 105
# [Time 106]
# Request: R-53D520, Alice: 9, Bob: 10, Fmin: 0.54, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-53D520: Start Time = 106, End Time = 106
# [Time 107]
# Request: R-53D550, Alice: 10, Bob: 3, Fmin: 0.89, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-53D550: Start Time = 107, End Time = 107
# [Time 108]
# Request: R-53D580, Alice: 5, Bob: 6, Fmin: 0.67, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Request R-53D580: Start Time = 108, End Time = 108
# [Time 109]
# Request: R-53D5B0, Alice: 6, Bob: 2, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-2)
# Request R-53D5B0: Start Time = 109, End Time = 109
# [Time 110]
# Request: R-53D5E0, Alice: 9, Bob: 5, Fmin: 0.6, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Request R-53D5E0: Start Time = 110, End Time = 110
# [Time 111]
# Request: R-53D610, Alice: 3, Bob: 0, Fmin: 0.9, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request R-53D610: Start Time = 111, End Time = 111
# [Time 112]
# Request: R-53D640, Alice: 5, Bob: 6, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Request R-53D640: Start Time = 112, End Time = 112
# [Time 113]
# Request: R-53D670, Alice: 1, Bob: 10, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-53D670: Start Time = 113, End Time = 113
# [Time 114]
# Request: R-53D6A0, Alice: 8, Bob: 7, Fmin: 0.56, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Tempo: 3
# Executando ação: Swap(8-5-7)
# Running Swap(8-5-7)
# Request R-53D6A0: Start Time = 114, End Time = 114
# [Time 115]
# Request: R-53D6D0, Alice: 2, Bob: 3, Fmin: 0.69, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Request R-53D6D0: Start Time = 115, End Time = 115
# [Time 116]
# Request: R-53D700, Alice: 8, Bob: 1, Fmin: 0.53, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-53D700: Start Time = 116, End Time = 116
# [Time 117]
# Request: R-53D730, Alice: 6, Bob: 10, Fmin: 0.93, Neprs: 4
# Request R-53D730: Start Time = 0, End Time = 117
# [Time 118]
# Request: R-53D760, Alice: 4, Bob: 8, Fmin: 0.67, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-8)
# Request R-53D760: Start Time = 118, End Time = 118
# [Time 119]
# Request: R-53D790, Alice: 10, Bob: 1, Fmin: 0.66, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-53D790: Start Time = 119, End Time = 119
# [Time 120]
# Request: R-53D7C0, Alice: 0, Bob: 9, Fmin: 0.88, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-53D7C0: Start Time = 120, End Time = 120
# [Time 121]
# Request: R-53D7F0, Alice: 2, Bob: 9, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(2-1-5)
# Running Swap(2-1-5)
# Request R-53D7F0: Start Time = 121, End Time = 121
# [Time 122]
# Request: R-53D820, Alice: 10, Bob: 9, Fmin: 0.55, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Request R-53D820: Start Time = 122, End Time = 122
# [Time 123]
# Request: R-53D850, Alice: 4, Bob: 5, Fmin: 0.83, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Request R-53D850: Start Time = 123, End Time = 123
# [Time 124]
# Request: R-53D880, Alice: 5, Bob: 2, Fmin: 0.52, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-53D880: Start Time = 124, End Time = 124
# [Time 125]
# Request: R-53D8B0, Alice: 4, Bob: 5, Fmin: 0.64, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Request R-53D8B0: Start Time = 125, End Time = 125
# [Time 126]
# Request: R-53D8E0, Alice: 8, Bob: 0, Fmin: 0.65, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-53D8E0: Start Time = 126, End Time = 126
# [Time 127]
# Request: R-53D910, Alice: 0, Bob: 3, Fmin: 0.94, Neprs: 2
# Request R-53D910: Start Time = 0, End Time = 127
# [Time 128]
# Request: R-53D940, Alice: 7, Bob: 9, Fmin: 0.83, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-53D940: Start Time = 128, End Time = 128
# [Time 129]
# Request: R-53D970, Alice: 2, Bob: 10, Fmin: 0.67, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(2-6-10)
# Running Swap(2-6-10)
# Request R-53D970: Start Time = 129, End Time = 129
# [Time 130]
# Request: R-53D9A0, Alice: 1, Bob: 4, Fmin: 0.52, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Request R-53D9A0: Start Time = 130, End Time = 130
# [Time 131]
# Request: R-53D9D0, Alice: 8, Bob: 3, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Tempo: 3
# Executando ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-53D9D0: Start Time = 131, End Time = 131
# [Time 132]
# Request: R-53DA00, Alice: 0, Bob: 9, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Executando ação: CreateEPR(8-9)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-53DA00: Start Time = 132, End Time = 132
# [Time 133]
# Request: R-53DA30, Alice: 9, Bob: 10, Fmin: 0.98, Neprs: 4
# Request R-53DA30: Start Time = 0, End Time = 133
# [Time 134]
# Request: R-53DA60, Alice: 1, Bob: 2, Fmin: 0.87, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Request R-53DA60: Start Time = 134, End Time = 134
# [Time 135]
# Request: R-53DA90, Alice: 3, Bob: 8, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-53DA90: Start Time = 135, End Time = 135
# [Time 136]
# Request: R-53DAC0, Alice: 1, Bob: 3, Fmin: 1.0, Neprs: 3
# Request R-53DAC0: Start Time = 0, End Time = 136
# [Time 137]
# Request: R-53DAF0, Alice: 1, Bob: 10, Fmin: 0.99, Neprs: 3
# Request R-53DAF0: Start Time = 0, End Time = 137
# [Time 138]
# Request: R-53DB20, Alice: 1, Bob: 6, Fmin: 0.5, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-53DB20: Start Time = 138, End Time = 138
# [Time 139]
# Request: R-53DB50, Alice: 0, Bob: 8, Fmin: 0.67, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-53DB50: Start Time = 139, End Time = 139
# [Time 140]
# Request: R-53DB80, Alice: 4, Bob: 6, Fmin: 0.59, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53DB80: Start Time = 140, End Time = 140
# [Time 141]
# Request: R-53DBB0, Alice: 5, Bob: 1, Fmin: 0.86, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-53DBB0: Start Time = 141, End Time = 141
# [Time 142]
# Request: R-53DBE0, Alice: 0, Bob: 3, Fmin: 0.95, Neprs: 4
# Request R-53DBE0: Start Time = 0, End Time = 142
# [Time 143]
# Request: R-53DC10, Alice: 3, Bob: 8, Fmin: 0.62, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-53DC10: Start Time = 143, End Time = 143
# [Time 144]
# Request: R-53DC40, Alice: 10, Bob: 1, Fmin: 0.93, Neprs: 4
# Request R-53DC40: Start Time = 0, End Time = 144
# [Time 145]
# Request: R-53DC70, Alice: 0, Bob: 1, Fmin: 0.72, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Request R-53DC70: Start Time = 145, End Time = 145
# [Time 146]
# Request: R-53DCA0, Alice: 3, Bob: 4, Fmin: 0.72, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-53DCA0: Start Time = 146, End Time = 146
# [Time 147]
# Request: R-53DCD0, Alice: 2, Bob: 4, Fmin: 0.51, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-53DCD0: Start Time = 147, End Time = 147
# [Time 148]
# Request: R-53DD00, Alice: 4, Bob: 6, Fmin: 0.51, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53DD00: Start Time = 148, End Time = 148
# [Time 149]
# Request: R-53DD30, Alice: 4, Bob: 7, Fmin: 0.52, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53DD30: Start Time = 149, End Time = 149
# [Time 150]
# Request: R-53DD60, Alice: 5, Bob: 1, Fmin: 0.73, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-53DD60: Start Time = 150, End Time = 150
# [Time 151]
# Request: R-53DD90, Alice: 2, Bob: 6, Fmin: 0.6, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Request R-53DD90: Start Time = 151, End Time = 151
# [Time 152]
# Request: R-53DDC0, Alice: 1, Bob: 9, Fmin: 0.74, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-53DDC0: Start Time = 152, End Time = 152
# [Time 153]
# Request: R-53DDF0, Alice: 8, Bob: 5, Fmin: 0.56, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-53DDF0: Start Time = 153, End Time = 153
# [Time 154]
# Request: R-53DE20, Alice: 3, Bob: 10, Fmin: 0.64, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(3-2-6)
# Running Swap(3-2-6)
# Request R-53DE20: Start Time = 154, End Time = 154
# [Time 155]
# Request: R-53DE50, Alice: 2, Bob: 0, Fmin: 0.56, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-53DE50: Start Time = 155, End Time = 155
# [Time 156]
# Request: R-53DE80, Alice: 10, Bob: 3, Fmin: 0.92, Neprs: 3
# Request R-53DE80: Start Time = 0, End Time = 156
# [Time 157]
# Request: R-53DEB0, Alice: 3, Bob: 10, Fmin: 0.52, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(3-2-6)
# Running Swap(3-2-6)
# Request R-53DEB0: Start Time = 157, End Time = 157
# [Time 158]
# Request: R-53DEE0, Alice: 2, Bob: 0, Fmin: 0.66, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-53DEE0: Start Time = 158, End Time = 158
# [Time 159]
# Request: R-53DF10, Alice: 5, Bob: 10, Fmin: 0.63, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(5-6-10)
# Running Swap(5-6-10)
# Request R-53DF10: Start Time = 159, End Time = 159
# [Time 160]
# Request: R-53DF40, Alice: 0, Bob: 2, Fmin: 0.95, Neprs: 2
# Request R-53DF40: Start Time = 0, End Time = 160
# [Time 161]
# Request: R-53DF70, Alice: 2, Bob: 4, Fmin: 0.65, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-53DF70: Start Time = 161, End Time = 161
# [Time 162]
# Request: R-53DFA0, Alice: 9, Bob: 7, Fmin: 0.5, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-53DFA0: Start Time = 162, End Time = 162
# [Time 163]
# Request: R-53DFD0, Alice: 10, Bob: 1, Fmin: 0.59, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-53DFD0: Start Time = 163, End Time = 163
# [Time 164]
# Request: R-53E000, Alice: 4, Bob: 0, Fmin: 0.63, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Request R-53E000: Start Time = 164, End Time = 164
# [Time 165]
# Request: R-53E030, Alice: 9, Bob: 0, Fmin: 0.6, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-53E030: Start Time = 165, End Time = 165
# [Time 166]
# Request: R-53E060, Alice: 5, Bob: 3, Fmin: 0.78, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-53E060: Start Time = 166, End Time = 166
# [Time 167]
# Request: R-53E090, Alice: 8, Bob: 7, Fmin: 0.97, Neprs: 4
# Request R-53E090: Start Time = 0, End Time = 167
# [Time 168]
# Request: R-53E0C0, Alice: 7, Bob: 3, Fmin: 0.93, Neprs: 2
# Request R-53E0C0: Start Time = 0, End Time = 168
# [Time 169]
# Request: R-53E0F0, Alice: 4, Bob: 9, Fmin: 0.94, Neprs: 3
# Request R-53E0F0: Start Time = 0, End Time = 169
# [Time 170]
# Request: R-53E120, Alice: 1, Bob: 6, Fmin: 0.74, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-53E120: Start Time = 170, End Time = 170
# [Time 171]
# Request: R-53E150, Alice: 9, Bob: 0, Fmin: 0.58, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-53E150: Start Time = 171, End Time = 171
# [Time 172]
# Request: R-53E180, Alice: 2, Bob: 7, Fmin: 0.94, Neprs: 2
# Request R-53E180: Start Time = 0, End Time = 172
# [Time 173]
# Request: R-53E1B0, Alice: 10, Bob: 3, Fmin: 0.98, Neprs: 2
# Request R-53E1B0: Start Time = 0, End Time = 173
# [Time 174]
# Request: R-53E1E0, Alice: 1, Bob: 9, Fmin: 0.66, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-53E1E0: Start Time = 174, End Time = 174
# [Time 175]
# Request: R-53E210, Alice: 3, Bob: 8, Fmin: 0.94, Neprs: 3
# Request R-53E210: Start Time = 0, End Time = 175
# [Time 176]
# Request: R-53E240, Alice: 7, Bob: 9, Fmin: 0.51, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-53E240: Start Time = 176, End Time = 176
# [Time 177]
# Request: R-53E270, Alice: 4, Bob: 7, Fmin: 0.8, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53E270: Start Time = 177, End Time = 177
# [Time 178]
# Request: R-53E2A0, Alice: 6, Bob: 9, Fmin: 1.0, Neprs: 2
# Request R-53E2A0: Start Time = 0, End Time = 178
# [Time 179]
# Request: R-53E2D0, Alice: 0, Bob: 3, Fmin: 0.92, Neprs: 3
# Request R-53E2D0: Start Time = 0, End Time = 179
# [Time 180]
# Request: R-53E300, Alice: 8, Bob: 7, Fmin: 0.71, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Tempo: 3
# Executando ação: Swap(8-5-7)
# Running Swap(8-5-7)
# Request R-53E300: Start Time = 180, End Time = 180
# [Time 181]
# Request: R-53E330, Alice: 9, Bob: 6, Fmin: 0.92, Neprs: 3
# Request R-53E330: Start Time = 0, End Time = 181
# [Time 182]
# Request: R-53E360, Alice: 5, Bob: 6, Fmin: 0.87, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Request R-53E360: Start Time = 182, End Time = 182
# [Time 183]
# Request: R-53E390, Alice: 6, Bob: 0, Fmin: 0.91, Neprs: 4
# Request R-53E390: Start Time = 0, End Time = 183
# [Time 184]
# Request: R-53E3C0, Alice: 5, Bob: 1, Fmin: 0.63, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-53E3C0: Start Time = 184, End Time = 184
# [Time 185]
# Request: R-53E3F0, Alice: 1, Bob: 9, Fmin: 0.93, Neprs: 2
# Request R-53E3F0: Start Time = 0, End Time = 185
# [Time 186]
# Request: R-53E420, Alice: 3, Bob: 1, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request R-53E420: Start Time = 186, End Time = 186
# [Time 187]
# Request: R-53E450, Alice: 4, Bob: 3, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-53E450: Start Time = 187, End Time = 187
# [Time 188]
# Request: R-53E480, Alice: 7, Bob: 4, Fmin: 0.8, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-53E480: Start Time = 188, End Time = 188
# [Time 189]
# Request: R-53E4B0, Alice: 0, Bob: 6, Fmin: 0.61, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-53E4B0: Start Time = 189, End Time = 189
# [Time 190]
# Request: R-53E4E0, Alice: 9, Bob: 7, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-53E4E0: Start Time = 190, End Time = 190
# [Time 191]
# Request: R-53E510, Alice: 4, Bob: 0, Fmin: 0.71, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Request R-53E510: Start Time = 191, End Time = 191
# [Time 192]
# Request: R-53E540, Alice: 9, Bob: 5, Fmin: 0.55, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Request R-53E540: Start Time = 192, End Time = 192
# [Time 193]
# Request: R-53E570, Alice: 9, Bob: 4, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-53E570: Start Time = 193, End Time = 193
# [Time 194]
# Request: R-53E5A0, Alice: 5, Bob: 10, Fmin: 0.98, Neprs: 4
# Request R-53E5A0: Start Time = 0, End Time = 194
# [Time 195]
# Request: R-53E5D0, Alice: 6, Bob: 7, Fmin: 0.83, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-7)
# Request R-53E5D0: Start Time = 195, End Time = 195
# [Time 196]
# Request: R-53E600, Alice: 6, Bob: 1, Fmin: 0.51, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(6-5-1)
# Running Swap(6-5-1)
# Request R-53E600: Start Time = 196, End Time = 196
# [Time 197]
# Request: R-53E630, Alice: 4, Bob: 7, Fmin: 0.74, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(4-5-6)
# Running Swap(4-5-6)
# Request R-53E630: Start Time = 197, End Time = 197
# [Time 198]
# Request: R-53E660, Alice: 10, Bob: 8, Fmin: 0.78, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-53E660: Start Time = 198, End Time = 198
# [Time 199]
# Request: R-53E690, Alice: 0, Bob: 6, Fmin: 0.51, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-53E690: Start Time = 199, End Time = 199
# [Time 200]
# Request: R-53E6C0, Alice: 9, Bob: 3, Fmin: 0.76, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(9-1-3)
# Running Swap(9-1-3)
# Request R-53E6C0: Start Time = 200, End Time = 200
# [Time 201]
# Request: R-53E6F0, Alice: 1, Bob: 6, Fmin: 0.88, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-53E6F0: Start Time = 201, End Time = 201
# [Time 202]
# Request: R-53E720, Alice: 10, Bob: 8, Fmin: 0.5, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-53E720: Start Time = 202, End Time = 202
# [Time 203]
# Request: R-53E750, Alice: 6, Bob: 10, Fmin: 0.72, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-10)
# Request R-53E750: Start Time = 203, End Time = 203
# [Time 204]
# Request: R-53E780, Alice: 1, Bob: 4, Fmin: 0.91, Neprs: 3
# Request R-53E780: Start Time = 0, End Time = 204
# [Time 205]
# Request: R-53E7B0, Alice: 8, Bob: 4, Fmin: 0.93, Neprs: 4
# Request R-53E7B0: Start Time = 0, End Time = 205
# [Time 206]
# Request: R-53E7E0, Alice: 9, Bob: 1, Fmin: 0.85, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-53E7E0: Start Time = 206, End Time = 206
# [Time 207]
# Request: R-53E810, Alice: 6, Bob: 4, Fmin: 0.59, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-53E810: Start Time = 207, End Time = 207
# [Time 208]
# Request: R-53E840, Alice: 4, Bob: 3, Fmin: 0.84, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-53E840: Start Time = 208, End Time = 208
# [Time 209]
# Request: R-53E870, Alice: 1, Bob: 4, Fmin: 0.97, Neprs: 2
# Request R-53E870: Start Time = 0, End Time = 209
# [Time 210]
# Request: R-53E8A0, Alice: 0, Bob: 2, Fmin: 0.81, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Tempo: 2
# Executando ação: Swap(0-1-2)
# Running Swap(0-1-2)
# Request R-53E8A0: Start Time = 210, End Time = 210
# [Time 211]
# Request: R-53E8D0, Alice: 6, Bob: 3, Fmin: 0.89, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-2)
# ...
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-5570B0: Start Time = 933, End Time = 933
# [Time 934]
# Request: R-5570E0, Alice: 3, Bob: 8, Fmin: 0.93, Neprs: 4
# Request R-5570E0: Start Time = 0, End Time = 934
# [Time 935]
# Request: R-557110, Alice: 10, Bob: 0, Fmin: 0.76, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(10-2-0)
# Running Swap(10-2-0)
# Request R-557110: Start Time = 935, End Time = 935
# [Time 936]
# Request: R-557140, Alice: 1, Bob: 4, Fmin: 0.58, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Request R-557140: Start Time = 936, End Time = 936
# [Time 937]
# Request: R-557170, Alice: 3, Bob: 0, Fmin: 0.92, Neprs: 3
# Request R-557170: Start Time = 0, End Time = 937
# [Time 938]
# Request: R-5571A0, Alice: 5, Bob: 9, Fmin: 0.79, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(5-9)
# Request R-5571A0: Start Time = 938, End Time = 938
# [Time 939]
# Request: R-5571D0, Alice: 2, Bob: 6, Fmin: 0.71, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-6)
# Request R-5571D0: Start Time = 939, End Time = 939
# [Time 940]
# Request: R-557200, Alice: 1, Bob: 6, Fmin: 0.79, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-6)
# Tempo: 2
# Executando ação: Swap(1-2-6)
# Running Swap(1-2-6)
# Request R-557200: Start Time = 940, End Time = 940
# [Time 941]
# Request: R-557230, Alice: 9, Bob: 3, Fmin: 0.59, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(9-1-3)
# Running Swap(9-1-3)
# Request R-557230: Start Time = 941, End Time = 941
# [Time 942]
# Request: R-557260, Alice: 9, Bob: 1, Fmin: 0.75, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-557260: Start Time = 942, End Time = 942
# [Time 943]
# Request: R-557290, Alice: 2, Bob: 4, Fmin: 0.52, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Tempo: 2
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-557290: Start Time = 943, End Time = 943
# [Time 944]
# Request: R-5572C0, Alice: 6, Bob: 7, Fmin: 0.86, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-7)
# Request R-5572C0: Start Time = 944, End Time = 944
# [Time 945]
# Request: R-5572F0, Alice: 9, Bob: 1, Fmin: 0.52, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-5572F0: Start Time = 945, End Time = 945
# [Time 946]
# Request: R-557320, Alice: 5, Bob: 7, Fmin: 0.83, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Request R-557320: Start Time = 946, End Time = 946
# [Time 947]
# Request: R-557350, Alice: 4, Bob: 9, Fmin: 0.78, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-557350: Start Time = 947, End Time = 947
# [Time 948]
# Request: R-557380, Alice: 0, Bob: 6, Fmin: 0.88, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-557380: Start Time = 948, End Time = 948
# [Time 949]
# Request: R-5573B0, Alice: 7, Bob: 10, Fmin: 0.9, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(7-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(7-6-10)
# Running Swap(7-6-10)
# Request R-5573B0: Start Time = 949, End Time = 949
# [Time 950]
# Request: R-5573E0, Alice: 3, Bob: 8, Fmin: 0.87, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-5573E0: Start Time = 950, End Time = 950
# [Time 951]
# Request: R-557410, Alice: 8, Bob: 10, Fmin: 0.68, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-557410: Start Time = 951, End Time = 951
# [Time 952]
# Request: R-557440, Alice: 4, Bob: 9, Fmin: 0.53, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-557440: Start Time = 952, End Time = 952
# [Time 953]
# Request: R-557470, Alice: 1, Bob: 5, Fmin: 0.86, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Request R-557470: Start Time = 953, End Time = 953
# [Time 954]
# Request: R-5574A0, Alice: 2, Bob: 3, Fmin: 0.98, Neprs: 3
# Request R-5574A0: Start Time = 0, End Time = 954
# [Time 955]
# Request: R-5574D0, Alice: 7, Bob: 0, Fmin: 0.71, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(7-3)
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Tempo: 2
# Executando ação: Swap(7-3-2)
# Running Swap(7-3-2)
# Executando ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Tempo: 3
# Executando ação: Swap(7-2-0)
# Running Swap(7-2-0)
# Request R-5574D0: Start Time = 955, End Time = 955
# [Time 956]
# Request: R-557500, Alice: 6, Bob: 5, Fmin: 0.59, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Request R-557500: Start Time = 956, End Time = 956
# [Time 957]
# Request: R-557530, Alice: 10, Bob: 8, Fmin: 0.99, Neprs: 3
# Request R-557530: Start Time = 0, End Time = 957
# [Time 958]
# Request: R-557560, Alice: 9, Bob: 8, Fmin: 0.6, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Request R-557560: Start Time = 958, End Time = 958
# [Time 959]
# Request: R-557590, Alice: 9, Bob: 10, Fmin: 0.69, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-10)
# Request R-557590: Start Time = 959, End Time = 959
# [Time 960]
# Request: R-5575C0, Alice: 10, Bob: 8, Fmin: 0.63, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(10-9)
# Executando ação: CreateEPR(9-8)
# Tempo: 2
# Executando ação: Swap(10-9-8)
# Running Swap(10-9-8)
# Request R-5575C0: Start Time = 960, End Time = 960
# [Time 961]
# Request: R-5575F0, Alice: 4, Bob: 3, Fmin: 0.89, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(4-0-1)
# Running Swap(4-0-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-5575F0: Start Time = 961, End Time = 961
# [Time 962]
# Request: R-557620, Alice: 3, Bob: 8, Fmin: 0.54, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-0)
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-8)
# Tempo: 2
# Executando ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Executando ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Tempo: 3
# Executando ação: Swap(3-1-4)
# Running Swap(3-1-4)
# Request R-557620: Start Time = 962, End Time = 962
# [Time 963]
# Request: R-557650, Alice: 0, Bob: 5, Fmin: 0.72, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-1)
# Executando ação: CreateEPR(1-5)
# Tempo: 2
# Executando ação: Swap(0-1-5)
# Running Swap(0-1-5)
# Request R-557650: Start Time = 963, End Time = 963
# [Time 964]
# Request: R-557680, Alice: 3, Bob: 7, Fmin: 0.84, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-7)
# Request R-557680: Start Time = 964, End Time = 964
# [Time 965]
# Request: R-5576B0, Alice: 2, Bob: 7, Fmin: 0.8, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(2-3)
# Executando ação: CreateEPR(3-7)
# Tempo: 2
# Executando ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request R-5576B0: Start Time = 965, End Time = 965
# [Time 966]
# Request: R-5576E0, Alice: 5, Bob: 7, Fmin: 0.61, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Request R-5576E0: Start Time = 966, End Time = 966
# [Time 967]
# Request: R-557710, Alice: 0, Bob: 6, Fmin: 0.68, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Request R-557710: Start Time = 967, End Time = 967
# [Time 968]
# Request: R-557740, Alice: 5, Bob: 6, Fmin: 0.98, Neprs: 3
# Request R-557740: Start Time = 0, End Time = 968
# [Time 969]
# Request: R-557770, Alice: 4, Bob: 9, Fmin: 0.78, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(4-5-9)
# Running Swap(4-5-9)
# Request R-557770: Start Time = 969, End Time = 969
# [Time 970]
# Request: R-5577A0, Alice: 10, Bob: 4, Fmin: 0.84, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-4)
# Tempo: 2
# Executando ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request R-5577A0: Start Time = 970, End Time = 970
# [Time 971]
# Request: R-5577D0, Alice: 1, Bob: 10, Fmin: 0.61, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-5577D0: Start Time = 971, End Time = 971
# [Time 972]
# Request: R-557800, Alice: 3, Bob: 2, Fmin: 0.82, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Request R-557800: Start Time = 972, End Time = 972
# [Time 973]
# Request: R-557830, Alice: 9, Bob: 3, Fmin: 0.75, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(9-5)
# Executando ação: CreateEPR(5-1)
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Tempo: 3
# Executando ação: Swap(9-1-3)
# Running Swap(9-1-3)
# Request R-557830: Start Time = 973, End Time = 973
# [Time 974]
# Request: R-557860, Alice: 8, Bob: 0, Fmin: 0.54, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-557860: Start Time = 974, End Time = 974
# [Time 975]
# Request: R-557890, Alice: 2, Bob: 9, Fmin: 0.92, Neprs: 3
# Request R-557890: Start Time = 0, End Time = 975
# [Time 976]
# Request: R-5578C0, Alice: 9, Bob: 0, Fmin: 0.63, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-5578C0: Start Time = 976, End Time = 976
# [Time 977]
# Request: R-5578F0, Alice: 5, Bob: 0, Fmin: 0.56, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(5-4-0)
# Running Swap(5-4-0)
# Request R-5578F0: Start Time = 977, End Time = 977
# [Time 978]
# Request: R-557920, Alice: 4, Bob: 0, Fmin: 0.74, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(4-0)
# Request R-557920: Start Time = 978, End Time = 978
# [Time 979]
# Request: R-557950, Alice: 2, Bob: 9, Fmin: 0.63, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(2-1)
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(2-1-5)
# Running Swap(2-1-5)
# Request R-557950: Start Time = 979, End Time = 979
# [Time 980]
# Request: R-557980, Alice: 1, Bob: 5, Fmin: 0.65, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Request R-557980: Start Time = 980, End Time = 980
# [Time 981]
# Request: R-5579B0, Alice: 5, Bob: 10, Fmin: 0.64, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(5-6-10)
# Running Swap(5-6-10)
# Request R-5579B0: Start Time = 981, End Time = 981
# [Time 982]
# Request: R-5579E0, Alice: 5, Bob: 1, Fmin: 0.83, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(5-1)
# Request R-5579E0: Start Time = 982, End Time = 982
# [Time 983]
# Request: R-557A10, Alice: 6, Bob: 4, Fmin: 0.92, Neprs: 3
# Request R-557A10: Start Time = 0, End Time = 983
# [Time 984]
# Request: R-557A40, Alice: 1, Bob: 6, Fmin: 0.91, Neprs: 4
# Request R-557A40: Start Time = 0, End Time = 984
# [Time 985]
# Request: R-557A70, Alice: 0, Bob: 4, Fmin: 0.52, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Request R-557A70: Start Time = 985, End Time = 985
# [Time 986]
# Request: R-557AA0, Alice: 6, Bob: 9, Fmin: 0.85, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-9)
# Tempo: 2
# Executando ação: Swap(6-5-9)
# Running Swap(6-5-9)
# Request R-557AA0: Start Time = 986, End Time = 986
# [Time 987]
# Request: R-557AD0, Alice: 1, Bob: 5, Fmin: 0.98, Neprs: 3
# Request R-557AD0: Start Time = 0, End Time = 987
# [Time 988]
# Request: R-557B00, Alice: 3, Bob: 10, Fmin: 1.0, Neprs: 2
# Request R-557B00: Start Time = 0, End Time = 988
# [Time 989]
# Request: R-557B30, Alice: 0, Bob: 7, Fmin: 0.84, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(0-4)
# Executando ação: CreateEPR(4-5)
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(0-4-5)
# Running Swap(0-4-5)
# Executando ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Tempo: 3
# Executando ação: Swap(0-5-7)
# Running Swap(0-5-7)
# Request R-557B30: Start Time = 989, End Time = 989
# [Time 990]
# Request: R-557B60, Alice: 1, Bob: 3, Fmin: 0.78, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(1-2)
# Executando ação: CreateEPR(2-3)
# Tempo: 2
# Executando ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-557B60: Start Time = 990, End Time = 990
# [Time 991]
# Request: R-557B90, Alice: 5, Bob: 10, Fmin: 0.88, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(5-6)
# Executando ação: CreateEPR(6-10)
# Tempo: 2
# Executando ação: Swap(5-6-10)
# Running Swap(5-6-10)
# Request R-557B90: Start Time = 991, End Time = 991
# [Time 992]
# Request: R-557BC0, Alice: 8, Bob: 10, Fmin: 0.73, Neprs: 4
# Tempo: 1
# Executando ação: CreateEPR(8-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(8-9-10)
# Running Swap(8-9-10)
# Request R-557BC0: Start Time = 992, End Time = 992
# [Time 993]
# Request: R-557BF0, Alice: 9, Bob: 0, Fmin: 0.61, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-557BF0: Start Time = 993, End Time = 993
# [Time 994]
# Request: R-557C20, Alice: 1, Bob: 10, Fmin: 0.71, Neprs: 2
# Tempo: 1
# Executando ação: CreateEPR(1-5)
# Executando ação: CreateEPR(5-9)
# Executando ação: CreateEPR(9-10)
# Tempo: 2
# Executando ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-557C20: Start Time = 994, End Time = 994
# [Time 995]
# Request: R-557C50, Alice: 6, Bob: 1, Fmin: 0.6, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(6-5)
# Executando ação: CreateEPR(5-1)
# Tempo: 2
# Executando ação: Swap(6-5-1)
# Running Swap(6-5-1)
# Request R-557C50: Start Time = 995, End Time = 995
# [Time 996]
# Request: R-557C80, Alice: 8, Bob: 1, Fmin: 0.85, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(8-4)
# Executando ação: CreateEPR(4-0)
# Executando ação: CreateEPR(0-1)
# Tempo: 2
# Executando ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-557C80: Start Time = 996, End Time = 996
# [Time 997]
# Request: R-557CB0, Alice: 9, Bob: 4, Fmin: 0.6, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(9-8)
# Executando ação: CreateEPR(8-4)
# Tempo: 2
# Executando ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-557CB0: Start Time = 997, End Time = 997
# [Time 998]
# Request: R-557CE0, Alice: 3, Bob: 2, Fmin: 0.56, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(3-2)
# Request R-557CE0: Start Time = 998, End Time = 998
# [Time 999]
# Request: R-557D10, Alice: 10, Bob: 7, Fmin: 0.59, Neprs: 3
# Tempo: 1
# Executando ação: CreateEPR(10-6)
# Executando ação: CreateEPR(6-7)
# Tempo: 2
# Executando ação: Swap(10-6-7)
# Running Swap(10-6-7)
# Request R-557D10: Start Time = 999, End Time = 999
