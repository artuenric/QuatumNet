# %% [markdown]
# # Preenchimento proativo
# Mostra o comportamento da rede utilizando o preenchimento proativo. Essa simulação registra informações das ``requests``:
#
#     - ID da requisição
#     - Alice
#     - Bob
#     - Fidelidade Mínima
#     - Número de EPRs
#     - Início (Quando começou a ser tratada)
#     - Término (Quando foi atendida)
#     - Novo Registro (Se foi necessário criar uma regra para atender, ou se já foi registrado)

# %%
from quantumnet.components import Controller, Network
from quantumnet.utils import generate_random_request, register_request, clear_file
from quantumnet.objects import time

# %% [markdown]
# Informações para a simulação

# %%
# Caminho do arquivo de saída
path = "resultados/proativo/sync.csv"
# Limpa o arquivo de saída
clear_file(path)
# Sobre a rede
rede = Network()
row, col = 3, 4
rede.set_ready_topology("Grade", (row, col))
# Sobre o controlador
controlador = Controller(rede)
controlador.default_ttl = 100
# Criação de requisições
fmin_range = (0.5, 1)
neprs_range = (2, 4)
num_requests = 100
requests = list(generate_random_request(len(rede.hosts), fmin_range, neprs_range) for i in range(num_requests))

# %% [markdown]
# Preenchimento proativo

# %%
hosts = rede.hosts
for alice in hosts:
    print(f"Adicionando regras para {alice}")
    for bob in hosts:
        controlador.add_match_route_rule_in_host_proactive(alice, bob, (0.5, 0.6), 5)
        controlador.add_match_route_rule_in_host_proactive(alice, bob, (0.8, 0.9), 5)
    rede.get_host(alice).draw_flow_table()
# Out:
# Adicionando regras para 0
# +---------------------+----------------------+--------------------+
# | Match               | Route                | Rule               |
# +=====================+======================+====================+
# | (0, (0.5, 0.6), 5)  | [0]                  | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [0]                  | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [0, 1]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [0, 1]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [0, 1, 2]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [0, 1, 2]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [0, 4]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [0, 4]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [0, 1, 5]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [0, 1, 5]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [0, 4, 8]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [0, 4, 8]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# Adicionando regras para 1
# +---------------------+-------------------+--------------------+
# | Match               | Route             | Rule               |
# +=====================+===================+====================+
# | (0, (0.5, 0.6), 5)  | [1, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [1, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [1]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [1]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [1, 2]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [1, 2]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [1, 2, 3]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [1, 2, 3]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [1, 0, 4]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [1, 0, 4]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [1, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [1, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [1, 2, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [1, 2, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [1, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [1, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# Adicionando regras para 2
# +---------------------+-----------------+--------------------+
# | Match               | Route           | Rule               |
# +=====================+=================+====================+
# | (0, (0.5, 0.6), 5)  | [2, 1, 0]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [2, 1, 0]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [2, 1]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [2, 1]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [2]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [2]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [2, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [2, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [2, 1, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [2, 1, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [2, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [2, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [2, 3, 7]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [2, 3, 7]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.5, 0.6), 5) | [2, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 5) | [2, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.5, 0.6), 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# Adicionando regras para 3
# +---------------------+--------------------+--------------------+
# | Match               | Route              | Rule               |
# +=====================+====================+====================+
# | (0, (0.5, 0.6), 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [3, 2, 1]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [3, 2, 1]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [3, 2]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [3, 2]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [3]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [3]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [3, 2, 6]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [3, 2, 6]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [3, 7]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [3, 7]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [3, 7, 11]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [3, 7, 11]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# Adicionando regras para 4
# +---------------------+-------------------+--------------------+
# | Match               | Route             | Rule               |
# +=====================+===================+====================+
# | (0, (0.5, 0.6), 5)  | [4, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [4, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [4, 0, 1]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [4, 0, 1]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [4]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [4]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [4, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [4, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [4, 5, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [4, 5, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [4, 8]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [4, 8]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [4, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [4, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# Adicionando regras para 5
# +---------------------+---------------+--------------------+
# | Match               | Route         | Rule               |
# +=====================+===============+====================+
# | (0, (0.5, 0.6), 5)  | [5, 4, 0]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [5, 4, 0]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [5, 1]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [5, 1]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [5, 1, 2]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [5, 1, 2]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [5, 4]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [5, 4]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [5]           | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [5]           | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [5, 6]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [5, 6]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [5, 6, 7]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [5, 6, 7]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [5, 4, 8]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [5, 4, 8]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [5, 9]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [5, 9]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (10, (0.5, 0.6), 5) | [5, 6, 10]    | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (10, (0.8, 0.9), 5) | [5, 6, 10]    | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (11, (0.5, 0.6), 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (11, (0.8, 0.9), 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# Adicionando regras para 6
# +---------------------+--------------+--------------------+
# | Match               | Route        | Rule               |
# +=====================+==============+====================+
# | (0, (0.5, 0.6), 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [6, 5, 1]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [6, 5, 1]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [6, 2]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [6, 2]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [6, 2, 3]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [6, 2, 3]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [6, 5, 4]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [6, 5, 4]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [6, 5]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [6, 5]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [6]          | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [6]          | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [6, 7]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [6, 7]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [6, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [6, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (10, (0.5, 0.6), 5) | [6, 10]      | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (10, (0.8, 0.9), 5) | [6, 10]      | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (11, (0.5, 0.6), 5) | [6, 7, 11]   | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (11, (0.8, 0.9), 5) | [6, 7, 11]   | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# Adicionando regras para 7
# +---------------------+-----------------+--------------------+
# | Match               | Route           | Rule               |
# +=====================+=================+====================+
# | (0, (0.5, 0.6), 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [7, 6, 2]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [7, 6, 2]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [7, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [7, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [7, 6, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [7, 6, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [7, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [7, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [7]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [7]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.5, 0.6), 5) | [7, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 5) | [7, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.5, 0.6), 5) | [7, 11]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 5) | [7, 11]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# Adicionando regras para 8
# +---------------------+--------------------+--------------------+
# | Match               | Route              | Rule               |
# +=====================+====================+====================+
# | (0, (0.5, 0.6), 5)  | [8, 4, 0]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [8, 4, 0]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [8, 4]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [8, 4]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [8, 4, 5]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [8, 4, 5]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [8]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [8]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [8, 9]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [8, 9]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [8, 9, 10]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [8, 9, 10]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# Adicionando regras para 9
# +---------------------+-----------------+--------------------+
# | Match               | Route           | Rule               |
# +=====================+=================+====================+
# | (0, (0.5, 0.6), 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [9, 5, 1]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [9, 5, 1]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [9, 8, 4]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [9, 8, 4]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [9, 5]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [9, 5]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [9, 5, 6]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [9, 5, 6]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [9, 8]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [9, 8]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [9]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [9]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.5, 0.6), 5) | [9, 10]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 5) | [9, 10]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.5, 0.6), 5) | [9, 10, 11]     | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 5) | [9, 10, 11]     | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# Adicionando regras para 10
# +---------------------+------------------+--------------------+
# | Match               | Route            | Rule               |
# +=====================+==================+====================+
# | (0, (0.5, 0.6), 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [10, 6, 2]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [10, 6, 2]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [10, 9, 5]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [10, 9, 5]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [10, 6]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [10, 6]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [10, 6, 7]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [10, 6, 7]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [10, 9, 8]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [10, 9, 8]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [10, 9]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [10, 9]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [10]             | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [10]             | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [10, 11]         | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [10, 11]         | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# Adicionando regras para 11
# +---------------------+---------------------+--------------------+
# | Match               | Route               | Rule               |
# +=====================+=====================+====================+
# | (0, (0.5, 0.6), 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [11, 7, 3]          | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [11, 7, 3]          | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [11, 10, 6]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [11, 10, 6]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [11, 7]             | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [11, 7]             | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [11, 10, 9]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [11, 10, 9]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [11, 10]            | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [11, 10]            | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [11]                | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [11]                | BasicRuleProactive |
# +---------------------+---------------------+--------------------+

# %% [markdown]
# Funções responsáveis pela passagem de tempo

# %%
def update_time(time_for_update):
    """
    Atualiza o tempo e as regras

    Args:
        time_for_update (int): Tempo para incrementar o time-slot.
    """
    # Atualiza o tempo
    for t in range(time_for_update):
        time.increment()
        # Atualiza os recursos de 10 em 10
        if time.get_current_time() % 10 == 0:
            rede.refresh_resources(num_qubits=10, num_eprs=10)
            print(f"[Time {time.get_current_time()}] Recursos atualizados")

# %% [markdown]
# Requests sendo processadas

# %%
for request in requests:
    print(f"[Time {time.get_current_time()}]")
    print(f"Request: {request}, Alice: {request.alice}, Bob: {request.bob}, Fmin: {request.fmin}, Neprs: {request.neprs}")
    alice = rede.get_host(request.alice)
    rule = alice.find_rule_by_request(request)

    if rule == False:  # Caso não exista um match na tabela
        print(f"Descartando requisição {request} em {alice}")
        request.endtime = time.get_current_time()
        # Registra no CSV como um novo registro
        register_request(request, "Descartado", path)
    else:  # Caso já exista a regra
        request.starttime = time.get_current_time()
        controlador.run_rule(rule[1])
        request.endtime = time.get_current_time() + 1
        
        # Registra no CSV como já registrado
        register_request(request, "Já Registrado", path)
    
    update_time(1)
    # Exibir informações da requisição
    print(f"Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")
# Out:
# [Time 0]
# Request: R-BD8980, Alice: 0, Bob: 11, Fmin: 0.84, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Ação: CreateEPR(8-9)
# [BasicRuleProactive] Ação: CreateEPR(9-10)
# [BasicRuleProactive] Ação: CreateEPR(10-11)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(0-4-8)
# Running Swap(0-4-8)
# [BasicRuleProactive] Ação: Swap(8-9-10)
# Running Swap(8-9-10)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(0-8-10)
# Running Swap(0-8-10)
# Request R-BD8980: Start Time = 0, End Time = 1
# [Time 1]
# Request: R-3C65D0, Alice: 1, Bob: 9, Fmin: 0.62, Neprs: 4
# Descartando requisição R-3C65D0 em 1
# Request R-3C65D0: Start Time = 0, End Time = 1
# [Time 2]
# Request: R-ADE710, Alice: 1, Bob: 8, Fmin: 0.93, Neprs: 3
# Descartando requisição R-ADE710 em 1
# Request R-ADE710: Start Time = 0, End Time = 2
# [Time 3]
# Request: R-AEAEA0, Alice: 3, Bob: 4, Fmin: 0.99, Neprs: 4
# Descartando requisição R-AEAEA0 em 3
# Request R-AEAEA0: Start Time = 0, End Time = 3
# [Time 4]
# Request: R-AEAFD0, Alice: 4, Bob: 0, Fmin: 0.7, Neprs: 4
# Descartando requisição R-AEAFD0 em 4
# Request R-AEAFD0: Start Time = 0, End Time = 4
# [Time 5]
# Request: R-AE3890, Alice: 4, Bob: 8, Fmin: 0.53, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# Request R-AE3890: Start Time = 5, End Time = 6
# [Time 6]
# Request: R-B4EE00, Alice: 5, Bob: 8, Fmin: 0.83, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(5-4-8)
# Running Swap(5-4-8)
# Request R-B4EE00: Start Time = 6, End Time = 7
# [Time 7]
# Request: R-B4EF10, Alice: 4, Bob: 6, Fmin: 0.7, Neprs: 4
# Descartando requisição R-B4EF10 em 4
# Request R-B4EF10: Start Time = 0, End Time = 7
# [Time 8]
# Request: R-B8D150, Alice: 0, Bob: 8, Fmin: 0.95, Neprs: 2
# Descartando requisição R-B8D150 em 0
# Request R-B8D150: Start Time = 0, End Time = 8
# [Time 9]
# Request: R-B8D250, Alice: 7, Bob: 2, Fmin: 0.81, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-2)
# Running Swap(7-6-2)
# [Time 10] Recursos atualizados
# Request R-B8D250: Start Time = 9, End Time = 10
# [Time 10]
# Request: R-BD05F0, Alice: 9, Bob: 8, Fmin: 1.0, Neprs: 4
# Descartando requisição R-BD05F0 em 9
# Request R-BD05F0: Start Time = 0, End Time = 10
# [Time 11]
# Request: R-BD08C0, Alice: 8, Bob: 4, Fmin: 0.55, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# Request R-BD08C0: Start Time = 11, End Time = 12
# [Time 12]
# Request: R-B9FBD0, Alice: 9, Bob: 11, Fmin: 0.87, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-10)
# [BasicRuleProactive] Ação: CreateEPR(10-11)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-10-11)
# Running Swap(9-10-11)
# Request R-B9FBD0: Start Time = 12, End Time = 13
# [Time 13]
# Request: R-B9FE70, Alice: 10, Bob: 2, Fmin: 0.57, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-B9FE70: Start Time = 13, End Time = 14
# [Time 14]
# Request: R-BC32B0, Alice: 10, Bob: 2, Fmin: 0.53, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-BC32B0: Start Time = 14, End Time = 15
# [Time 15]
# Request: R-A37E90, Alice: 6, Bob: 5, Fmin: 0.7, Neprs: 3
# Descartando requisição R-A37E90 em 6
# Request R-A37E90: Start Time = 0, End Time = 15
# [Time 16]
# Request: R-A37F50, Alice: 3, Bob: 6, Fmin: 0.86, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-6)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(3-2-6)
# Running Swap(3-2-6)
# Request R-A37F50: Start Time = 16, End Time = 17
# [Time 17]
# Request: R-B5DF40, Alice: 3, Bob: 2, Fmin: 0.55, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# Request R-B5DF40: Start Time = 17, End Time = 18
# [Time 18]
# Request: R-B5DFF0, Alice: 0, Bob: 5, Fmin: 0.73, Neprs: 3
# Descartando requisição R-B5DFF0 em 0
# Request R-B5DFF0: Start Time = 0, End Time = 18
# [Time 19]
# Request: R-576030, Alice: 11, Bob: 8, Fmin: 0.76, Neprs: 2
# Descartando requisição R-576030 em 11
# [Time 20] Recursos atualizados
# Request R-576030: Start Time = 0, End Time = 19
# [Time 20]
# Request: R-576DF0, Alice: 1, Bob: 11, Fmin: 0.74, Neprs: 4
# Descartando requisição R-576DF0 em 1
# Request R-576DF0: Start Time = 0, End Time = 20
# [Time 21]
# Request: R-3E2D50, Alice: 5, Bob: 1, Fmin: 0.95, Neprs: 3
# Descartando requisição R-3E2D50 em 5
# Request R-3E2D50: Start Time = 0, End Time = 21
# [Time 22]
# Request: R-BED750, Alice: 10, Bob: 11, Fmin: 0.75, Neprs: 2
# Descartando requisição R-BED750 em 10
# Request R-BED750: Start Time = 0, End Time = 22
# [Time 23]
# Request: R-BED850, Alice: 5, Bob: 10, Fmin: 0.61, Neprs: 3
# Descartando requisição R-BED850 em 5
# Request R-BED850: Start Time = 0, End Time = 23
# [Time 24]
# Request: R-BED8D0, Alice: 10, Bob: 6, Fmin: 0.76, Neprs: 4
# Descartando requisição R-BED8D0 em 10
# Request R-BED8D0: Start Time = 0, End Time = 24
# [Time 25]
# Request: R-BED950, Alice: 5, Bob: 9, Fmin: 0.84, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-9)
# Request R-BED950: Start Time = 25, End Time = 26
# [Time 26]
# Request: R-BED9D0, Alice: 11, Bob: 8, Fmin: 0.65, Neprs: 2
# Descartando requisição R-BED9D0 em 11
# Request R-BED9D0: Start Time = 0, End Time = 26
# [Time 27]
# Request: R-BEDA50, Alice: 3, Bob: 5, Fmin: 0.74, Neprs: 2
# Descartando requisição R-BEDA50 em 3
# Request R-BEDA50: Start Time = 0, End Time = 27
# [Time 28]
# Request: R-BEDAD0, Alice: 1, Bob: 11, Fmin: 0.7, Neprs: 4
# Descartando requisição R-BEDAD0 em 1
# Request R-BEDAD0: Start Time = 0, End Time = 28
# [Time 29]
# Request: R-BEDB50, Alice: 10, Bob: 6, Fmin: 0.65, Neprs: 2
# Descartando requisição R-BEDB50 em 10
# [Time 30] Recursos atualizados
# Request R-BEDB50: Start Time = 0, End Time = 29
# [Time 30]
# Request: R-BEDBD0, Alice: 7, Bob: 8, Fmin: 0.77, Neprs: 2
# Descartando requisição R-BEDBD0 em 7
# Request R-BEDBD0: Start Time = 0, End Time = 30
# [Time 31]
# Request: R-BEDC50, Alice: 4, Bob: 3, Fmin: 0.6, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(4-0-1)
# Running Swap(4-0-1)
# [BasicRuleProactive] Ação: Swap(1-2-3)
# Running Swap(1-2-3)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-BEDC50: Start Time = 31, End Time = 32
# [Time 32]
# Request: R-BEDCD0, Alice: 10, Bob: 11, Fmin: 0.9, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-11)
# Request R-BEDCD0: Start Time = 32, End Time = 33
# [Time 33]
# Request: R-BEDD50, Alice: 1, Bob: 9, Fmin: 0.74, Neprs: 3
# Descartando requisição R-BEDD50 em 1
# Request R-BEDD50: Start Time = 0, End Time = 33
# [Time 34]
# Request: R-BEDDD0, Alice: 1, Bob: 6, Fmin: 0.93, Neprs: 4
# Descartando requisição R-BEDDD0 em 1
# Request R-BEDDD0: Start Time = 0, End Time = 34
# [Time 35]
# Request: R-BEDE50, Alice: 10, Bob: 9, Fmin: 0.64, Neprs: 4
# Descartando requisição R-BEDE50 em 10
# Request R-BEDE50: Start Time = 0, End Time = 35
# [Time 36]
# Request: R-BEDED0, Alice: 5, Bob: 11, Fmin: 0.68, Neprs: 4
# Descartando requisição R-BEDED0 em 5
# Request R-BEDED0: Start Time = 0, End Time = 36
# [Time 37]
# Request: R-BEDF50, Alice: 4, Bob: 5, Fmin: 0.91, Neprs: 4
# Descartando requisição R-BEDF50 em 4
# Request R-BEDF50: Start Time = 0, End Time = 37
# [Time 38]
# Request: R-BEDFD0, Alice: 10, Bob: 2, Fmin: 0.52, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-BEDFD0: Start Time = 38, End Time = 39
# [Time 39]
# Request: R-BEE050, Alice: 9, Bob: 2, Fmin: 0.71, Neprs: 2
# Descartando requisição R-BEE050 em 9
# [Time 40] Recursos atualizados
# Request R-BEE050: Start Time = 0, End Time = 39
# [Time 40]
# Request: R-BEE0D0, Alice: 9, Bob: 6, Fmin: 0.86, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-BEE0D0: Start Time = 40, End Time = 41
# [Time 41]
# Request: R-BEE150, Alice: 3, Bob: 6, Fmin: 0.97, Neprs: 2
# Descartando requisição R-BEE150 em 3
# Request R-BEE150: Start Time = 0, End Time = 41
# [Time 42]
# Request: R-BEE1D0, Alice: 9, Bob: 8, Fmin: 0.8, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-8)
# Request R-BEE1D0: Start Time = 42, End Time = 43
# [Time 43]
# Request: R-BEE250, Alice: 2, Bob: 11, Fmin: 0.97, Neprs: 3
# Descartando requisição R-BEE250 em 2
# Request R-BEE250: Start Time = 0, End Time = 43
# [Time 44]
# Request: R-BEE2D0, Alice: 0, Bob: 11, Fmin: 0.71, Neprs: 4
# Descartando requisição R-BEE2D0 em 0
# Request R-BEE2D0: Start Time = 0, End Time = 44
# [Time 45]
# Request: R-BEE350, Alice: 5, Bob: 4, Fmin: 0.66, Neprs: 3
# Descartando requisição R-BEE350 em 5
# Request R-BEE350: Start Time = 0, End Time = 45
# [Time 46]
# Request: R-BEE3D0, Alice: 4, Bob: 8, Fmin: 0.51, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# Request R-BEE3D0: Start Time = 46, End Time = 47
# [Time 47]
# Request: R-BEE450, Alice: 3, Bob: 2, Fmin: 0.79, Neprs: 3
# Descartando requisição R-BEE450 em 3
# Request R-BEE450: Start Time = 0, End Time = 47
# [Time 48]
# Request: R-BEE4D0, Alice: 10, Bob: 0, Fmin: 0.95, Neprs: 2
# Descartando requisição R-BEE4D0 em 10
# Request R-BEE4D0: Start Time = 0, End Time = 48
# [Time 49]
# Request: R-BEE550, Alice: 7, Bob: 6, Fmin: 0.68, Neprs: 3
# Descartando requisição R-BEE550 em 7
# [Time 50] Recursos atualizados
# Request R-BEE550: Start Time = 0, End Time = 49
# [Time 50]
# Request: R-BEE5D0, Alice: 5, Bob: 4, Fmin: 0.96, Neprs: 3
# Descartando requisição R-BEE5D0 em 5
# Request R-BEE5D0: Start Time = 0, End Time = 50
# [Time 51]
# Request: R-BEE650, Alice: 7, Bob: 8, Fmin: 0.82, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-5)
# Running Swap(7-6-5)
# [BasicRuleProactive] Ação: Swap(5-4-8)
# Running Swap(5-4-8)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(7-5-8)
# Running Swap(7-5-8)
# Request R-BEE650: Start Time = 51, End Time = 52
# [Time 52]
# Request: R-BEE6D0, Alice: 10, Bob: 6, Fmin: 0.54, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# Request R-BEE6D0: Start Time = 52, End Time = 53
# [Time 53]
# Request: R-BEE750, Alice: 11, Bob: 6, Fmin: 0.98, Neprs: 4
# Descartando requisição R-BEE750 em 11
# Request R-BEE750: Start Time = 0, End Time = 53
# [Time 54]
# Request: R-BEE7D0, Alice: 5, Bob: 4, Fmin: 0.98, Neprs: 4
# Descartando requisição R-BEE7D0 em 5
# Request R-BEE7D0: Start Time = 0, End Time = 54
# [Time 55]
# Request: R-BEE850, Alice: 8, Bob: 6, Fmin: 0.94, Neprs: 2
# Descartando requisição R-BEE850 em 8
# Request R-BEE850: Start Time = 0, End Time = 55
# [Time 56]
# Request: R-BEE8D0, Alice: 3, Bob: 8, Fmin: 0.66, Neprs: 2
# Descartando requisição R-BEE8D0 em 3
# Request R-BEE8D0: Start Time = 0, End Time = 56
# [Time 57]
# Request: R-BEE950, Alice: 5, Bob: 9, Fmin: 0.74, Neprs: 4
# Descartando requisição R-BEE950 em 5
# Request R-BEE950: Start Time = 0, End Time = 57
# [Time 58]
# Request: R-BEE9D0, Alice: 1, Bob: 10, Fmin: 0.65, Neprs: 3
# Descartando requisição R-BEE9D0 em 1
# Request R-BEE9D0: Start Time = 0, End Time = 58
# [Time 59]
# Request: R-BEEA50, Alice: 7, Bob: 3, Fmin: 0.97, Neprs: 4
# Descartando requisição R-BEEA50 em 7
# [Time 60] Recursos atualizados
# Request R-BEEA50: Start Time = 0, End Time = 59
# [Time 60]
# Request: R-BEEAD0, Alice: 3, Bob: 0, Fmin: 0.81, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request R-BEEAD0: Start Time = 60, End Time = 61
# [Time 61]
# Request: R-BEEB50, Alice: 6, Bob: 10, Fmin: 0.8, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(6-10)
# Request R-BEEB50: Start Time = 61, End Time = 62
# [Time 62]
# Request: R-BEEBD0, Alice: 7, Bob: 6, Fmin: 0.59, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# Request R-BEEBD0: Start Time = 62, End Time = 63
# [Time 63]
# Request: R-BEEC50, Alice: 9, Bob: 3, Fmin: 0.97, Neprs: 4
# Descartando requisição R-BEEC50 em 9
# Request R-BEEC50: Start Time = 0, End Time = 63
# [Time 64]
# Request: R-BEECD0, Alice: 7, Bob: 4, Fmin: 0.73, Neprs: 3
# Descartando requisição R-BEECD0 em 7
# Request R-BEECD0: Start Time = 0, End Time = 64
# [Time 65]
# Request: R-BEED50, Alice: 8, Bob: 5, Fmin: 0.87, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-BEED50: Start Time = 65, End Time = 66
# [Time 66]
# Request: R-BEEDD0, Alice: 11, Bob: 1, Fmin: 1.0, Neprs: 4
# Descartando requisição R-BEEDD0 em 11
# Request R-BEEDD0: Start Time = 0, End Time = 66
# [Time 67]
# Request: R-BEEE50, Alice: 9, Bob: 0, Fmin: 0.6, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-8)
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-BEEE50: Start Time = 67, End Time = 68
# [Time 68]
# Request: R-BEEED0, Alice: 6, Bob: 3, Fmin: 0.59, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(6-2-3)
# Running Swap(6-2-3)
# Request R-BEEED0: Start Time = 68, End Time = 69
# [Time 69]
# Request: R-BEEF50, Alice: 9, Bob: 3, Fmin: 0.74, Neprs: 2
# Descartando requisição R-BEEF50 em 9
# [Time 70] Recursos atualizados
# Request R-BEEF50: Start Time = 0, End Time = 69
# [Time 70]
# Request: R-BEEFD0, Alice: 8, Bob: 3, Fmin: 0.78, Neprs: 2
# Descartando requisição R-BEEFD0 em 8
# Request R-BEEFD0: Start Time = 0, End Time = 70
# [Time 71]
# Request: R-BEF050, Alice: 6, Bob: 3, Fmin: 0.51, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(6-2-3)
# Running Swap(6-2-3)
# Request R-BEF050: Start Time = 71, End Time = 72
# [Time 72]
# Request: R-BEF0D0, Alice: 11, Bob: 0, Fmin: 0.59, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(11-7)
# [BasicRuleProactive] Ação: CreateEPR(7-3)
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(11-7-3)
# Running Swap(11-7-3)
# [BasicRuleProactive] Ação: Swap(3-2-1)
# Running Swap(3-2-1)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(11-3-1)
# Running Swap(11-3-1)
# Request R-BEF0D0: Start Time = 72, End Time = 73
# [Time 73]
# Request: R-BEF150, Alice: 7, Bob: 6, Fmin: 0.96, Neprs: 3
# Descartando requisição R-BEF150 em 7
# Request R-BEF150: Start Time = 0, End Time = 73
# [Time 74]
# Request: R-BEF1D0, Alice: 4, Bob: 11, Fmin: 0.76, Neprs: 3
# Descartando requisição R-BEF1D0 em 4
# Request R-BEF1D0: Start Time = 0, End Time = 74
# [Time 75]
# Request: R-BEF250, Alice: 1, Bob: 3, Fmin: 0.88, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-BEF250: Start Time = 75, End Time = 76
# [Time 76]
# Request: R-BEF2D0, Alice: 11, Bob: 7, Fmin: 0.67, Neprs: 2
# Descartando requisição R-BEF2D0 em 11
# Request R-BEF2D0: Start Time = 0, End Time = 76
# [Time 77]
# Request: R-BEF350, Alice: 4, Bob: 2, Fmin: 0.94, Neprs: 3
# Descartando requisição R-BEF350 em 4
# Request R-BEF350: Start Time = 0, End Time = 77
# [Time 78]
# Request: R-BEF3D0, Alice: 9, Bob: 0, Fmin: 0.53, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-8)
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-8-4)
# Running Swap(9-8-4)
# Request R-BEF3D0: Start Time = 78, End Time = 79
# [Time 79]
# Request: R-BEF450, Alice: 5, Bob: 8, Fmin: 0.65, Neprs: 3
# Descartando requisição R-BEF450 em 5
# [Time 80] Recursos atualizados
# Request R-BEF450: Start Time = 0, End Time = 79
# [Time 80]
# Request: R-BEF4D0, Alice: 3, Bob: 5, Fmin: 0.77, Neprs: 4
# Descartando requisição R-BEF4D0 em 3
# Request R-BEF4D0: Start Time = 0, End Time = 80
# [Time 81]
# Request: R-BEF550, Alice: 0, Bob: 7, Fmin: 0.54, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(0-4-5)
# Running Swap(0-4-5)
# [BasicRuleProactive] Ação: Swap(5-6-7)
# Running Swap(5-6-7)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(0-5-7)
# Running Swap(0-5-7)
# Request R-BEF550: Start Time = 81, End Time = 82
# [Time 82]
# Request: R-BEF5D0, Alice: 0, Bob: 3, Fmin: 0.69, Neprs: 4
# Descartando requisição R-BEF5D0 em 0
# Request R-BEF5D0: Start Time = 0, End Time = 82
# [Time 83]
# Request: R-BEF650, Alice: 10, Bob: 8, Fmin: 0.76, Neprs: 3
# Descartando requisição R-BEF650 em 10
# Request R-BEF650: Start Time = 0, End Time = 83
# [Time 84]
# Request: R-BEF6D0, Alice: 4, Bob: 5, Fmin: 0.84, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# Request R-BEF6D0: Start Time = 84, End Time = 85
# [Time 85]
# Request: R-BEF750, Alice: 6, Bob: 7, Fmin: 0.61, Neprs: 4
# Descartando requisição R-BEF750 em 6
# Request R-BEF750: Start Time = 0, End Time = 85
# [Time 86]
# Request: R-BEF7D0, Alice: 4, Bob: 0, Fmin: 0.59, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# Request R-BEF7D0: Start Time = 86, End Time = 87
# [Time 87]
# Request: R-BEF850, Alice: 3, Bob: 1, Fmin: 0.67, Neprs: 3
# Descartando requisição R-BEF850 em 3
# Request R-BEF850: Start Time = 0, End Time = 87
# [Time 88]
# Request: R-BEF8D0, Alice: 2, Bob: 9, Fmin: 0.61, Neprs: 2
# Descartando requisição R-BEF8D0 em 2
# Request R-BEF8D0: Start Time = 0, End Time = 88
# [Time 89]
# Request: R-BEF950, Alice: 6, Bob: 4, Fmin: 0.73, Neprs: 3
# Descartando requisição R-BEF950 em 6
# [Time 90] Recursos atualizados
# Request R-BEF950: Start Time = 0, End Time = 89
# [Time 90]
# Request: R-BEF9D0, Alice: 8, Bob: 3, Fmin: 0.74, Neprs: 4
# Descartando requisição R-BEF9D0 em 8
# Request R-BEF9D0: Start Time = 0, End Time = 90
# [Time 91]
# Request: R-BEFA50, Alice: 1, Bob: 5, Fmin: 0.73, Neprs: 4
# Descartando requisição R-BEFA50 em 1
# Request R-BEFA50: Start Time = 0, End Time = 91
# [Time 92]
# Request: R-BEFAD0, Alice: 6, Bob: 4, Fmin: 0.99, Neprs: 3
# Descartando requisição R-BEFAD0 em 6
# Request R-BEFAD0: Start Time = 0, End Time = 92
# [Time 93]
# Request: R-BEFB50, Alice: 7, Bob: 2, Fmin: 0.94, Neprs: 2
# Descartando requisição R-BEFB50 em 7
# Request R-BEFB50: Start Time = 0, End Time = 93
# [Time 94]
# Request: R-BEFBD0, Alice: 11, Bob: 5, Fmin: 0.92, Neprs: 3
# Descartando requisição R-BEFBD0 em 11
# Request R-BEFBD0: Start Time = 0, End Time = 94
# [Time 95]
# Request: R-BEFC50, Alice: 3, Bob: 8, Fmin: 0.99, Neprs: 4
# Descartando requisição R-BEFC50 em 3
# Request R-BEFC50: Start Time = 0, End Time = 95
# [Time 96]
# Request: R-BEFCD0, Alice: 5, Bob: 7, Fmin: 0.89, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Request R-BEFCD0: Start Time = 96, End Time = 97
# [Time 97]
# Request: R-BEFD50, Alice: 1, Bob: 3, Fmin: 0.95, Neprs: 2
# Descartando requisição R-BEFD50 em 1
# Request R-BEFD50: Start Time = 0, End Time = 97
# [Time 98]
# Request: R-BEFDD0, Alice: 5, Bob: 3, Fmin: 0.93, Neprs: 4
# Descartando requisição R-BEFDD0 em 5
# Request R-BEFDD0: Start Time = 0, End Time = 98
# [Time 99]
# Request: R-BEFE50, Alice: 10, Bob: 7, Fmin: 0.89, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-7)
# Running Swap(10-6-7)
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 0.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 1.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 2.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 3.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 4.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 5.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 6.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 7.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 8.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 9.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 10.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [BasicRuleProactive] Regra fechada e removida do Host 11.
# [Time 100] Recursos atualizados
# Request R-BEFE50: Start Time = 99, End Time = 100

# %% [markdown]
# Registro de recursos

# %%
rede.registry_of_resources
# Out:
# {'qubits created': 1320,
#  'qubits used': 142,
#  'eprs created': 3231,
#  'eprs used': 0}

# %% [markdown]
# Tabelas ao final

# %%
for alice in hosts:
    print(f"Regras de {alice}")
    rede.get_host(alice).draw_flow_table()
# Out:
# Regras de 0
# +---------------------+----------------------+--------------------+
# | Match               | Route                | Rule               |
# +=====================+======================+====================+
# | (7, (0.5, 0.6), 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# Regras de 1
# +--------------------+-----------+--------------------+
# | Match              | Route     | Rule               |
# +====================+===========+====================+
# | (3, (0.8, 0.9), 5) | [1, 2, 3] | BasicRuleProactive |
# +--------------------+-----------+--------------------+
# Regras de 2
# +---------+---------+--------+
# | Match   | Route   | Rule   |
# +=========+=========+========+
# +---------+---------+--------+
# Regras de 3
# +--------------------+--------------+--------------------+
# | Match              | Route        | Rule               |
# +====================+==============+====================+
# | (0, (0.8, 0.9), 5) | [3, 2, 1, 0] | BasicRuleProactive |
# +--------------------+--------------+--------------------+
# | (2, (0.5, 0.6), 5) | [3, 2]       | BasicRuleProactive |
# +--------------------+--------------+--------------------+
# | (6, (0.8, 0.9), 5) | [3, 2, 6]    | BasicRuleProactive |
# +--------------------+--------------+--------------------+
# Regras de 4
# +--------------------+-----------------+--------------------+
# | Match              | Route           | Rule               |
# +====================+=================+====================+
# | (0, (0.5, 0.6), 5) | [4, 0]          | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5) | [4, 0, 1, 2, 3] | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5) | [4, 5]          | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5) | [4, 8]          | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# Regras de 5
# +--------------------+-----------+--------------------+
# | Match              | Route     | Rule               |
# +====================+===========+====================+
# | (7, (0.8, 0.9), 5) | [5, 6, 7] | BasicRuleProactive |
# +--------------------+-----------+--------------------+
# | (8, (0.8, 0.9), 5) | [5, 4, 8] | BasicRuleProactive |
# +--------------------+-----------+--------------------+
# | (9, (0.8, 0.9), 5) | [5, 9]    | BasicRuleProactive |
# +--------------------+-----------+--------------------+
# Regras de 6
# +---------------------+-----------+--------------------+
# | Match               | Route     | Rule               |
# +=====================+===========+====================+
# | (3, (0.5, 0.6), 5)  | [6, 2, 3] | BasicRuleProactive |
# +---------------------+-----------+--------------------+
# | (10, (0.8, 0.9), 5) | [6, 10]   | BasicRuleProactive |
# +---------------------+-----------+--------------------+
# Regras de 7
# +--------------------+-----------------+--------------------+
# | Match              | Route           | Rule               |
# +====================+=================+====================+
# | (2, (0.8, 0.9), 5) | [7, 6, 2]       | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5) | [7, 6]          | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5) | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +--------------------+-----------------+--------------------+
# Regras de 8
# +--------------------+-----------+--------------------+
# | Match              | Route     | Rule               |
# +====================+===========+====================+
# | (4, (0.5, 0.6), 5) | [8, 4]    | BasicRuleProactive |
# +--------------------+-----------+--------------------+
# | (5, (0.8, 0.9), 5) | [8, 4, 5] | BasicRuleProactive |
# +--------------------+-----------+--------------------+
# Regras de 9
# +---------------------+--------------+--------------------+
# | Match               | Route        | Rule               |
# +=====================+==============+====================+
# | (0, (0.5, 0.6), 5)  | [9, 8, 4, 0] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [9, 5, 6]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [9, 8]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (11, (0.8, 0.9), 5) | [9, 10, 11]  | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# Regras de 10
# +---------------------+------------+--------------------+
# | Match               | Route      | Rule               |
# +=====================+============+====================+
# | (2, (0.5, 0.6), 5)  | [10, 6, 2] | BasicRuleProactive |
# +---------------------+------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [10, 6]    | BasicRuleProactive |
# +---------------------+------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [10, 6, 7] | BasicRuleProactive |
# +---------------------+------------+--------------------+
# | (11, (0.8, 0.9), 5) | [10, 11]   | BasicRuleProactive |
# +---------------------+------------+--------------------+
# Regras de 11
# +--------------------+---------------------+--------------------+
# | Match              | Route               | Rule               |
# +====================+=====================+====================+
# | (0, (0.5, 0.6), 5) | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +--------------------+---------------------+--------------------+
