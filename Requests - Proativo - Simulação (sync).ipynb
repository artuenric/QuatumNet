# %% [markdown]
# # Preenchimento proativo
# Mostra o comportamento da rede utilizando o preenchimento proativo. Essa simulação registra informações das ``requests``:
#
#     - ID da requisição
#     - Alice
#     - Bob
#     - Fidelidade Mínima
#     - Número de EPRs
#     - Início (Quando começou a ser tratada)
#     - Término (Quando foi atendida)
#     - Novo Registro (Se foi necessário criar uma regra para atender, ou se já foi registrado)

# %%
from quantumnet.components import Controller, Network
from quantumnet.utils import generate_random_request, register_request, clear_file
from quantumnet.objects import time

# %% [markdown]
# Informações para a simulação

# %%
# Caminho do arquivo de saída
path = "resultados/proativo/sync.csv"
# Limpa o arquivo de saída
clear_file(path)
# Sobre a rede
rede = Network()
row, col = 3, 4
rede.set_ready_topology("Grade", row, col)
# Sobre o controlador
controlador = Controller(rede)
controlador.default_ttl = 100
# Criação de requisições
fmin_range = (0.5, 1)
neprs_range = (2, 4)
num_requests = 100
requests = list(generate_random_request(len(rede.hosts)-1, fmin_range, neprs_range) for i in range(num_requests))

# %% [markdown]
# Preenchimento proativo

# %%
hosts = rede.hosts
for alice in hosts:
    print(f"Adicionando regras para {alice}")
    for bob in hosts:
        controlador.add_match_route_rule_in_host_proactive(alice, bob, (0.5, 0.6), 5)
        controlador.add_match_route_rule_in_host_proactive(alice, bob, (0.8, 0.9), 5)
    rede.get_host(alice).draw_flow_table()
# Out:
# Adicionando regras para 0
# +---------------------+----------------------+--------------------+
# | Match               | Route                | Rule               |
# +=====================+======================+====================+
# | (0, (0.5, 0.6), 5)  | [0]                  | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [0]                  | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [0, 1]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [0, 1]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [0, 1, 2]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [0, 1, 2]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [0, 1, 2, 3]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [0, 4]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [0, 4]               | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [0, 1, 5]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [0, 1, 5]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [0, 4, 5, 6]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [0, 4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [0, 4, 8]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [0, 4, 8]            | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [0, 4, 8, 9]         | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [0, 4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [0, 4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+----------------------+--------------------+
# Adicionando regras para 1
# +---------------------+-------------------+--------------------+
# | Match               | Route             | Rule               |
# +=====================+===================+====================+
# | (0, (0.5, 0.6), 5)  | [1, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [1, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [1]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [1]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [1, 2]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [1, 2]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [1, 2, 3]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [1, 2, 3]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [1, 0, 4]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [1, 0, 4]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [1, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [1, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [1, 2, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [1, 2, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [1, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [1, 0, 4, 8]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [1, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [1, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [1, 5, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [1, 5, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# Adicionando regras para 2
# +---------------------+-----------------+--------------------+
# | Match               | Route           | Rule               |
# +=====================+=================+====================+
# | (0, (0.5, 0.6), 5)  | [2, 1, 0]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [2, 1, 0]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [2, 1]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [2, 1]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [2]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [2]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [2, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [2, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [2, 1, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [2, 1, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [2, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [2, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [2, 3, 7]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [2, 3, 7]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.5, 0.6), 5) | [2, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 5) | [2, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.5, 0.6), 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 5) | [2, 3, 7, 11]   | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# Adicionando regras para 3
# +---------------------+--------------------+--------------------+
# | Match               | Route              | Rule               |
# +=====================+====================+====================+
# | (0, (0.5, 0.6), 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [3, 2, 1, 0]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [3, 2, 1]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [3, 2, 1]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [3, 2]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [3, 2]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [3]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [3]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [3, 2, 1, 0, 4]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [3, 2, 1, 5]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [3, 2, 6]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [3, 2, 6]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [3, 7]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [3, 7]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [3, 2, 1, 0, 4, 8] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [3, 2, 1, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [3, 2, 6, 10]      | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [3, 7, 11]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [3, 7, 11]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# Adicionando regras para 4
# +---------------------+-------------------+--------------------+
# | Match               | Route             | Rule               |
# +=====================+===================+====================+
# | (0, (0.5, 0.6), 5)  | [4, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [4, 0]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [4, 0, 1]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [4, 0, 1]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [4, 0, 1, 2]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [4, 0, 1, 2, 3]   | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [4]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [4]               | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [4, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [4, 5]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [4, 5, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [4, 5, 6]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [4, 5, 6, 7]      | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [4, 8]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [4, 8]            | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [4, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [4, 5, 9]         | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [4, 8, 9, 10]     | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [4, 8, 9, 10, 11] | BasicRuleProactive |
# +---------------------+-------------------+--------------------+
# Adicionando regras para 5
# +---------------------+---------------+--------------------+
# | Match               | Route         | Rule               |
# +=====================+===============+====================+
# | (0, (0.5, 0.6), 5)  | [5, 4, 0]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [5, 4, 0]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [5, 1]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [5, 1]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [5, 1, 2]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [5, 1, 2]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [5, 1, 2, 3]  | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [5, 4]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [5, 4]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [5]           | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [5]           | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [5, 6]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [5, 6]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [5, 6, 7]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [5, 6, 7]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [5, 4, 8]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [5, 4, 8]     | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [5, 9]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [5, 9]        | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (10, (0.5, 0.6), 5) | [5, 6, 10]    | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (10, (0.8, 0.9), 5) | [5, 6, 10]    | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (11, (0.5, 0.6), 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# | (11, (0.8, 0.9), 5) | [5, 6, 7, 11] | BasicRuleProactive |
# +---------------------+---------------+--------------------+
# Adicionando regras para 6
# +---------------------+--------------+--------------------+
# | Match               | Route        | Rule               |
# +=====================+==============+====================+
# | (0, (0.5, 0.6), 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [6, 5, 4, 0] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [6, 5, 1]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [6, 5, 1]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [6, 2]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [6, 2]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [6, 2, 3]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [6, 2, 3]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [6, 5, 4]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [6, 5, 4]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [6, 5]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [6, 5]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [6]          | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [6]          | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [6, 7]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [6, 7]       | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [6, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [6, 5, 9]    | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (10, (0.5, 0.6), 5) | [6, 10]      | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (10, (0.8, 0.9), 5) | [6, 10]      | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (11, (0.5, 0.6), 5) | [6, 7, 11]   | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# | (11, (0.8, 0.9), 5) | [6, 7, 11]   | BasicRuleProactive |
# +---------------------+--------------+--------------------+
# Adicionando regras para 7
# +---------------------+-----------------+--------------------+
# | Match               | Route           | Rule               |
# +=====================+=================+====================+
# | (0, (0.5, 0.6), 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [7, 6, 2]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [7, 6, 2]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [7, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [7, 3]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [7, 6, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [7, 6, 5]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [7, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [7, 6]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [7]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [7]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [7, 6, 5, 4, 8] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [7, 6, 5, 9]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.5, 0.6), 5) | [7, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 5) | [7, 6, 10]      | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.5, 0.6), 5) | [7, 11]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 5) | [7, 11]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# Adicionando regras para 8
# +---------------------+--------------------+--------------------+
# | Match               | Route              | Rule               |
# +=====================+====================+====================+
# | (0, (0.5, 0.6), 5)  | [8, 4, 0]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [8, 4, 0]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [8, 4, 0, 1]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [8, 4, 0, 1, 2]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [8, 4, 0, 1, 2, 3] | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [8, 4]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [8, 4]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [8, 4, 5]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [8, 4, 5]          | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [8, 4, 5, 6]       | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [8, 4, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [8]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [8]                | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [8, 9]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [8, 9]             | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [8, 9, 10]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [8, 9, 10]         | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [8, 9, 10, 11]     | BasicRuleProactive |
# +---------------------+--------------------+--------------------+
# Adicionando regras para 9
# +---------------------+-----------------+--------------------+
# | Match               | Route           | Rule               |
# +=====================+=================+====================+
# | (0, (0.5, 0.6), 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [9, 8, 4, 0]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [9, 5, 1]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [9, 5, 1]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [9, 5, 1, 2]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [9, 5, 1, 2, 3] | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [9, 8, 4]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [9, 8, 4]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [9, 5]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [9, 5]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [9, 5, 6]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [9, 5, 6]       | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [9, 5, 6, 7]    | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [9, 8]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [9, 8]          | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [9]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [9]             | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.5, 0.6), 5) | [9, 10]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (10, (0.8, 0.9), 5) | [9, 10]         | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.5, 0.6), 5) | [9, 10, 11]     | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# | (11, (0.8, 0.9), 5) | [9, 10, 11]     | BasicRuleProactive |
# +---------------------+-----------------+--------------------+
# Adicionando regras para 10
# +---------------------+------------------+--------------------+
# | Match               | Route            | Rule               |
# +=====================+==================+====================+
# | (0, (0.5, 0.6), 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [10, 6, 2, 1, 0] | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [10, 6, 2, 1]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [10, 6, 2]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [10, 6, 2]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [10, 6, 2, 3]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [10, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [10, 9, 5]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [10, 9, 5]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [10, 6]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [10, 6]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [10, 6, 7]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [10, 6, 7]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [10, 9, 8]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [10, 9, 8]       | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [10, 9]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [10, 9]          | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [10]             | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [10]             | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [10, 11]         | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [10, 11]         | BasicRuleProactive |
# +---------------------+------------------+--------------------+
# Adicionando regras para 11
# +---------------------+---------------------+--------------------+
# | Match               | Route               | Rule               |
# +=====================+=====================+====================+
# | (0, (0.5, 0.6), 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (0, (0.8, 0.9), 5)  | [11, 7, 3, 2, 1, 0] | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (1, (0.5, 0.6), 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (1, (0.8, 0.9), 5)  | [11, 7, 3, 2, 1]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (2, (0.5, 0.6), 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (2, (0.8, 0.9), 5)  | [11, 7, 3, 2]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (3, (0.5, 0.6), 5)  | [11, 7, 3]          | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (3, (0.8, 0.9), 5)  | [11, 7, 3]          | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (4, (0.5, 0.6), 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (4, (0.8, 0.9), 5)  | [11, 7, 6, 5, 4]    | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (5, (0.5, 0.6), 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (5, (0.8, 0.9), 5)  | [11, 7, 6, 5]       | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (6, (0.5, 0.6), 5)  | [11, 10, 6]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (6, (0.8, 0.9), 5)  | [11, 10, 6]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (7, (0.5, 0.6), 5)  | [11, 7]             | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (7, (0.8, 0.9), 5)  | [11, 7]             | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (8, (0.5, 0.6), 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (8, (0.8, 0.9), 5)  | [11, 10, 9, 8]      | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (9, (0.5, 0.6), 5)  | [11, 10, 9]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (9, (0.8, 0.9), 5)  | [11, 10, 9]         | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (10, (0.5, 0.6), 5) | [11, 10]            | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (10, (0.8, 0.9), 5) | [11, 10]            | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (11, (0.5, 0.6), 5) | [11]                | BasicRuleProactive |
# +---------------------+---------------------+--------------------+
# | (11, (0.8, 0.9), 5) | [11]                | BasicRuleProactive |
# +---------------------+---------------------+--------------------+

# %% [markdown]
# Funções responsáveis pela passagem de tempo

# %%
def update_rules(host, time_for_update):
    """
    Atualiza as regras de um host
    Args:
        host (Host): Host que terá as regras atualizadas
        time_for_update (int): Tempo para atualização das regras
    """
    # Percorre a tabela de fluxo do host
    for match in host.flow_table.copy():
        # Recebe o objeto da regra, somente
        rule = host.flow_table[match][1]
        # Incrementa a idade da regra
        for t in range(time_for_update):
            rule.increment_age()
        # Verifica se a regra expirou
        if rule.ttl <= rule.age:
            if rule.hit_count == 0:
                host.flow_table.pop(match)
                print(f"[Time {time.get_current_time()}] Regra {rule} expirada em {host}")
            else:
                print(f"Regra reutilizada {rule} em {host}")
                rule.hit_count = 0
                rule.age = rule.ttl/2

def update_time(time_for_update):
    """
    Atualiza o tempo e as regras

    Args:
        time_for_update (int): Tempo para incrementar o time-slot.
    """
    # Atualiza o tempo
    for t in range(time_for_update):
        time.increment()
        # Atualiza os recursos de 10 em 10
        if time.get_current_time() % 10 == 0:
            rede.refresh_resources(num_qubits=10, num_eprs=10)
            print(f"[Time {time.get_current_time()}] Recursos atualizados")
    # Atualiza as regras
    for host in rede.hosts:
        update_rules(rede.get_host(host), time_for_update)

# %% [markdown]
# Requests sendo processadas

# %%
for request in requests:
    print(f"[Time {time.get_current_time()}]")
    print(f"Request: {request}, Alice: {request.alice}, Bob: {request.bob}, Fmin: {request.fmin}, Neprs: {request.neprs}")
    alice = rede.get_host(request.alice)
    rule = alice.find_rule_by_request(request)

    if rule == False:  # Caso não exista um match na tabela
        print(f"Descartando requisição {request} em {alice}")
        request.endtime = time.get_current_time()
        # Registra no CSV como um novo registro
        register_request(request, "Descartado", path)
    else:  # Caso já exista a regra
        request.starttime = time.get_current_time()
        controlador.run_rule(rule[1])
        request.endtime = time.get_current_time() + 1
        
        # Registra no CSV como já registrado
        register_request(request, "Já Registrado", path)
    
    update_time(1)
    # Exibir informações da requisição
    print(f"Request {request}: Start Time = {request.starttime}, End Time = {request.endtime}")
# Out:
# [Time 0]
# Request: R-ED0830, Alice: 8, Bob: 2, Fmin: 0.54, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# [BasicRuleProactive] Ação: Swap(0-1-2)
# Running Swap(0-1-2)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-ED0830: Start Time = 0, End Time = 1
# [Time 1]
# Request: R-DCE710, Alice: 8, Bob: 0, Fmin: 0.58, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# Request R-DCE710: Start Time = 1, End Time = 2
# [Time 2]
# Request: R-DCE850, Alice: 7, Bob: 8, Fmin: 0.9, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-5)
# Running Swap(7-6-5)
# [BasicRuleProactive] Ação: Swap(5-4-8)
# Running Swap(5-4-8)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(7-5-8)
# Running Swap(7-5-8)
# Request R-DCE850: Start Time = 2, End Time = 3
# [Time 3]
# Request: R-DD6D70, Alice: 5, Bob: 9, Fmin: 0.74, Neprs: 4
# Descartando requisição R-DD6D70 em 5
# Request R-DD6D70: Start Time = 0, End Time = 3
# [Time 4]
# Request: R-DD6EA0, Alice: 10, Bob: 1, Fmin: 0.64, Neprs: 3
# Descartando requisição R-DD6EA0 em 10
# Request R-DD6EA0: Start Time = 0, End Time = 4
# [Time 5]
# Request: R-DCB9B0, Alice: 8, Bob: 2, Fmin: 0.92, Neprs: 4
# Descartando requisição R-DCB9B0 em 8
# Request R-DCB9B0: Start Time = 0, End Time = 5
# [Time 6]
# Request: R-E3EAD0, Alice: 7, Bob: 2, Fmin: 0.82, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-2)
# Running Swap(7-6-2)
# Request R-E3EAD0: Start Time = 6, End Time = 7
# [Time 7]
# Request: R-E3EBE0, Alice: 2, Bob: 7, Fmin: 0.55, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Ação: CreateEPR(3-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(2-3-7)
# Running Swap(2-3-7)
# Request R-E3EBE0: Start Time = 7, End Time = 8
# [Time 8]
# Request: R-E75450, Alice: 2, Bob: 8, Fmin: 0.99, Neprs: 2
# Descartando requisição R-E75450 em 2
# Request R-E75450: Start Time = 0, End Time = 8
# [Time 9]
# Request: R-E75550, Alice: 5, Bob: 4, Fmin: 0.74, Neprs: 4
# Descartando requisição R-E75550 em 5
# [Time 10] Recursos atualizados
# Request R-E75550: Start Time = 0, End Time = 9
# [Time 10]
# Request: R-EC0500, Alice: 3, Bob: 7, Fmin: 0.53, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-7)
# Request R-EC0500: Start Time = 10, End Time = 11
# [Time 11]
# Request: R-EC07D0, Alice: 4, Bob: 3, Fmin: 0.55, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(4-0-1)
# Running Swap(4-0-1)
# [BasicRuleProactive] Ação: Swap(1-2-3)
# Running Swap(1-2-3)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-EC07D0: Start Time = 11, End Time = 12
# [Time 12]
# Request: R-ED4210, Alice: 7, Bob: 5, Fmin: 0.84, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-ED4210: Start Time = 12, End Time = 13
# [Time 13]
# Request: R-ED42F0, Alice: 9, Bob: 5, Fmin: 0.77, Neprs: 2
# Descartando requisição R-ED42F0 em 9
# Request R-ED42F0: Start Time = 0, End Time = 13
# [Time 14]
# Request: R-EA35F0, Alice: 7, Bob: 3, Fmin: 0.88, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-3)
# Request R-EA35F0: Start Time = 14, End Time = 15
# [Time 15]
# Request: R-D27B90, Alice: 4, Bob: 7, Fmin: 0.96, Neprs: 4
# Descartando requisição R-D27B90 em 4
# Request R-D27B90: Start Time = 0, End Time = 15
# [Time 16]
# Request: R-D27C50, Alice: 7, Bob: 6, Fmin: 0.55, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# Request R-D27C50: Start Time = 16, End Time = 17
# [Time 17]
# Request: R-E4DC80, Alice: 7, Bob: 2, Fmin: 0.98, Neprs: 4
# Descartando requisição R-E4DC80 em 7
# Request R-E4DC80: Start Time = 0, End Time = 17
# [Time 18]
# Request: R-E4DD30, Alice: 3, Bob: 0, Fmin: 0.94, Neprs: 2
# Descartando requisição R-E4DD30 em 3
# Request R-E4DD30: Start Time = 0, End Time = 18
# [Time 19]
# Request: R-EAE0D0, Alice: 4, Bob: 6, Fmin: 0.58, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(4-5-6)
# Running Swap(4-5-6)
# [Time 20] Recursos atualizados
# Request R-EAE0D0: Start Time = 19, End Time = 20
# [Time 20]
# Request: R-EAE210, Alice: 5, Bob: 6, Fmin: 0.79, Neprs: 4
# Descartando requisição R-EAE210 em 5
# Request R-EAE210: Start Time = 0, End Time = 20
# [Time 21]
# Request: R-E79C70, Alice: 5, Bob: 7, Fmin: 0.54, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Request R-E79C70: Start Time = 21, End Time = 22
# [Time 22]
# Request: R-ECD150, Alice: 2, Bob: 9, Fmin: 0.76, Neprs: 3
# Descartando requisição R-ECD150 em 2
# Request R-ECD150: Start Time = 0, End Time = 22
# [Time 23]
# Request: R-ECD2D0, Alice: 1, Bob: 10, Fmin: 0.66, Neprs: 2
# Descartando requisição R-ECD2D0 em 1
# Request R-ECD2D0: Start Time = 0, End Time = 23
# [Time 24]
# Request: R-ECD350, Alice: 5, Bob: 10, Fmin: 0.76, Neprs: 3
# Descartando requisição R-ECD350 em 5
# Request R-ECD350: Start Time = 0, End Time = 24
# [Time 25]
# Request: R-ECD3D0, Alice: 3, Bob: 0, Fmin: 0.81, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-2)
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(3-2-1)
# Running Swap(3-2-1)
# Request R-ECD3D0: Start Time = 25, End Time = 26
# [Time 26]
# Request: R-ECD450, Alice: 3, Bob: 4, Fmin: 0.7, Neprs: 4
# Descartando requisição R-ECD450 em 3
# Request R-ECD450: Start Time = 0, End Time = 26
# [Time 27]
# Request: R-ECD4D0, Alice: 5, Bob: 2, Fmin: 0.92, Neprs: 4
# Descartando requisição R-ECD4D0 em 5
# Request R-ECD4D0: Start Time = 0, End Time = 27
# [Time 28]
# Request: R-ECD550, Alice: 1, Bob: 8, Fmin: 0.77, Neprs: 2
# Descartando requisição R-ECD550 em 1
# Request R-ECD550: Start Time = 0, End Time = 28
# [Time 29]
# Request: R-ECD5D0, Alice: 10, Bob: 7, Fmin: 0.64, Neprs: 2
# Descartando requisição R-ECD5D0 em 10
# [Time 30] Recursos atualizados
# Request R-ECD5D0: Start Time = 0, End Time = 29
# [Time 30]
# Request: R-ECD650, Alice: 8, Bob: 9, Fmin: 0.69, Neprs: 4
# Descartando requisição R-ECD650 em 8
# Request R-ECD650: Start Time = 0, End Time = 30
# [Time 31]
# Request: R-ECD6D0, Alice: 0, Bob: 5, Fmin: 0.73, Neprs: 4
# Descartando requisição R-ECD6D0 em 0
# Request R-ECD6D0: Start Time = 0, End Time = 31
# [Time 32]
# Request: R-ECD750, Alice: 8, Bob: 4, Fmin: 0.62, Neprs: 4
# Descartando requisição R-ECD750 em 8
# Request R-ECD750: Start Time = 0, End Time = 32
# [Time 33]
# Request: R-ECD7D0, Alice: 1, Bob: 5, Fmin: 0.87, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(1-5)
# Request R-ECD7D0: Start Time = 33, End Time = 34
# [Time 34]
# Request: R-ECD850, Alice: 2, Bob: 7, Fmin: 0.92, Neprs: 4
# Descartando requisição R-ECD850 em 2
# Request R-ECD850: Start Time = 0, End Time = 34
# [Time 35]
# Request: R-ECD8D0, Alice: 2, Bob: 4, Fmin: 0.86, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-ECD8D0: Start Time = 35, End Time = 36
# [Time 36]
# Request: R-ECD950, Alice: 5, Bob: 3, Fmin: 0.79, Neprs: 2
# Descartando requisição R-ECD950 em 5
# Request R-ECD950: Start Time = 0, End Time = 36
# [Time 37]
# Request: R-ECD9D0, Alice: 9, Bob: 2, Fmin: 0.95, Neprs: 2
# Descartando requisição R-ECD9D0 em 9
# Request R-ECD9D0: Start Time = 0, End Time = 37
# [Time 38]
# Request: R-ECDA50, Alice: 9, Bob: 7, Fmin: 0.77, Neprs: 4
# Descartando requisição R-ECDA50 em 9
# Request R-ECDA50: Start Time = 0, End Time = 38
# [Time 39]
# Request: R-ECDAD0, Alice: 2, Bob: 3, Fmin: 0.77, Neprs: 3
# Descartando requisição R-ECDAD0 em 2
# [Time 40] Recursos atualizados
# Request R-ECDAD0: Start Time = 0, End Time = 39
# [Time 40]
# Request: R-ECDB50, Alice: 1, Bob: 3, Fmin: 0.6, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(1-2-3)
# Running Swap(1-2-3)
# Request R-ECDB50: Start Time = 40, End Time = 41
# [Time 41]
# Request: R-ECDBD0, Alice: 6, Bob: 7, Fmin: 0.64, Neprs: 2
# Descartando requisição R-ECDBD0 em 6
# Request R-ECDBD0: Start Time = 0, End Time = 41
# [Time 42]
# Request: R-ECDC50, Alice: 0, Bob: 4, Fmin: 0.55, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# Request R-ECDC50: Start Time = 42, End Time = 43
# [Time 43]
# Request: R-ECDCD0, Alice: 6, Bob: 4, Fmin: 0.87, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(6-5-4)
# Running Swap(6-5-4)
# Request R-ECDCD0: Start Time = 43, End Time = 44
# [Time 44]
# Request: R-ECDD50, Alice: 4, Bob: 0, Fmin: 0.85, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# Request R-ECDD50: Start Time = 44, End Time = 45
# [Time 45]
# Request: R-ECDDD0, Alice: 10, Bob: 2, Fmin: 0.7, Neprs: 2
# Descartando requisição R-ECDDD0 em 10
# Request R-ECDDD0: Start Time = 0, End Time = 45
# [Time 46]
# Request: R-ECDE50, Alice: 1, Bob: 5, Fmin: 0.82, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(1-5)
# Request R-ECDE50: Start Time = 46, End Time = 47
# [Time 47]
# Request: R-ECDED0, Alice: 0, Bob: 8, Fmin: 0.97, Neprs: 3
# Descartando requisição R-ECDED0 em 0
# Request R-ECDED0: Start Time = 0, End Time = 47
# [Time 48]
# Request: R-ECDF50, Alice: 1, Bob: 8, Fmin: 0.52, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(1-0-4)
# Running Swap(1-0-4)
# Request R-ECDF50: Start Time = 48, End Time = 49
# [Time 49]
# Request: R-ECDFD0, Alice: 8, Bob: 6, Fmin: 0.56, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-5)
# Running Swap(8-4-5)
# [Time 50] Recursos atualizados
# Request R-ECDFD0: Start Time = 49, End Time = 50
# [Time 50]
# Request: R-ECE050, Alice: 8, Bob: 2, Fmin: 0.87, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# [BasicRuleProactive] Ação: Swap(0-1-2)
# Running Swap(0-1-2)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-ECE050: Start Time = 50, End Time = 51
# [Time 51]
# Request: R-ECE0D0, Alice: 3, Bob: 6, Fmin: 0.78, Neprs: 2
# Descartando requisição R-ECE0D0 em 3
# Request R-ECE0D0: Start Time = 0, End Time = 51
# [Time 52]
# Request: R-ECE150, Alice: 2, Bob: 6, Fmin: 0.59, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-6)
# Request R-ECE150: Start Time = 52, End Time = 53
# [Time 53]
# Request: R-ECE1D0, Alice: 5, Bob: 2, Fmin: 0.89, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(5-1-2)
# Running Swap(5-1-2)
# Request R-ECE1D0: Start Time = 53, End Time = 54
# [Time 54]
# Request: R-ECE250, Alice: 8, Bob: 10, Fmin: 0.62, Neprs: 3
# Descartando requisição R-ECE250 em 8
# Request R-ECE250: Start Time = 0, End Time = 54
# [Time 55]
# Request: R-ECE2D0, Alice: 6, Bob: 2, Fmin: 0.99, Neprs: 4
# Descartando requisição R-ECE2D0 em 6
# Request R-ECE2D0: Start Time = 0, End Time = 55
# [Time 56]
# Request: R-ECE350, Alice: 1, Bob: 4, Fmin: 0.69, Neprs: 4
# Descartando requisição R-ECE350 em 1
# Request R-ECE350: Start Time = 0, End Time = 56
# [Time 57]
# Request: R-ECE3D0, Alice: 2, Bob: 9, Fmin: 0.71, Neprs: 2
# Descartando requisição R-ECE3D0 em 2
# Request R-ECE3D0: Start Time = 0, End Time = 57
# [Time 58]
# Request: R-ECE450, Alice: 0, Bob: 1, Fmin: 0.54, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# Request R-ECE450: Start Time = 58, End Time = 59
# [Time 59]
# Request: R-ECE4D0, Alice: 8, Bob: 9, Fmin: 0.59, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-9)
# [Time 60] Recursos atualizados
# Request R-ECE4D0: Start Time = 59, End Time = 60
# [Time 60]
# Request: R-ECE550, Alice: 2, Bob: 4, Fmin: 0.99, Neprs: 2
# Descartando requisição R-ECE550 em 2
# Request R-ECE550: Start Time = 0, End Time = 60
# [Time 61]
# Request: R-ECE5D0, Alice: 9, Bob: 6, Fmin: 0.59, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-5)
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-5-6)
# Running Swap(9-5-6)
# Request R-ECE5D0: Start Time = 61, End Time = 62
# [Time 62]
# Request: R-ECE650, Alice: 4, Bob: 3, Fmin: 0.76, Neprs: 4
# Descartando requisição R-ECE650 em 4
# Request R-ECE650: Start Time = 0, End Time = 62
# [Time 63]
# Request: R-ECE6D0, Alice: 7, Bob: 6, Fmin: 0.78, Neprs: 2
# Descartando requisição R-ECE6D0 em 7
# Request R-ECE6D0: Start Time = 0, End Time = 63
# [Time 64]
# Request: R-ECE750, Alice: 10, Bob: 7, Fmin: 0.66, Neprs: 4
# Descartando requisição R-ECE750 em 10
# Request R-ECE750: Start Time = 0, End Time = 64
# [Time 65]
# Request: R-ECE7D0, Alice: 8, Bob: 4, Fmin: 0.52, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# Request R-ECE7D0: Start Time = 65, End Time = 66
# [Time 66]
# Request: R-ECE850, Alice: 3, Bob: 4, Fmin: 0.66, Neprs: 2
# Descartando requisição R-ECE850 em 3
# Request R-ECE850: Start Time = 0, End Time = 66
# [Time 67]
# Request: R-ECE8D0, Alice: 2, Bob: 3, Fmin: 0.9, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# Request R-ECE8D0: Start Time = 67, End Time = 68
# [Time 68]
# Request: R-ECE950, Alice: 3, Bob: 10, Fmin: 0.94, Neprs: 4
# Descartando requisição R-ECE950 em 3
# Request R-ECE950: Start Time = 0, End Time = 68
# [Time 69]
# Request: R-ECE9D0, Alice: 0, Bob: 10, Fmin: 0.69, Neprs: 3
# Descartando requisição R-ECE9D0 em 0
# [Time 70] Recursos atualizados
# Request R-ECE9D0: Start Time = 0, End Time = 69
# [Time 70]
# Request: R-ECEA50, Alice: 1, Bob: 10, Fmin: 0.84, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(1-5)
# [BasicRuleProactive] Ação: CreateEPR(5-9)
# [BasicRuleProactive] Ação: CreateEPR(9-10)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(1-5-9)
# Running Swap(1-5-9)
# Request R-ECEA50: Start Time = 70, End Time = 71
# [Time 71]
# Request: R-ECEAD0, Alice: 8, Bob: 2, Fmin: 0.52, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-0)
# Running Swap(8-4-0)
# [BasicRuleProactive] Ação: Swap(0-1-2)
# Running Swap(0-1-2)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(8-0-2)
# Running Swap(8-0-2)
# Request R-ECEAD0: Start Time = 71, End Time = 72
# [Time 72]
# Request: R-ECEB50, Alice: 7, Bob: 5, Fmin: 0.59, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(7-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(7-6-5)
# Running Swap(7-6-5)
# Request R-ECEB50: Start Time = 72, End Time = 73
# [Time 73]
# Request: R-ECEBD0, Alice: 5, Bob: 7, Fmin: 0.56, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(5-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(5-6-7)
# Running Swap(5-6-7)
# Request R-ECEBD0: Start Time = 73, End Time = 74
# [Time 74]
# Request: R-ECEC50, Alice: 10, Bob: 0, Fmin: 0.71, Neprs: 4
# Descartando requisição R-ECEC50 em 10
# Request R-ECEC50: Start Time = 0, End Time = 74
# [Time 75]
# Request: R-ECECD0, Alice: 8, Bob: 10, Fmin: 0.72, Neprs: 3
# Descartando requisição R-ECECD0 em 8
# Request R-ECECD0: Start Time = 0, End Time = 75
# [Time 76]
# Request: R-ECED50, Alice: 8, Bob: 2, Fmin: 0.92, Neprs: 4
# Descartando requisição R-ECED50 em 8
# Request R-ECED50: Start Time = 0, End Time = 76
# [Time 77]
# Request: R-ECEDD0, Alice: 10, Bob: 7, Fmin: 0.53, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-7)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-7)
# Running Swap(10-6-7)
# Request R-ECEDD0: Start Time = 77, End Time = 78
# [Time 78]
# Request: R-ECEE50, Alice: 5, Bob: 4, Fmin: 0.91, Neprs: 2
# Descartando requisição R-ECEE50 em 5
# Request R-ECEE50: Start Time = 0, End Time = 78
# [Time 79]
# Request: R-ECEED0, Alice: 9, Bob: 6, Fmin: 0.79, Neprs: 4
# Descartando requisição R-ECEED0 em 9
# [Time 80] Recursos atualizados
# Request R-ECEED0: Start Time = 0, End Time = 79
# [Time 80]
# Request: R-ECEF50, Alice: 2, Bob: 1, Fmin: 0.81, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# Request R-ECEF50: Start Time = 80, End Time = 81
# [Time 81]
# Request: R-ECEFD0, Alice: 10, Bob: 2, Fmin: 0.52, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-2)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-2)
# Running Swap(10-6-2)
# Request R-ECEFD0: Start Time = 81, End Time = 82
# [Time 82]
# Request: R-ECF050, Alice: 10, Bob: 3, Fmin: 0.71, Neprs: 4
# Descartando requisição R-ECF050 em 10
# Request R-ECF050: Start Time = 0, End Time = 82
# [Time 83]
# Request: R-ECF0D0, Alice: 4, Bob: 3, Fmin: 0.85, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-0)
# [BasicRuleProactive] Ação: CreateEPR(0-1)
# [BasicRuleProactive] Ação: CreateEPR(1-2)
# [BasicRuleProactive] Ação: CreateEPR(2-3)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(4-0-1)
# Running Swap(4-0-1)
# [BasicRuleProactive] Ação: Swap(1-2-3)
# Running Swap(1-2-3)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(4-1-3)
# Running Swap(4-1-3)
# Request R-ECF0D0: Start Time = 83, End Time = 84
# [Time 84]
# Request: R-ECF150, Alice: 0, Bob: 8, Fmin: 0.88, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(0-4-8)
# Running Swap(0-4-8)
# Request R-ECF150: Start Time = 84, End Time = 85
# [Time 85]
# Request: R-ECF1D0, Alice: 2, Bob: 8, Fmin: 0.53, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# [BasicRuleProactive] Ação: Swap(0-4-8)
# Running Swap(0-4-8)
# [BasicRuleProactive] Passo: 3
# [BasicRuleProactive] Ação: Swap(2-0-8)
# Running Swap(2-0-8)
# Request R-ECF1D0: Start Time = 85, End Time = 86
# [Time 86]
# Request: R-ECF250, Alice: 2, Bob: 4, Fmin: 0.52, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-1)
# [BasicRuleProactive] Ação: CreateEPR(1-0)
# [BasicRuleProactive] Ação: CreateEPR(0-4)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(2-1-0)
# Running Swap(2-1-0)
# Request R-ECF250: Start Time = 86, End Time = 87
# [Time 87]
# Request: R-ECF2D0, Alice: 1, Bob: 5, Fmin: 0.71, Neprs: 2
# Descartando requisição R-ECF2D0 em 1
# Request R-ECF2D0: Start Time = 0, End Time = 87
# [Time 88]
# Request: R-ECF350, Alice: 3, Bob: 7, Fmin: 0.53, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-7)
# Request R-ECF350: Start Time = 88, End Time = 89
# [Time 89]
# Request: R-ECF3D0, Alice: 4, Bob: 1, Fmin: 0.98, Neprs: 3
# Descartando requisição R-ECF3D0 em 4
# [Time 90] Recursos atualizados
# Request R-ECF3D0: Start Time = 0, End Time = 89
# [Time 90]
# Request: R-ECF450, Alice: 2, Bob: 6, Fmin: 0.5, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(2-6)
# Request R-ECF450: Start Time = 90, End Time = 91
# [Time 91]
# Request: R-ECF4D0, Alice: 8, Bob: 5, Fmin: 0.82, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(8-4)
# [BasicRuleProactive] Ação: CreateEPR(4-5)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(8-4-5)
# Running Swap(8-4-5)
# Request R-ECF4D0: Start Time = 91, End Time = 92
# [Time 92]
# Request: R-ECF550, Alice: 9, Bob: 0, Fmin: 0.61, Neprs: 4
# Descartando requisição R-ECF550 em 9
# Request R-ECF550: Start Time = 0, End Time = 92
# [Time 93]
# Request: R-ECF5D0, Alice: 9, Bob: 1, Fmin: 0.51, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(9-5)
# [BasicRuleProactive] Ação: CreateEPR(5-1)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(9-5-1)
# Running Swap(9-5-1)
# Request R-ECF5D0: Start Time = 93, End Time = 94
# [Time 94]
# Request: R-ECF650, Alice: 4, Bob: 10, Fmin: 0.57, Neprs: 2
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(4-8)
# [BasicRuleProactive] Ação: CreateEPR(8-9)
# [BasicRuleProactive] Ação: CreateEPR(9-10)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(4-8-9)
# Running Swap(4-8-9)
# Request R-ECF650: Start Time = 94, End Time = 95
# [Time 95]
# Request: R-ECF6D0, Alice: 2, Bob: 4, Fmin: 0.78, Neprs: 2
# Descartando requisição R-ECF6D0 em 2
# Request R-ECF6D0: Start Time = 0, End Time = 95
# [Time 96]
# Request: R-ECF750, Alice: 10, Bob: 4, Fmin: 0.83, Neprs: 3
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(10-6)
# [BasicRuleProactive] Ação: CreateEPR(6-5)
# [BasicRuleProactive] Ação: CreateEPR(5-4)
# [BasicRuleProactive] Passo: 2
# [BasicRuleProactive] Ação: Swap(10-6-5)
# Running Swap(10-6-5)
# Request R-ECF750: Start Time = 96, End Time = 97
# [Time 97]
# Request: R-ECF7D0, Alice: 2, Bob: 1, Fmin: 0.74, Neprs: 4
# Descartando requisição R-ECF7D0 em 2
# Request R-ECF7D0: Start Time = 0, End Time = 97
# [Time 98]
# Request: R-ECF850, Alice: 1, Bob: 3, Fmin: 0.65, Neprs: 2
# Descartando requisição R-ECF850 em 1
# Request R-ECF850: Start Time = 0, End Time = 98
# [Time 99]
# Request: R-ECF8D0, Alice: 3, Bob: 7, Fmin: 0.85, Neprs: 4
# [BasicRuleProactive] Passo: 1
# [BasicRuleProactive] Ação: CreateEPR(3-7)
# [Time 100] Recursos atualizados
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# Regra reutilizada BasicRuleProactive em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# Regra reutilizada BasicRuleProactive em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# Regra reutilizada BasicRuleProactive em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 0
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# Regra reutilizada BasicRuleProactive em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# Regra reutilizada BasicRuleProactive em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# Regra reutilizada BasicRuleProactive em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# Regra reutilizada BasicRuleProactive em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 1
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# Regra reutilizada BasicRuleProactive em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# Regra reutilizada BasicRuleProactive em 2
# Regra reutilizada BasicRuleProactive em 2
# Regra reutilizada BasicRuleProactive em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# Regra reutilizada BasicRuleProactive em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# Regra reutilizada BasicRuleProactive em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# Regra reutilizada BasicRuleProactive em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 2
# [Time 100] Regra BasicRuleProactive expirada em 3
# Regra reutilizada BasicRuleProactive em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# Regra reutilizada BasicRuleProactive em 3
# Regra reutilizada BasicRuleProactive em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 3
# [Time 100] Regra BasicRuleProactive expirada em 4
# Regra reutilizada BasicRuleProactive em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# Regra reutilizada BasicRuleProactive em 4
# Regra reutilizada BasicRuleProactive em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# Regra reutilizada BasicRuleProactive em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# Regra reutilizada BasicRuleProactive em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 4
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# Regra reutilizada BasicRuleProactive em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# Regra reutilizada BasicRuleProactive em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 5
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# Regra reutilizada BasicRuleProactive em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 6
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# Regra reutilizada BasicRuleProactive em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# Regra reutilizada BasicRuleProactive em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# Regra reutilizada BasicRuleProactive em 7
# Regra reutilizada BasicRuleProactive em 7
# Regra reutilizada BasicRuleProactive em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# Regra reutilizada BasicRuleProactive em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# [Time 100] Regra BasicRuleProactive expirada em 7
# Regra reutilizada BasicRuleProactive em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# Regra reutilizada BasicRuleProactive em 8
# Regra reutilizada BasicRuleProactive em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# Regra reutilizada BasicRuleProactive em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# Regra reutilizada BasicRuleProactive em 8
# Regra reutilizada BasicRuleProactive em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# Regra reutilizada BasicRuleProactive em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 8
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# Regra reutilizada BasicRuleProactive em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# Regra reutilizada BasicRuleProactive em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 9
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# Regra reutilizada BasicRuleProactive em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# Regra reutilizada BasicRuleProactive em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# Regra reutilizada BasicRuleProactive em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 10
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# [Time 100] Regra BasicRuleProactive expirada em 11
# Request R-ECF8D0: Start Time = 99, End Time = 100

# %%
rede.registry_of_resources
# Out:
# {'qubits created': 1320,
#  'qubits used': 204,
#  'eprs created': 3222,
#  'eprs used': 0}
